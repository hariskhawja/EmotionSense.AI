# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import random
import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zroy1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def clean_text(text):
    text = re.sub(r"[!@#$(),\n%^*?.'\:;~`0-9]", '', str(text))
    text = text.lower()

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text, language='english', preserve_line=True)
    text = " ".join(word for word in word_tokens if not word.lower() in stop_words)
    
    return text

# %%
def prediction(text, model, cv):
    text = clean_text(text)
    X = cv.transform([text]).toarray()
    return model.predict_proba(X)

# %% [markdown]
# # Positivity Dataset

# %%
filename = "positivity.csv"
positivity = pd.read_csv(filename, encoding="ISO-8859-1")
positivity
# Out:
#        Unnamed: 0  sentiment          id                          date  \
# 0               0          0  1467811184  Mon Apr 06 22:19:57 PDT 2009
# 1               1          0  1467811594  Mon Apr 06 22:20:03 PDT 2009
# 2               2          0  1467812964  Mon Apr 06 22:20:22 PDT 2009
# 3               3          0  1467825863  Mon Apr 06 22:23:43 PDT 2009
# 4               4          0  1467826052  Mon Apr 06 22:23:45 PDT 2009
# ...           ...        ...         ...                           ...
# 49995       49995          1  2193552981  Tue Jun 16 08:36:49 PDT 2009
# 49996       49996          1  2193554410  Tue Jun 16 08:36:56 PDT 2009
# 49997       49997          1  2193576655  Tue Jun 16 08:38:46 PDT 2009
# 49998       49998          1  2193577315  Tue Jun 16 08:38:49 PDT 2009
# 49999       49999          1  2193577918  Tue Jun 16 08:38:53 PDT 2009
#
#            flag            user  \
# 0      NO_QUERY         ElleCTF
# 1      NO_QUERY            coZZ
# 2      NO_QUERY  lovesongwriter
# 3      NO_QUERY    BrookeAmanda
# 4      NO_QUERY     paulseverio
# ...         ...             ...
# 49995  NO_QUERY       JDenouden
# 49996  NO_QUERY      Arr0wsmith
# 49997  NO_QUERY       eratyptin
# 49998  NO_QUERY        jamie_ox
# 49999  NO_QUERY    milliontwits
#
#                                                     text
# 0        my whole body feels itchy and like its on fire
# 1      @LOLTrish hey  long time no see! Yes.. Rains a...
# 2      Hollis' death scene will hurt me severely to w...
# 3      i really hate how people diss my bands!  Trace...
# 4      Why won't you show my location?!   http://twit...
# ...                                                  ...
# 49995  @NLPride08 that's a perfectly reasonable time ...
# 49996  @Jihav actually my other PSN ID is GUNSnSPEEDO...
# 49997  @siahoney I am good thanks!    How is #Eric, I...
# 49998  doing another piece of media homework is that ...
# 49999  @stum450n Hi. Thanks for the follow. Nice webs...
#
# [50000 rows x 7 columns]

# %%
positivity_X = positivity["text"]
positivity_y = positivity["sentiment"]

# %%
positivity_texts = []
for text in positivity_X:
    positivity_texts.append(clean_text(text))
positivity_texts
# Out:
# ['whole body feels itchy like fire',
#  'loltrish hey long time see yes rains bit bit lol im fine thanks hows',
#  'hollis death scene hurt severely watch film wry directors cut',
#  'really hate people diss bands trace clearly ugly',
#  'wont show location http//twitpiccom/yes',
#  'kpreyes remember bum leg strikes back time serious',
#  'ozesteph shame hear stephan',
#  'caitlinoconnor want tacos margarhitas telll gay say hello & lt',
#  'missing bff watching home away reminds & lt shout u courts',
#  'chriscantore congrats im totally jealous wish xm working',
#  'marge_inovera tried tweetdeck hated passion hated im sure',
#  'danadearmond',
#  'trolley packed like sardines padre game remove car good call mts',
#  'mamasvan lol - nope complete camerafail',
#  'b_barnett really see coming',
#  'nicolerichie oh yes miss',
#  'eazydoesit negative lost vote confidence',
#  'sofii_noel thatï¿½s bad',
#  'crap need dresses',
#  'huuuge headache omg feel like crap',
#  'dammit need stop buying furniture',
#  'ill cant go cinema',
#  'marybethune oh everything happened today forgot going dress shopping opera tomorrow',
#  'chordsy - last find things like youre twitter',
#  'photoshop hate crash',
#  'four games fall modern warfare halo odst brutal legend bioshock need cash',
#  'miss home calving seasonsad black one died morning wish bottle calves',
#  'heidimontag wish would get time rest world unfornately cairo wait mtva play',
#  'home spring break one home tho',
#  'winggato free comp lol',
#  'crying friend moving away tomorrow',
#  'good morning everybody pkoi fais pas beau bon coffee time',
#  'vernonhamilton youre stranger',
#  'smokey_robinson fell listdid offend',
#  'feeling well stupid migraine making tummy upset whole body aches shoot',
#  'dog cant move anymore praying okay',
#  'mhm good day blah blah blah',
#  'sensesdestroyer wan na go lamb god',
#  'onlysweeter dont know dance',
#  'sigh rain decide show move away invited tuesday-party start hoped',
#  'lanarisque hahahahhha hows food poisening going gone away',
#  'woke hour ago im hard time going back bed lakewood ca http//looptus/rywlhq',
#  'work w asma nawal fe obeerate alwatan tv',
#  'avisionofbeauty phone doesnt like sorry',
#  'thanks chaffie thousand apologies please fogive sinned',
#  'itschelseastaub goodnight chels sorry major layout-delay & lt',
#  'morning v groggy morning',
#  'tried fix hubbys computer didnt come disks windows key wont work might buy like afford',
#  'tired leave bed',
#  'beginning enjoy lazy town - oh dear',
#  'wyldceltic oh man sad ever',
#  'aholmes_nj able downthemall ta able delete account didnt lose photos lost almost comments',
#  'bkgirlfriday dude snowed todaycant imagine weather hawaii right',
#  'theajp glad enjoyed mate gigs lined near future none horizon mo',
#  'got denied letter bazaar bizarre sad looking forward road trip vendor',
#  'schnicklefritz omg problem lent someone never gave back',
#  'arielehenriques feel like preaching lol damn im guilty',
#  'oh em gee love http//tinyurlcom/djjc want want want lusting things afford',
#  'jamzeee knowwwwww sukkkk take care gurls',
#  'iwouldificould watched tried youtube link wont work',
#  'realized im talking one',
#  'downy weather wheres summer',
#  'pose ta b goin ta az dis week hope lol',
#  'tired need regular -',
#  'journalist throws shoe chidambaram http//ibnliveincom/news/journalist-throws-shoe-at-chidambaram/-html',
#  'went doctors today blood sugar level',
#  'shelikescute thats sad',
#  'sick today lot work',
#  'oh darnits mandy creed isnt jordar mikerra',
#  'common chidambaram george bush http//newsoneindiain////sikh-journalist-hurls-shoe-at-p-chidambaramhtml',
#  'still waiting missing baby boy',
#  'cant sleep im stressing jpc & lt',
#  'liking back work morning',
#  'feeling really really ill',
#  'also want easter break / pï¿½sklov',
#  'nobody likes leatherhead',
#  'beeeaaach',
#  'sucked heather sewage bath xp poor owen bear total drama island',
#  'sickness making impossible sleep hot',
#  'cant sleep wondering following keeps going guess got ta try interesting haha',
#  'kremsersenf away tubingen germs yes away friends much',
#  'awww ellie sounds sick poor thing',
#  'episode house cuddy hook apo meetings fault',
#  'wants use -directional dance pad pero di compatible sa tv yung game http//plurkcom/p/nhyu',
#  'morning im baggered gym work later',
#  'knotserious oh btwdjrocko & amp tried go cuban buffet told u aboutso excitedits closed mondays sad story',
#  'bnish dan grabbed yardhouse earlier didnt pirate disappointed',
#  'robertzalme yes much theory getting much solutions coming',
#  'mean nobody goes anymore x',
#  'ugh mum wake early geesh need sleep princessnadysthere noth awww',
#  'got offer go camping fraser island weekend would jump offer without nd thought forecast rain',
#  'insomnia headache',
#  'mckayla_jb hey lol btw u know upload picture tried never shows xo',
#  'jona_thin sorry must left corel install cd somewhere room',
#  'got amazing new pedal blew speakers',
#  'still waiting dispatch got hour ago sleeping hours guess ill go back bed',
#  'entered online poker tournement others finished th',
#  'really sleeping already cant seem get bed sun comes progress sorting life slow+hard',
#  'ryuoky sun hoping sit balcony',
#  'hrs need go quick',
#  'youve failed',
#  'get mine iï¿½m going tour copenhagen ï¿½ hmmph cant top must get thinking http//tinyurlcom/ctrgj',
#  'fragilemuse book awesome great works couldnt afford buy today tho',
#  'kev_nz lol better let aboy know hes deploy bedtime hope feeling better sick sux',
#  'childrensjewell damn annoying happens isnt hope doesnt copy work',
#  'guess go bed hours havent able sleep lately stressed website done yet',
#  'pigman love cooler trenchcoat weather dnw darker evenings scary run night',
#  'hopeok soon -dies-',
#  'found nice lake-side park small beach grills oh well ill keep looking - another time',
#  'erickaaa im workkkk im freezing need mass hug call u night babe xxx',
#  'delay',
#  'wet hair eyes',
#  'coffee going twitter facebook social networks seems become full time job keep',
#  'joypalmer wake think ah yes thats mice running around ceiling',
#  'moving managerial finance nicht gut',
#  'work plus im sick blah',
#  'incrediblesteve cold turkeys way know',
#  'morning gone',
#  'cant sleep frustrating',
#  'eating lunch forgot get home cooked food morning',
#  'ohdatsbeezy - dont mind behind follows',
#  'wellreadkitty oh poor thing used ot love squeezing pus vet nurse kinda gross really',
#  '& quotwho favorite vintage designer & quot lucy & quottopshop & quot miss cycle britains ntm',
#  'honey_ nasty reports flooding yet multiple reports bad hair wet pants however',
#  'mfarnsworth retired time done mate',
#  'absolutelybatty hugs back thanks hon cant believe hes gone',
#  'wish going melbourne wkend harlot house tramp',
#  'mmmm chocolate cupcake lorraine kellys fault know cakestand full cupcakes im getting hooked',
#  'whats world ppl decide shoot others watching news depressing',
#  'zeenav sims shut',
#  'nikkiwoods thinks bust day late overslept still keep u entertained w/o perving lol',
#  'oh gosh messy hair',
#  'think dead',
#  'seriously freaked outfuzz',
#  'kymhuynh hahaha yeah laughed way end sick',
#  'going deaf right ear many feedback squalls soundchecks earplugs',
#  'squink oh yay means ill get soon & gt_ & gt never used suffer year gets worse',
#  'cutting grass dad hayfever',
#  'xbox died stress relief depressing middle moving new apartment ugh someone cheer',
#  'arrrrrrgh havent saved file',
#  'oh babysitting love springs morning cant object',
#  's_eisbaer face',
#  'groat feels like getting sore',
#  'flat iron melted glasses',
#  'unlock espresso',
#  'yawn got getting ready school',
#  'got home school long day school today',
#  'preparing quotes day tiring job',
#  'emmabush well didnt mention stale peeps',
#  'j_e_p',
#  'im feeling ecstatic met james matthews josh wilkinson got james towel xd maan ears still ringing throat hurts',
#  'mileycyrus god blizzard',
#  'shame processing pics isnt much fun actually taking',
#  'pm asked teacher speak project said noo happy might spewed',
#  'finally back track studio lost cubase dongle miami',
#  'spring time http//twitpiccom/yagh',
#  'car sucks bad week get car taken away',
#  'binxy thanks started sniffling like crazy gym today boohoo lots vitamin c trick',
#  'sheamus chance switch bitly tiny url cant read links work bitly gets stopped malicious',
#  'amazingphoebe guess / ima still hell fucked nights regardless guess',
#  'back school papers',
#  'gahhh twitter app fails',
#  'early school ugh',
#  'know dont people put lack spelling ability looked couple posts messed word',
#  'tessaschraven sure would work fly west want though',
#  'silverwind aw sucks',
#  'trip castle turned mile round trip kids sick back car',
#  'jutecht btwloved baseball postthis definitely best time yearwas disappointed red sox opener rained',
#  'http//twitpiccom/yb - eggies sister parents im sure im gon na get back',
#  'smart start + = chipped tooth',
#  'hello tweetershavent much latelytoo busy hope well',
#  'watchin candy girlswhy cant b videosux dey mainly use american girls',
#  'procrastinator perfectionist terrible combination university',
#  'joanneskywalker really depressing teases working fine try save people created hell ahh',
#  'im wearing black socks =o haha pretty random im bored tired nigel',
#  'davtoole cant bring watch film sheffield united',
#  'sitting jury duty',
#  'im un-realisticly gutted cant go download year see papa roach',
#  'sydney rail advertising http//twitpiccom/ybkw graduate programs railways first choice alas ended fashion',
#  'blehdidnt wake time leave work early chiropractor',
#  'work late night watching game state lost',
#  'tigger lost bounce',
#  'animatic project done got positive result write page report days gon na fun',
#  'ive thinking getting blackberry iphone something sucks year contracts',
#  'waiting go dentist wondering flippin cold gon na go feel poorly',
#  'donniewahlberg word street & quotface time & quot worth individual pics rush rush rush',
#  'kdfw girl suitcase story messed cant imagine anyone something like',
#  'schedules messed gaaak many deadlines looming horizon',
#  'see snow outside im sick ohios weather years till move palm springs camissing weather',
#  'fave hairdresser still isnt back hope dont get rubbishy cut friday somanydeadends & gt_ & lt',
#  'ugh dont feel good morning hope goes away',
#  'one bunnies died today wasnt fault wasnt fault',
#  'buttload worki wish people hated cars',
#  'im miss dad',
#  'happy birthday rrdad bad also travelling today',
#  'im going lose followers one tweet lol',
#  'lovely avacado bacon chicken baguette - time work',
#  'honkpeace never received dms last night twitter hacking lung something',
#  'rockinrita plans fell meet',
#  'woke upanother hour shift today started pally last nightshe kicks butt',
#  'throat killing',
#  'still center lincoln wandering aimlessly round shops wish cud think something iphone running slow',
#  'twitter wound',
#  'fever cold cough sunburn',
#  'rotting_orange im sorry job going away',
#  'ababyblueeyes yea call stress',
#  'work',
#  'tired get ready school',
#  'val dor waiting wife youngests flight leave long drive chisasibi',
#  'looks like going nice day lynchburg today bad im sitting class right',
#  'research report due five library trying get finished',
#  'hot outside ice cream time whats catch bees annoying',
#  'lauraechilds enjoying far far much',
#  'noxhanti almost quite uncanniness rampant luddism might put paid replicants theyre even built',
#  'got go sux cant text cant text am-pm ill text people later today may blogtv sure',
#  'uughhhh back work help please',
#  'rewy looking like',
#  'looking forward writing - word essay history next week stupid exam essay worth im scared',
#  'bebosore tummy',
#  'good big headache dont feel well',
#  'michellev ok hope make',
#  'feeling good morning im hungover lol takes two glasses wine',
#  'babysittin stupid lil sister wen actually shud friends enjoyin weather think im jokin',
#  'english bummer',
#  'really miss & quotreal & quot college def vibe hair school',
#  'ok get serious im poking nose trying find green cant find none',
#  'missnappyboy sucks havent outside yet love cold inside outside',
#  'headache still splitting head open th day row',
#  'day two training tech doesnt even know ctrl-c hes probably lasting',
#  'charmer said aint ready yet asthma beign cautious',
#  'nohorob ack goddammit denton get good defect best alliance something',
#  'woke late today hour lol school ready portfolio',
#  'kio_redsen people like work weekends though wednesdays good',
#  'started rain naw wales',
#  'sony ericsson w something seriously wrong decide want send texts time dont want',
#  'jason_nott http//twitpiccom/ybib - sorry bad weather hate hope still good time ohio',
#  'often feel like im going panic attack register classes',
#  'consumed nothing feel im everything im lost twisted paths made',
#  'think spring pink slipped',
#  'truck went shop denver leaking radiator fluid student prolly gon na stick thru likee da lifestyle',
#  'thinks going watch wall-e tonight since nothing else',
#  'jonathan_hlibka late insulted construction worker gave attitude walking wrong direction queen/yonge',
#  'guess wasnt meant happen',
#  'squarenails yep yep certainly child-friendly hk wide pavements tricky maneuvers strollers air gd',
#  'got th longest trip back train ever london tired',
#  'havent home since xmas break lm lil homesick faithhopelove',
#  'money hid golden square long gone',
#  'school need get zone game livermore today',
#  'adders -have asked bitly inaccessible im unable read articles readers tweeting',
#  'thinking hate yankees - dont im yankees fan losing orioles less',
#  'gets take math classes computer science class education class next semester',
#  'sleepy boy starts dont agree',
#  'time day got back time tired skint good news bank may watch another zombie film',
#  'royalbluestuey haha little scared public stage eh love like travel dont get chance often',
#  'mege hows beach retreat wanted go mi madre said',
#  'sparkledonkey second started posting moving subscriber section thought guys',
#  'wickedtrue boo work unrelated news get highly-paid roommate contact sent email last week response',
#  'im getting really lazy twitter updating',
#  'rock fore dough tonight & amp im missing cant wait til friday ill actually augusta ps - happy birthday eve laurob',
#  'somebody go give dad hug feel like hes grumpy days',
#  'kids still little sick im getting going light school today get lots rest',
#  'feel worn tuesday',
#  'chin-ups dont know another set',
#  'http//twitpiccom/yii - q key broke',
#  'average industry ï¿½nilla porno doesnï¿½t even start around coffee table anymoreï¿½ hell',
#  'ive bed since saturday tuesday',
#  'cigerates petrol c bollix petrol dont care cigs',
#  'getting ready work blah tuesdays suck hope ur tuesdays better',
#  'mardhiah read ohnotheydidntlivejournal sure true ill sad',
#  'hope reach home ajeesh sings super singer missed ydays episode heard sang really well',
#  'light cold hoping go away soon worried instead become heavy cold',
#  'sitting morning class crashing fast hate',
#  'looooooooooong day home chillaxin shane',
#  'slept months body always making get whyyyyyyyyy',
#  'want touch heiney',
#  'hate make joke one laughs feel funny',
#  'cant veda video today cause flipcam batteries',
#  'loooooooooong day work today home chillaxin',
#  'mï¿½nh chng mun ngh n vic chng ly / nï¿½y http//afamilychannelvnnet/tmca/phim-hay-vtv-co-dau-chay-tron',
#  'wickeddisney lol loves us wonder shes going europe',
#  'soooo feeling good suckss',
#  'im lonely keep company female decatur - alabama',
#  'homework',
#  'lyokamoto hey girly left sunset wish got updates phonebut lets hangout one days',
#  'kayleighs service tomorrow ugh text morning miss bestfrannnnnnnn & lt',
#  '_kelli sure im thankful much research horizon bottom cows sunnysideraleys wholefoods cows',
#  'way airport saying bye kids soooo hard',
#  'thinking practicing posing routine worried im body oil',
#  'lmao dont get twitter stuff going work soon love savannah',
#  'wish could make work disappear snap fingers',
#  'eerland something air edy woke bit ago wimpering sleep go soothe quietly cried',
#  'aww one lil chicks yawned going home tomorrow',
#  'im lonely keep company female duluth - minnesota',
#  'coachdeb loving randomfacts tell us - cant dm - dms broken twitter weeks see cant send',
#  'way lakeview really sad couldnt make ifightdragons concert',
#  'iamjulito tatauc im smut know',
#  'im really mood rp everyone dies',
#  'brookandthecity cant wait miss yal soo much',
#  'woverton ive couple days hope hours',
#  'officialashleyg heath ledger rip',
#  'watching larry king live cable went booohoooo',
#  'ahhh celebrating success week found new suppliers must-have items old suppliers quit supplying',
#  'mcrmuffin thanks always need talk',
#  'woke pm philippines hot im sweating hell',
#  'wont go back kfc kfc failed ordered usual fave guy suggested & quotspecial & quot instead yum',
#  'day looking something new wear birthday next week absolutley luck',
#  'didnt well id hoped earthday footprint quiz http//earthdaynet/footprint/flashhtml - earths',
#  'edward cullen bï¿½la lugosi spinning grave',
#  'ate bean cheese dip tacos dinner sleeping next steve stinky',
#  'winkler tomo get',
#  'yankee doodle went town ridin aww miss wild n',
#  'cant keep girl im sorry',
#  'still sick feeling weak cant enjoy beautiful spring weather',
#  'boyfriend decided depress putting paradise lost',
#  'shithole awesomelife guess night crapper',
#  'mackenziefox sun doesnt wan na come today',
#  'hoping next weeks go fast left & amp already miss',
#  'sigh csk youre screwed',
#  'sometimes wonder money goes',
#  'really want go thunder today dog going crazy cant leave day long & quotm boooooored',
#  'dandy_sephy close friends family im afraid im work colleague',
#  'nawong go getting access idzrorg im dying try',
#  'bummercant get see bf sing ernie els gig guess dog pockles tonight',
#  'crapi think ive caught wifeys virus',
#  'sunny day today yay = ] still cold',
#  'expect chen super kings wud start dis season wit loss cmon ms',
#  'misscasey bummer',
#  'received least phone calls today already telemarketers',
#  'daughter isnt starting day right tried prom dress & amp doesnt fit gained little weight',
#  'custardcuppcake hand clapping usual reaction dancing',
#  'nooooo one day holiday left still much work',
#  'getting ready work next days move im missing baby much',
#  'neti pot following directions = massive sinus pain congestion yesterday drainage/bronchial cough today',
#  'ugghhwhy awake',
#  'hungover hurting real bad',
#  'gunkanator ugh horse sight well one thats mine least neighbors frown stealth riding',
#  'feel like crap',
#  'uncle grandma car crash uncle going jail dui hit run',
#  'cant sleep anymore ugh',
#  'red ant bites really smart',
#  'gg - morning - warned - mikeyy back - careful - one ppl following infected',
#  'thatï¿½s call & quotsuboptimal & quot sat night going friend study exam till fall asleep somebody please cheer',
#  'caved',
#  'djedub dats wasup u bein mean talkin cares mean',
#  'scottmonty wishing official sxsemia ford car stuck crappy dodge charger rental',
#  'shit im sick',
#  'hollywills come north see us',
#  'sisky yeeee \\o/ work mins waahhhhh',
#  'today crap drawing day dont want one done day horrific gets worse every day boring',
#  'http//picim/q - sunset iphone',
#  'skimud sorry upside weather says snow day today georgetown co clear tomorrow & amp partly cloudyhave good day',
#  'markbrooke im sorry mark shoots today luck',
#  'mcunclebuck sad hope u feel better',
#  'want relax',
#  'brianmckinney bunch good places mass blocks im looking im stuck lease august',
#  'reedoh lol team already played lost da week x nice chill got busy day moro making da xx',
#  'best figure tweet trying upload photo',
#  'briggysmalls - wont able make got stuck running around pint ill see monday go gunners',
#  'wants go downtown take photosbut one hang',
#  'see u later - time move work dont smart phone carry around send tweets run',
#  'kcinwpb depressing im ok morning',
#  'plaintruthiness first final days',
#  'coachyeomans yes',
#  'trying trim big laptop use least amount power still look ac soon',
#  'stonedsteve alas live connection moment pc got sick landline dell mini needs sorting',
#  'officialtila well sucks im near la',
#  'massive lag times wow lame',
#  'richelle feeling well staying home tend wifemissing barcamp orlando today',
#  'im missing friends & amp instead watching dora explorer - prefered mickey mouse',
#  'melaniengzuer - exactly could',
#  'petewentz guys better play tonight dont want stand rain nothing',
#  'last day freedom going back jail tomorrow hahaha aka school',
#  'first saw ingeous pouncer immediately thought demonic apprentice one made cant fit',
#  'nath_girl haha im brazil cant speak spanish sorry',
#  'soo sick revision sucks',
#  'reverendvince great show last night got late see fuckin lights bright',
#  'sherrieshepherd hi sherri love daughter diabetes shes almost love said someone needing today',
#  'tinkugallery hey amrita dont think ill get see today sigh',
#  'donniewahlberg im sick im chilling happy',
#  'laying bed ill wishing hot nurse girlfriend would come make better',
#  'justsara great daughter trying figure college go photography looking boston far away',
#  'angiekramer oh english beat really bad wanted go couldnt',
#  'ate last mini egg watched stickin around first time + years',
#  'owowow breaking boxes got hit eye rogue piece glue',
#  'hates bank able get tuesday broke effing weekend',
#  'record store day bad dying breed days miss blue dogs',
#  'anyone wan na get monday walk almost miles anyone bueller',
#  'ecu -- plex gone',
#  'yay saturday stereo died something car got ta rip dash',
#  'mussomitchel sudburys never gon na win',
#  'ugh look like mental patient grandma gon na find im play',
#  'poor roomate sick boobs leaking gross',
#  'paulacxx live fanfiction',
#  'nice weather finally blesses us dc - starts raining tomorrow',
#  'cassiefx look good scratch sniff internet',
#  'getting ready go work soon',
#  'time kingdom hearts play frm beggining roxas memory card',
#  'inmykitchen nah bro need em asap thothe maybach music floating sumwhere tho',
#  'sebby_peek okay goodnight love much xxxx im sorry',
#  'has_bookpushers im freaking depressed knew would happen still',
#  'ah well back grind',
#  'woke started day dropping crackberry',
#  'srptchkd hey steph texted morning said would picking around',
#  'storming dont like',
#  'tessdejong bad bday party hehe',
#  'damn man really wanted damn funnel cake',
#  'sore throat really bad head cold hench bruise blood test',
#  'feels alone friends twitter et miley cyrus doesnt answer',
#  'heebiegjbies missed bowling fam wish still',
#  'confused cs homework',
#  'sad know arsenal lost chelsea fa cup',
#  'word wise never buy porno gas-station liquor store chicks probabl covered giant moles ruins purpose',
#  'desert + running == death hmm seem forgotten little fact',
#  'stoopid-i spilt bit bleach pink top small white patch',
#  'video audio nothingggg n nooooooo asot',
#  'people forsaken icq makes sad pants',
#  'rawrbeccah come',
#  'missyuu guess \\',
#  'less week month town begins',
#  'phillprice currently got mk golf & amp love wanted mk small family got new mazda coming monday',
#  'hansonmusic wish fan event tulsa college graduation miss guys',
#  'leannenufc oh still quite early mebbies things flow better later lol worry moment xd',
#  'early',
#  'theres fox garden hide',
#  'booshface lol cooper cooped ] hate things though call jenny long legs xd idea',
#  'bdiflip yep doesnt',
#  'im always hanging boysand feeling left',
#  'thinks shes done something isnt quite sure oh need',
#  'think milk bad',
#  'terrible daughter',
#  'work',
#  'craving pinkberry right cant get fix',
#  'nathanfillion & amp morena orlando panel - pm one upping con prank war plan late',
#  'feel sick stomach ick',
#  'hawaii & amp woke love saturdayseven though work hours least get monday',
#  'exam done hopefully passed maybe marks curved stressful lame',
#  'saw old house first time long time beautiful theyve done ton miss',
#  'exam time',
#  'ok seems working - comp one midlife crises seems everytime quiz',
#  'campus pc lab dont photoshop',
#  'bed got ta early work night night sexuals lol xx',
#  'home alone lonely',
#  'leapylees oh ill check tescos theyre much closer scotmid yummy treats make us gain weight',
#  'im lonely keep company female cincinnati - ohio',
#  'hope show doesnt move fridays tho whats gon na telly saturdays',
#  'watching brothers game losing',
#  'someone got disqualified sending multiple entries',
#  'whered mr pepper dude go via zenjar',
#  'way back conference - amazing sorry everyone couldnt come',
#  'work',
#  'lonemat yes months ago',
#  'pm think im going bed got work tomorrow',
#  'princessq confiscated bottle',
#  'hurt crap finger playing football boys soo swollen hurts',
#  'watching film visitor feeling depressed',
#  'actually hot outside http//mylocme/op',
#  'suppose go camping weekend bad weather changed plans',
#  'need homework school starts monday oh well still need iwill godly day sunday church',
#  'emilysmoomoo shame schofe didnt say hi side studio shall go visit soon',
#  'bientï¿½t dï¿½collage vacances bye bye twitterï¿½',
#  'lectrickrainbow ended babysit',
#  'finally heading party emergency vehicles arrived kroger took stretcher',
#  'oceanuptwitt would enter cant',
#  'call grandparents time',
#  'raining toois raining everywhereim sorry kids houston really sucks',
#  'elevenution yeah supposed clean room never',
#  'swear didnt matter id move today fed might cable and/or food til get jobreal talk',
#  'watching breakfast club missing/thinking katie & lt xoxo',
#  'stupid caffine headache hate addiction grrrr',
#  'lose followers time haha',
#  'mii mni huge headache',
#  'laying bed watching favorite showwhose wedding anyway guess good gon na get',
#  'asked abercrombie model',
#  'charley_farley im kind love hathaway mum understand want see hope make',
#  'yer hgistory presetnation',
#  'exhausted long day babysitting',
#  'think like trim virl shorter http//trim/jiq',
#  'wants access virus ti theyre like grand',
#  'argh geek makes cry inside - uncle runs windows whenever camera card full buys another',
#  'im lonely keep company female cincinnati - ohio',
#  'andy roddick got married',
#  'damn celtics chokin bulls keep playing like cavs title lose',
#  'ive many probs w/ twitter app week finally seems back normal well see',
#  'tried setting twitter phone failed',
#  'mulatta emotional reaction severus looked conflicted omg couldnt hold',
#  'elderly im terrified becoming dont mind healthy young elderly people absolute fear & amp cant quit',
#  'men freakin suckkkkkkkk',
#  'heh im glad mood went shit need cassandra',
#  'xtashax miss u woo woo',
#  'unpacking really sucksand homework already',
#  'back killing',
#  'csantopietro medical student weekends study',
#  'nathanfillion bad im canada dont hbave b+ns',
#  'bonnie oh havent able read yet lotsa email dms today kinda shocked opened bo',
#  'dont know lay night go fun really need stay detox god sounds boring',
#  'hurts poor thumb',
#  'skdickey im bummed cant ride bike new wheels show tuesday',
#  'marcushazzard ugh homework ive got money wish could go dancing tonight',
#  'jmk brandon doesnt want toooooo',
#  'time make ends meet somebody move ends',
#  'depressing empty tic tax box',
#  'leaving beach got nice pictures sadly wasnt inspired enough draw anything',
#  'really needs sort insomnia crap still wide awake',
#  'beat two year olds tomorrow denver wont kick ass even harder beers backyard option',
#  'lukeaddis wow filled whole page aplusk twitter king im go searching tweets',
#  'much pain back fucked dont know happen feels like something place lower back',
#  'greenmonsterpoo little bee miss youuu',
#  'crash shut sh go back way via mangawhai',
#  'bechyy miss online weird seeing online hehehe',
#  'rch_l lol pitty points ftw dont always help though',
#  'want macbook taking suggestions name',
#  'well good night followers wish',
#  'teearnstack conshence think wouldnt know either xd goes dictionary conscience aw dont want die',
#  'fuck birthday',
#  'maryalmighty',
#  'thinking great day cleveland sports precious browns left sad fb',
#  'mariajessica ahhh jess still revisions thesis bound till tuesday cant lazy',
#  'missing baby girl',
#  'bit tongue',
#  'kataylor wish could go going cruise hope fun enough',
#  'wish friends twitter',
#  'time go fold laundry mentioned much hate laundry well anyone got laundry fairy spare',
#  'paurubio ruins others tweet u',
#  'ripped new tank trying take tag offawesome goodnight',
#  'samatic ha ha damn fun without',
#  'tonylui oh sorry late response got hit car',
#  'anyelday ooops bug fixed try tiny url',
#  'thinking drive nashville',
#  'really crusty feet ah awoken yet loud drunks even summer love shore',
#  'bdhorse im nawt stopped sitting like minutes ago',
#  'shinydirt dude bf went said hot got dirty confused look disappointing lol ff still rocked',
#  'needs twitter tutorial',
#  'im sooooooo sad watching week b lasts american chopper like jr think sr serious fucking issues',
#  'wax - epilate ive waxing lower legs diy recently -scrutinise- see ingrowns',
#  'trying write song freakin insanely hard',
#  'bananawong hobing ah joeys cat lost two beloved cats less year',
#  'ecosaveology sorry missed today let know and/or ed come oklahoma texas ed amazing',
#  'trying figure heck going dont understand site wont let upload picture',
#  'msprettynsweet messin essay papers huh lol good luck didnt hang lol',
#  'cmellmer long twitter',
#  '_angeliina ouch glad ya didnt =d otherwise poor kevy would awful lonely lol',
#  'mslujan fair w/e night',
#  'sad broke nail bowling',
#  'bout go bed without baebe good time tonight',
#  'frankie nonnas really want',
#  'going books getting ready school tomoz',
#  'sarahdope need dibs',
#  'liz_perez sad first ever playoff experience straight whoopin',
#  'one worst moods ever',
#  'srslylily cold',
#  'pana send message wont read anyway',
#  'got done watching saddest movie - boy striped pajamas',
#  'disappointing game rose garden tonight blazers',
#  'headache',
#  'pinkberry sara wallowing self pitty',
#  'saw marley sad cried',
#  'bored',
#  'hate laptop hours go email slow hardlly ever turn tweetdeck itunes visit blogs anymore b/c',
#  'rode much today got blisters palms need better gloves',
#  'listening saturate tears miss dad',
#  'omg feel like jerk great guy think craigby',
#  'wants find good guy',
#  'elikapeka sad car accident careful',
#  'damn thumb throbbing forgot give perscription pain meds counter stuff dont cut',
#  'moriahsallis dont want move come see',
#  'sfltv yeah screen over-nighted itll monday sunday delivery ticket replacement phone new monit',
#  'didnt get much sleep last ngiht fire trucks',
#  'playing guitar hero ps im noob',
#  'cant sleep david isnt raining thundering',
#  'going sleep b/c feels really sick',
#  'disappointed sound quality educamp - especially recordings',
#  'brian_g think could wait urgent care want save dollars doesnt sound fun hang er',
#  'callin niteboring & lt -- -- lol sometimes thats u got kids',
#  'shrek well option thtjust tht st cell n gift bro boot plus tht damn thing cost k back',
#  'im lonely',
#  'ever thought laying bed would darn boring want go somewhere',
#  'oh noes found cons skate shoes hard find financial issues bought nike',
#  'sivereaf man fixing good sorry hear wife',
#  'something road killed truck almost florida http//twitpiccom/ljr',
#  'worst headache lying bed day lazy',
#  'worst headache ever',
#  'ok time head home sad leave dancing knee really hurts sleeping tomorrow',
#  'says kinda miss long hair http//plurkcom/p/oxx',
#  'boring game fun',
#  'silly govt grant havent paid yet',
#  'back huuuurts happy never move xx',
#  'lose followers less hours im back single digits kinda bums',
#  'go job',
#  'wan na go home',
#  'short hairi hate',
#  'krystleperez tried test wpm wouldnt let without installing application',
#  'oregonjen whole post con blues things really sucks others say gets worse go',
#  'kimkardashian looks like hurts ive never sunburn =x armenians shouldnt burn lol',
#  'lost money tonight support local bartender',
#  'nicolerichie funnybut theres happy ending',
#  'adthrelfall fork redmine sa plugins word warning cant raise authors accept pull requests',
#  'empressericka oh well tried',
#  'dennis im sorry human bad game bad really bad familiar games right',
#  'ashlynicole happens phone got cut ya',
#  'sch start tmr',
#  'tomm_j haha video soo sick want',
#  'guess get get wake early tomorrow yardwork yay',
#  'leaving trollstigen heading towards bjorli super-dissapointed trollstigen spectacular http//twitpiccom/ldv',
#  'got home already want go back & lt off-roading',
#  'madeline_cole sorry bout hun',
#  'majornelson wow good deal xbox bad stock',
#  'kings men rule \\/ pray pray',
#  'twimailer twitter says twimailer email isnt working anymore cant see easy way fix ur site',
#  'maharishi_velle bcus kid bedbugson couch & amp say im itchy & amp rush get home & amp take freakin shower',
#  'still alone',
#  'btw dont live country suburbia hell theres sense community',
#  'beethousand call got dropped',
#  'swedishjoe would love traveling throughout may',
#  'want listen point',
#  'roombreathe eitherand doesnt last long kinda sucks weather nice',
#  'brawl let guys ahaha go adam hunter',
#  'sushirockstar blogtv sucking computer boo',
#  'cant believe almost time brother move chile',
#  'legonz guy snuck didnt get invite hope freegin great time',
#  'pinkberrygirl nothing really / hour shift work today boo iam dead zone ill tweetless',
#  'davedays actually rained day today live kinda suckedlol',
#  'xxmarypoppinsxx well yeah',
#  'jonathanrknight hope feeling better jon looking forward going cruise soooo wish going xx',
#  'cant sleep stupid bus',
#  'really easy park stuck hopelessly one lane pile hasnt shown signs movement minutes',
#  'jonathanrknight would uk need full service give us shout til morninxx',
#  'cant find sister twitter makes harder stalk',
#  'want talk love night looks like im going get',
#  'didnt go coachella live middle nowhere fml',
#  'twitter temporarily disable editing whos tweets go mobile currently neither turn specific ppl',
#  'im going cry',
#  'oh well back work tomorrow',
#  'fiancees mother taken ill heading upto birmingham see family least fri',
#  'mariahcarey ouch sore tooth fun',
#  'iamdiddy got home trying im locked',
#  'cookiemonster thankfully todaybut work tomorrow hoping rain dead wipers/',
#  'arifgan arifgan except last part',
#  'jessicastrust problemo u might wan na tell pembrokedave u said im nice hes horrid & amp dean_cummings im always nice',
#  'trying avoid getting delay evil blood tests today dont want go either',
#  'remainamystery hope gets fixed soon',
#  'face numb lol pittsburg ca http//looptus/myqkat',
#  'rain today first cricket game season',
#  'joelmadden soo wanted see movie love jennifer aniston refuse watch know dies',
#  'viva_la_sue_sue u hurt right',
#  'want third day weekend',
#  'homework',
#  'im back guys laying hotel soooooo excited many things havent heard sweetface -',
#  'local oxfam trendy window display shocker cyberman helmet paired manequin wearing dress sign doctor though',
#  'ood + snapper tarakihi kingfish porae marlin',
#  'robertbrook youre getting abit today im going take river wander - dreaded gym',
#  'talieshablackie nup',
#  'ddlovato germany toobaumholder never seen celebrity concert cept lil jon',
#  'restless sunday night',
#  'morning people last day holiday today back work tmrw hr shift',
#  'really enjoyed last night truely sorry giving mel cold',
#  'bradiewebbstack aww poor bradie u walk',
#  'damn thought successfully ousted cat came home',
#  'beer pizza krispy kremes anna pretty fun way end melbourne sad go home',
#  'biological clocks messed still cant sleep',
#  'im awake going get ready back school monday',
#  'rossbreadmore sounds like fun sunshine following ali_bubblegate ali_mosaic',
#  'waahh im home & amp im sick',
#  'skinhead & lt many small place nearlly jizzed missin cheffy though',
#  'jonnypaula oh dear youve started auto-facebook-updating-via-twitter already',
#  'oh ffs get rid desktop tool dock vista good please anyone know hate',
#  'yes governor corzine',
#  'drugs arent bad miss well anyways talkin bout icebreaker xbox live u need new mic nd quick',
#  'bw know right ever since released ive wanting perform end jeesh',
#  'sunny day back work tomorrow',
#  'scott_amh yes says wp database doesnt exist',
#  'eating final easter egg & lt/ business nall great stuff',
#  'grrr cant center div safari reason using width em margin auto works fine ff aligns left safari',
#  'courty yer know woke like noo dream wasnt real',
#  'dollyparton whataburger well eni claudia night ima think idea u',
#  'im shattered sister kept couldnt sleep hours',
#  'contemplating',
#  'far gutted / wardrobe next bedside table bed argh old desk',
#  'ive updated couple wordpress sites bummer see need build k theme scratch damn',
#  'theellenshow ellen watched show ages agree views gay rights tonight proof bad',
#  'cant sleep stomach hurts',
#  'got home church tomorrow would last day easter break',
#  'today sorta bummy club didnt work king taco bomb im back home ready sleeeeeep',
#  'im going start playing wow',
#  'hmm thought daddy giving milk think im seeing double get rid hickups http//twitpiccom/lpb',
#  'lovelies sorry absence woke flu-ey symptons still got im bit subdued still smiling -',
#  'raining grrrr ipl',
#  'xxhale ahaa get family mehmets family maybe going florida miami want go la & lt',
#  'omygosh end holidays maths exam tomorrow / billion othes week- okay six stilll ahh',
#  'chaitee new business idea spandex fatties many business ideas',
#  'miss bff mandy way nyc',
#  'start term',
#  'shift b two hourscant wait go home & amp spend time w/ guysb turn around & amp b right back',
#  'ssedro submerged let dry like week might suggest hairdryer waters hd buh bye',
#  'bruno ohhh much ohh feel terrible',
#  'doin graphics work aaaaaaaaaaaages x',
#  'moved couch cause boo said snoring',
#  'back work feel ill',
#  'mattk_au wow nice effort im stuck wastelands -k need find avatar rental somewhere',
#  'erlang recommendations engine making good use cores damn disk cant keep need ram damn',
#  'filipinowise see quite busy work top caught bad ass cold week studio yet',
#  'sweltering im irritated friends cancelling last minute biometric passport tmr wooo',
#  'ahj speculation press today chris considering leaving hes dumped',
#  'hilariouscow yeah got hands documentation pretty interesting boring want radians back',
#  'says nakakapanlumoshouldve printed chance http//plurkcom/p/ozg',
#  'shotdown would even care updates never',
#  'back school tomorrow',
#  'fair_awesome dont though',
#  'samantharonson thx sam went checked sad',
#  'early sunday morning twins still sick fever days criminal looks like ear infections',
#  'eileenmarshall need friend ill vilnius thank kobe im getting moscow soon',
#  'amazingphoebe thats want believe guest',
#  'amazingphoebe youre right doesnt matter',
#  'report media regulators bffc done next asa pcc dreaded ofcom theplus side im listening fatboy slim',
#  'famouslyalone wish jen coming',
#  'bored silly think hav cold - bored sillyand think hav cold',
#  'miss cosplay sooo much',
#  'maryjanesuckaz really',
#  'disappointed damn getting hopes',
#  'pseudrandom sweeping garden = sweeping garden sadly [ didnt know meant something else ] hehe',
#  'painfully dull experience nearly new pc n running probsitunes bad times speedy fecker quiet good times',
#  'birthday cake gone good good',
#  'great weekend birthday went bang lol back college mro',
#  'raining paradise',
#  'nose done really hurting ouch',
#  'looks like wet ride home - day',
#  'vicodin_martini jealous get watch tv',
#  'babybeech oh trying comment report status ages ago haha also tempted sun xxx',
#  'therescue want go manchester uk cant go leeds',
#  'djknucklehead',
#  'hunnybunnyxjs youre either',
#  'lenedgerly hub says buying one xmas tried audible books fell asleep airplanes lost place',
#  'bringing baby drs today -yuck- poor little dude im hoping allergies beginnings something serious',
#  'allenhortaleza food tech today',
#  'sconefiend missin alla yall go bed & quotbrunch & quot later',
#  'sweet_candii smashed pancakes',
#  'booooo cant see photos reason glad hear nagas good time miss u',
#  'back school tomorrow',
#  'miss erica way used hang sad realizations come night',
#  'happy - drinking pint tea cos dont coffee left',
#  'tomorrow back school',
#  'ohmydaysitshayz ahahha maths test tomorrow swimming',
#  'franky_fingers home b next one though promise hope u cleaned seat u put ur feet one inch x',
#  'honeybeemine missed sytycd dance event afternoon evening',
#  'cat looking bereft take away food getting teeth checked tomorrow morning anesthetic sad kitty',
#  'sebby_peek understand',
#  'im still & amp sleep',
#  '_brian_johnson & quoteveryone become great & quot one still isnt working rest work fine',
#  'bombtwinz carpenters making repairs couldnt leave alone',
#  'suffering gastric acid since saturday morninghuhuhu help',
#  'wishing could go see tai today',
#  'feel like lost best friend',
#  'back school tomorrow got lot homework',
#  'wish houston houston_dynamo game instead work',
#  'sorting high schools yo nerve wracking stuff dont want get wrong',
#  'wan na watching milan v torino tv occupied others',
#  'fsuamanda kind syrup folgers morning sun mine',
#  'good couldnt help check result sharks v crusaders game',
#  'doorsdownrock thanks guys - sorry miss show mohegan',
#  'work crazy busy today rns patients pts r conrol & amp someone pass away god bless',
#  'miserableatleast tempwent much enjoying weekend',
#  'brookeelyse officially finished life meaning anymore one single thing look forward',
#  'awake project really vivid dream thought real',
#  'belladonna youre im patio theres music & ltgrin & gt got ta yardwork soon',
#  'last day',
#  'andrea home bored got college tommorow bad times bad times',
#  'paper please write yoself best intentions starting somehow devolve simply getting',
#  'dont want wake',
#  'bored waiting pee wee pictures san antonio posted',
#  'drinking coffee perfect time',
#  'ew karen dillards',
#  'studying chemistry got pg three days including chapters reading material workbook',
#  'maybe cutting ties best thingso sad tho miss',
#  'wallace_reid mine gone text-only completely unusable im go ffox',
#  'nikkibenz still waiting hope got',
#  'meshmeshere thank u hope get time',
#  'jradc day hell work ended badly started whole hours went',
#  'back skaterhockey crazy old bears _chiefs reloaded goals us last mins',
#  'licensed drive',
#  'sun burnt & amp hurts helping kayla party thing',
#  'drpants going lots sad people today',
#  'sniffly nose',
#  'cleaning battery acid holga',
#  'sireuan',
#  'realized left wallet llano',
#  'back uni tomorrow cbaaaa',
#  'want go resevoir',
#  'dylanjobe starhawk please',
#  'christamacphee sick lot',
#  'im listening fuck first time agessssss - sarahwhere r u sing along',
#  'enjoy night crammingï¿½',
#  'wow chaneles nephew passed away yesterday part drive got shot times reason still came work',
#  'sigh stitching yet bad day',
#  'neck herts',
#  'tottenham - newcastle ouch newcastle looking good drop',
#  'im trying figure twitter thing works',
#  'want write history paper',
#  'merrrrgi got nothing',
#  'kwill cant write jfs wall fb wan na know name girl michael kluthe salon u know',
#  'wan na go home',
#  'going bridal shower today looks like going rain',
#  'morningglory cant say didnt try',
#  'oh almost monday',
#  'homework',
#  'sad leave dayton',
#  'last day going back work',
#  'patientzeroband thanx u im bad day today',
#  'work -',
#  'getting packedoff texas week bad work',
#  'alwaysmommy im jealous raining gloomy stay indoors',
#  'klutz like themwhich means gon na much new moon',
#  'aanaravs cool wish netflix',
#  'hollymcombs hi ths really holly great actress miss charmed please write back xxx',
#  'mannnn dad wants cut grass darn lol',
#  'warmth sun returned transplanting strawberries today may story show lost daphne winter',
#  'upset cant find pair sexy cut-out sandal boots anywhere',
#  'college visit',
#  'vanillurve dun miss us',
#  'jamiev way cant go holiday',
#  'raining',
#  'joannadelilah need lose lot started gaining went back birth control yrs ago',
#  'woa listend jennette mccurdy sing acoustic guitar wow shes amazing jezz wish could sing',
#  'awww last day spring break',
#  'confusing game chatter twitter',
#  'lyndseylouwho wish known sooner could come honey',
#  'hannahmtew',
#  'cba school morra',
#  'johncow yeah hate things sorry get auto-dm cant hit un-follow button fast enough',
#  'got exam timetable exams day',
#  'nathanreid ya sucks stress gf turn stress relationship',
#  'feel like death warmed pretty sure im getting bed today',
#  'ugh work http//twitpiccom/llt',
#  'jasmineoh lucky ive studying like hours',
#  'stupid allergies headaches',
#  'livejournal seems cant distracted editing essay back mm',
#  'crappy dayrain much homework constantly let people',
#  'bjstone im going see againlol im going girls floor last time something group',
#  'oh good mom back bed hour minutes tears welling eyes',
#  'last day experiments cinemahow sad',
#  'still waiting goal man u',
#  'boknowsshoes guess ill make lol',
#  'waiting get told clean & ampwatching american idol thing gabbis sleeping',
#  'miss home church tho infinity ny church bronx also bronx community baptist church bronx ill back soon',
#  'ben_hall sorry meant ex gf better u keep secret',
#  'rockbigdave charge mine practically daily',
#  'im missing bananas myy pancakes still gon hit spot regardless im trippin ] holla',
#  'omghe killed cries sooo latewith house episodes',
#  'doesnt want go bac toronto today',
#  'tanto stockholm friends today great time im extremely tired easter breaks tomorrow',
#  'gud mornin gotz stomach acherz',
#  'jeremya bummerthats worst way whole life',
#  'orange county sad going back bay area work tomorow love dinsey oc',
#  'day grand internet outage',
#  'wish followers',
#  '[ -o ] sitting atlanta airport waiting flight orlando-wish going disneyworld http//tinyurlcom/dyanlp',
#  'wants see maddie',
#  'dreary outside',
#  'goodbye disneyland going melrose',
#  'bad hair day',
#  'rainy day',
#  'misses rob something cronic left two mins ago',
#  'violently throwing kinda freaked since didnt even go last night one sip alcohol',
#  'solangeknowles wish could wont chicago tonight',
#  'librarybad times',
#  'way home swans another sad goodbye get home family spring break',
#  'soooooo grouchy tonight wearing ring ither',
#  'hoping mini golf tonight please dont rain',
#  'audubon center sanctuarywalkin trails feel better ashton kutcher',
#  'im hungry dont know eat',
#  'new amp shows cancelled wait use',
#  'amaditalks thought really healthy didnt know vegan knew martha apprentice didnt watch',
#  'got made redundant today oh shame',
#  'paulaabdul hmmmm rain toledo',
#  'cant find cue cards',
#  'cant seem anything right today maybe take nap',
#  'tons homework',
#  'fatally_yours dont trader joes fl actually poor healthfood store selection need move lol',
#  'coffee bee sunday tradition last one semester',
#  'cherrybumbum lose video camera poor thing',
#  'bowl pho good',
#  'feeling great anymore hahaha sure drink lil year cool',
#  'pavithri sniff thanks sniff',
#  'binko picture lol excited video oh well hhahha',
#  'leavethistown miss muffin',
#  'mileycyrus dont leave us haha im part fan family okay good look hm premiere germany god bless luv ya guurl',
#  'last day spring break heading venice beach around though fun',
#  'fell last night fav jeans dead beasides im wounded',
#  'seriously much going watching katie leah play lotr one online going feel ignored',
#  'lovely outside one share lovelyness',
#  'sundays always depressing worry mondays following day',
#  'petewentz piecsesthe stupid little fish im bad monthso make get better sucked bad',
#  'cant find ipod tore living room apart never found',
#  'alynn dont want know answer want money back',
#  'angelicmischief nothing stood pomptly hit floor threw',
#  'sad someone left today cant wait summer',
#  'breaks later tweethearts',
#  'bergenlarsen actress played oracle replaced inferior crap coverup bonded wanted cookies',
#  'got home fashion show rehersal listening depressing music aid depression',
#  'stuppppppid papers day long even thought going',
#  'fair ride tilt-o-whirl bad santana doesnt play anymore',
#  'cat usual lies beside right im get go somewhere else poor thing',
#  'called day -',
#  'hollywills wished cud signin',
#  'elshertz yess say need fornarina jeans',
#  'dannywood danny enjoy well-deserved break miss boys already though going nkotb withdrawal',
#  'weather messed sunday',
#  'bbc toy americans showing wonderful full episodes topgear available watch us',
#  'marianne cold',
#  'woburn days days til graduation',
#  'rockpapershot oh man jealous doesnt unlock tuesday',
#  'time bath yoghurt bubbles goodnight fav twittertown sweet dreamss',
#  'havent gotten started prepping essays massive exam next saturday exams one must get ass gear',
#  'woot work sunday ohh wait thats exciting',
#  'lazone http//bitly/anqju ace prize winning fan made vid best single released please keep retweeting',
#  'want wendys',
#  'walmart sunday always barely got alive',
#  'hate saying goodbye ugggggh',
#  'christymychem yeah know hey u email',
#  'back church memorize creed gon na killl wan na shopping tay momma',
#  'stefsull usually gets wonky actually headed genius bar aft macbook refused restart last forced reboot',
#  'calanan youre pretty damn cool although miss brunch today thanks hosting last night super fun',
#  'bripoe aw man wan na see terracotta army',
#  'still lil bit hungover awesome bachelorette party though',
#  'marybologna keep updated im working',
#  'really going watch brothers sisters breaking bad damn roomies',
#  'ah alicia making watch saw im scared',
#  'bedback work tomorrow',
#  'rosewowie im similiar boat one time zone behind',
#  'going back school',
#  'degrees thats like summers day ul know coldwinter getting close',
#  'still work',
#  'nayedene workin old phantom opera z moment great astaire-depeche mode vid got removed utube',
#  'left queesy feeling much frusteration anger team',
#  'noisy street-lit outside keep window open else ill die',
#  'lost usb',
#  'back work wish still holiday',
#  'happy going bed',
#  'trying get train london present ceo none parking machines accepting cards must monday',
#  'ready another work week',
#  'shenaniganjenn plz dont die totally need may th would miss & amp dead would suck',
#  'aubreyoday abouthumm danielle lol yay',
#  'danwarp argh icarlycom keeps forwarding icarlycomau',
#  'bad bad person',
#  'lilyroseallen giving free tickets county durham area fair x',
#  'follow guys im new',
#  'johnathan havent mate',
#  'like nokia messaging app support nokia slow',
#  'nooo school mins altough im still bed',
#  'queenbmakeup havent found face cleanser/exfoliator ive liked since real oily skin idk look',
#  'wish doug',
#  'im cold',
#  'iced hazelnut coffee mcds sounds great right bad ive given caffeinei guess ill stick ice water',
#  'lindza broke nose holy crap hope okay',
#  'creating twitter account',
#  'took bubs hospital first big bump bump frightened witless shes ok tho wait day lol',
#  'bike ride really hard yesterday paintball least good fun',
#  'drinkyd know im like damn ima never meet cockblocking security guards',
#  'search friend countrywithout email address',
#  'maester sad true society says life already',
#  'anybody remember & quotwe want cup & quot song z canucks wish knew tape',
#  'school hair seems mind morning hugs jane xx',
#  'ddlovato great day demi school haha x',
#  'shame beejive supported anymore open sourced',
#  'project references xcode killing poorly documented buggy something get',
#  'soy_ale dood month selling',
#  'mrskutcher sad story rubina everyone elseslumdog millionaire stars family trying sell herhttp//bitly/muu',
#  'oh man im going miss back-to-school gossip',
#  'bsy today lot work',
#  'school time see guys later',
#  'simon_barton oh god hope im young spawn',
#  'sleeping poor start week',
#  'thinkin bout mess kids r gon na make eatin tacos dinner',
#  'vaempyr sent friday',
#  'ow heard jamesmeese got pwned face yesterday playing syn futsal team unisexicorns poor james',
#  'nut_cookie hope ugh im pissed user posts lot pictures kinda nsfw & amp mama kang-mom',
#  'msphotogenic loved mine moved seattle hi miss',
#  'vinny_vegas yeah something nice eight letter word distance gah',
#  'two deaths one day wtf',
#  'exactly one year ago drunk baked cocaine mom calling asking',
#  'woke apparent readon realizedim fn sick dammit nooooot sexy clenex please',
#  'cant tweet something awwwww',
#  'work',
#  'loves sunshine wishes christopher didnt work pm tonight',
#  'want cold snow cold hot chocolate _____ brazil hot -',
#  'shamalac sad inevitable - noticed lot trees uprooted either side agara junction flyover',
#  'beejensen awi actually text-ed one wanted',
#  'imariaprime everyone left jewb talking knuckle herpes star wars',
#  'cant monday already',
#  'first message cant think anything quirky interesting write',
#  'imjulio gon na hang ableton sesh aint got oc live buddies',
#  'antmats cant believe im back ny yuck wish fsa school actually wish went northeastern',
#  'go rs revision session school today grim cant believe havt go school holidays',
#  'official printers hate going sulk make cup tea',
#  'comes something notice wifes shoes twitter notice feet ooops',
#  'ready work ohcorrections fridays work',
#  'im sadi met guy dreamsin dreams didnt even get name number ahh swt dreams tonight please',
#  'snoozed far many times stressed getting everything ready hour',
#  'baby girl immunisations today shes happy',
#  'oooooo ok cuz wonderin hell ur eat supper like cuz thaugh u america srry',
#  'really hoping get job getting worried',
#  'nails book complete series called life ice-cream salvage day call monday',
#  ...]

# %%
# vectorize
positivity_cv = CountVectorizer(token_pattern=r'[^\s]+', max_features=7500)
positivity_X = positivity_cv.fit_transform(positivity_texts).toarray()
positivity_X.shape
# Out:
# (50000, 7500)

# %%
positivity_x_train, positivity_x_test, positivity_y_train, positivity_y_test = train_test_split(positivity_X, positivity_y, test_size = 0.25)

# %%
positivity_model = MultinomialNB()
positivity_model.fit(positivity_x_train, positivity_y_train)
# Out:
# MultinomialNB()

# %%
positivity_y_pred = positivity_model.predict(positivity_x_test)
accuracy = accuracy_score(positivity_y_test, positivity_y_pred)
accuracy
# Out:
# 0.75096

# %%
message = "This sucks"
prediction(message, positivity_model, positivity_cv)
# Out:
# array([[0.88535247, 0.11464753]])

# %%
positivity_model_filename = "positivity_model.pickle"
pickle.dump(positivity_model, open(positivity_model_filename, "wb"))
positivity_cv_filename = "positivity_cv.pickle"
pickle.dump(positivity_cv, open(positivity_cv_filename, "wb"))

# %% [markdown]
# # Emotions dataset

# %%
n = 416809 #number of records in file
s = 50000 #desired sample size
filename = "emotions.csv"
skip = sorted(random.sample(range(n),n-s))
labels = ["index", "text", "label"]
emotions = pd.read_csv(filename, skiprows=skip, encoding="ISO-8859-1", names=labels).drop(columns="index")
emotions
# Out:
#                                                     text  label
# 0      i need to feel dangerous and pretty so here a ...      3
# 1      i don t feel submissive and for the time being...      0
# 2      i remember feeling after the third bong hit th...      4
# 3      i have a feeling that has to do with the unfor...      0
# 4      i was feeling extremely generous last night so...      1
# ...                                                  ...    ...
# 49996  i chose vain beauty initially i wasnt very kee...      1
# 49997  i feel that i must confess even though it kill...      5
# 49998  i don t know why today i feel like it looks ve...      1
# 49999  i don t even feel like i fully resolved it but...      1
# 50000  i think that after i had spent some time inves...      5
#
# [50001 rows x 2 columns]

# %%
emotions_X = emotions["text"]
emotions_y = emotions["label"]

# %%
emotions["label"].value_counts()
# Out:
# 1    16914
# 0    14491
# 3     6999
# 4     5635
# 2     4092
# 5     1870
# Name: label, dtype: int64

# %%
emotions_text = []
for text in emotions_X:
    emotions_text.append(clean_text(text))
emotions_text
# Out:
# ['need feel dangerous pretty striking dance pick deep vogue minutes ago',
#  'feel submissive time lost interest bdsm stuff',
#  'remember feeling third bong hit pressured',
#  'feeling unfortunate fact family cat recently passed away',
#  'feeling extremely generous last night companion ate double told lion stomach pipe',
#  'feel strong confident intelligent ready step real world',
#  'know im going disappoint ive decided volunteer year fear ill end feeling resentful',
#  'able lose three kilo feeling energetic even month old things seem track',
#  'id good days weeks months kept feeling like cant last life cant sweet',
#  'feeling glamourous wear something glamourous feeling relaxed put feel relaxed basically fashion expression person',
#  'feel awfully isolated one talk things',
#  'really love reading bible feel presence lord jesus feel every single word says also amazed happened jesus sacrifice save us sin also looking back created everything world',
#  'feeling bit sceptical',
#  'ive come back montreal ive feeling restless',
#  'im feeling bit amazed grateful landed amid congregation',
#  'feel like mention another sweet family us',
#  'im feeling bit melancholy',
#  'knew feelings core thankfully daughter came fine',
#  'wish women could feel comfortable talk day really like highlight perfect parts',
#  'love travel developed love photography however began feel type travel photography even though commercially successful unsatisfying clearly expressing personality thoughts world',
#  'feel sadness feel frightened incredibly happy',
#  'know still feel surprised thinking could done deserve',
#  'really hate feeling getting ignored someone u love',
#  'take comfort paralyzed years living weird state abnormal separation things normal knowing always connected god feelings loneliness pass sense aloneness loneliness good us',
#  'feel find share unfortunately pleasant',
#  'feel shocked realize whatever talking seeing understanding way',
#  'created shared blog feel free share others please give credit link back take credit something creation',
#  'im feeling groggy still',
#  'feel someone hands wrap around frightened thinking someone else trying hurt',
#  'excited came perfect time feeling little homesick',
#  'think probably good somebody might feel disempowered realize things life dont feel victimized',
#  'knew entering race would going kind time goal still hard feel embarrassed',
#  'belonged difference feeling like youre accepted belong feeling like youre others people',
#  'finally go feel little bit sorry whoever final catalyst',
#  'feel love collection target blank title click liked article',
#  'feel joyful inspired write lately happens two reasons im hurt beyond tears im happy',
#  'know words much power give messenger words influential makes feel said term endearment felt dismay quite frankly got pissed',
#  'im feeling frightened dont know handle',
#  'feeling sociable want stay home watch tennis finals couch',
#  'occasionally slip one usual stews frustration fueled attachments non acceptance ego course banes serenity human body usually feel satisfied alive',
#  'feeling urge yell greedy teabag licking potato bottom',
#  'choose feel calm think clearly',
#  'look forward morning cant find time paint couple days start feeling grumpy',
#  'started feeling numb relief',
#  'im pretty sure stash products overwhelmingly impressive im waiting inventory posts make feel lame comparison',
#  'walked floor said loud really feel like leaving really want dance dance see guys paying attention getting impatient',
#  'feel abit stupid writing opinions everything haha',
#  'feel helped revitalise dull locks',
#  'feel like attempt truthful caused get involved cause inadvertent pain',
#  'feel delighted cause aaron coming sydney days',
#  'love feeling useful',
#  'feel like live without gps also thankful driving common items learn drive maps road signs google directions mapquest almost got us shot times atlanta kidding',
#  'feel like lame email im time',
#  'cant shake feeling impulse add endgame bonuses special actions would make rather elegant game needlessly complex',
#  'feel though life pathetic havent amounted anything',
#  'mostly positive days feel discouraged bad side effects treatment',
#  'feel glad able spend time places hope convey something mixture ancient presence amp fragile beauty',
#  'feel ecstatic amp think everything achieved',
#  'cant feel sympathetic humans get killed yoma merely part nature',
#  'feel like im sinking feel helpless makes even frustrated',
#  'feeling bit lively though ready go yet therefore dear friend maggie went sweet little restaurant opened across apartment',
#  'feel hiding know youre dangerous',
#  'feeling vigorous like cajun olympian',
#  'sit blow nose feel miserable ever',
#  'im feeling foolishly optimistic',
#  'feel tranquil peaceful go war',
#  'lost hopes talk know satisfied enough beside means feeling giving kind pleasure divine pleasure',
#  'feel really lucky people family still value time carry tradition',
#  'pictures everywhereee even managed find places put paper roses piece scenery senior musical thing says hope painting made nats isnt great putting made feel artistic ha href http pics',
#  'feeling discouraged came comic work ended trying work sketchbook instead',
#  'feel terrible one loses life',
#  'feel even pressured',
#  'basically chopped machete could leave feeling rejected leave opposite want',
#  'feel like heretic bitter using simcoe hard come recently ill probably warrior add magnum kick',
#  'feeling absolutely enraged right bathroom incident happened morning happened six years ago',
#  'feel kind relieved really bad times since well hes super nice guy great boss time',
#  'drove work feeling rather smug',
#  'find feeling even offended ms',
#  'remember feeling surprised wondering dropped us',
#  'didnt feel pain felt pretty comfortable',
#  'feeling quite satisfied accomplished',
#  'feel hesitant',
#  'guess normal feel shaken drained etc point',
#  'feel peaceful well kind feeling guy gets knows exactly lighting world fire least',
#  'also picked sticks get enough sun hour go basement feel deprived light',
#  'feel theyve put lot yet theyve beyond supportive everything ive wanted',
#  'im feeling sentimental kinds crap along bored',
#  'feel make ring lovely tactile end',
#  'looked sleeping face suddenly felt stress leave body small stress deadline stress life feeling replaced sweet peace',
#  'came university piss ups expect feel humiliated seminars',
#  'dont eat cant focus feel cranky pissed mood swings like crazy',
#  'also feeling benevolent absolutely could taken advantage didnt got tip match one girl stole',
#  'feel bitter jealous',
#  'im talking sex anything though maybe talk first sexual nature feelings repressed world society general',
#  'start feeling needy',
#  'feel terrible course would opening line bloggers anonymous thing',
#  'bought three books feeling disillusioned one id brought glasgow',
#  'feel like pain hurt terrible things life died time free',
#  'im going finish marking knit another pair socks tree feel pleased gifts ive sewn last buttons little dress harriet smaller copy one nolas wearing href http materfamiliasknits',
#  'ive short fuse kids cranky people come contact feeling irritable altogether',
#  'feel like hero warrior brave strong amazing fun word people use describe',
#  'feel top world read somewhere talented danny dougie get mentioned word',
#  'write feel feel exactly romantic stuck',
#  'think decent grasp itll still take trial error feel assured talent scouting',
#  'im already getting feeling hes keen',
#  'dread checking emails make feel shitty',
#  'feel babe moving back reminding carry precious burden engage fight wise decision',
#  'feel strangely discontent alienated',
#  'need learn feel much pain suffering',
#  'need feel hope fact one vital statements book according hundreds shared helps hurts heals',
#  'understand feels hated',
#  'still feeling somewhat dazed well gone spite inability cope much change',
#  'feel like finally resolved major conflicts room mate thankfully us mature enough sit listen others complaints',
#  'feeling nostalgic toronto adventures right thing stands sad images favourite apartment fireplace',
#  'im used feeling helpless',
#  'remember feeling gloomy th even cried front hugged everything okay',
#  'feel like im sorta pressuring go reassured want go',
#  'feel like marvin robot hitchhikers guide galaxy morose',
#  'might feel resentful sometimes think part process living world good know could',
#  'feel shamed could forget person',
#  'feel distribution important would rather guaranteed loss ten days chance losing years',
#  'feel like much experience tournaments trusting swing',
#  'feel lousy happen',
#  'dont know im ready summer mostly feel like missed much summer year',
#  'blog im feeling dissatisfied tenure track job lot happy life',
#  'im feeling mellow moment',
#  'feel like hopelessly devastated',
#  'ive feeling impatient get worked easily even small matter',
#  'miss sideshow favorite band hours feel rather regretful',
#  'think blessing feel get everything loved first one get much time around',
#  'started feel terrible found quite attracting vanessa marisa taking pictures ipad',
#  'completely sympathize wish feel stability scared change see definitely stability',
#  'begun feel though valuable contributions insights make within network professionals',
#  'feel acceptable supposed looking child best interest cool',
#  'varying degrees feeling person obviously went really liked talk really wanted',
#  'feel many insects taking lovely sound assurance',
#  'must state record say certainty regrets marrying feel missed god way',
#  'feel calm silent protected definiteness existence',
#  'think events last year left feeling unprotected vulnerable',
#  'watching programme starving refugees plight source sadness',
#  'feel sentimental knowing blip family timeline',
#  'im feeling guilty much giving many excuses everything',
#  'im bit ashamed admit bare faced makes feel vulnerable',
#  'feel selfish even thinking',
#  'never feels insincere little nosy get hint something might wrong want jump get details',
#  'go feeling emotional pain trust one gives peace beyond comprehension',
#  'sat shared little walked door feels terrified',
#  'feel like kind obnoxious say tie navy blue orange since href http www',
#  'think started feeling fearful future',
#  'feel optimistic',
#  'feel abotu couple im impressed',
#  'feel like ive closure back wonderful think im better seattle',
#  'feel though might posted barcelona quite sure',
#  'feeling compassionate daughter bringing home manner creatures varying states demise grows made clear leaving store without ellie bellie',
#  'decided feeling tearfully regretful probably rather good mental state occasion nodded bring us together',
#  'figured parents wont make feel accepted stopped trying turned romantic relationships men',
#  'feel energy body loving',
#  'im feeling calm today',
#  'distraught eyes go wide glazed really feel shes shocked horrified',
#  'im big believer need feel part something feel valued worthwhile',
#  'ive started feel uncomfortableness cant sit cant stand cant lay without something aching pulling stretching',
#  'feel sorta bad claiming big fan show dont even last season',
#  'love feeling reassured',
#  'also problems regulating body temperature feel hot much time',
#  'ive felt thing rollos wife feeling day im glad thank god',
#  'feeling welcomed',
#  'weeks pregnant feeling comfortable arrival time post',
#  'actually went lot fun weekend made feel invigorated today helped crank ton pages novel editing',
#  'revelling feeling much almost missed said',
#  'rarely feel bothered walking around',
#  'really enjoy volunteering pre school really makes feel like something worthwhile giving positive contribution community',
#  'feeling one might popular answer today',
#  'im feeling positive enlightened moment',
#  'ive looking photos house im feeling rather sentimental',
#  'feel beaten discouraged',
#  'interviewed journalist herald earlier week festival feel really pleased team achieved year festival',
#  'ive voiced concerns past us dropping old im feeling slightly reassured preparations new campaign',
#  'im coincidentally feeling weight thanksgiving upon making bad choices weekend',
#  'feel less stressed work clear head focus',
#  'entire day didnt sell single policy feel pretty satisfied time know takes good sales get paycheck week',
#  'feel really stupid',
#  'articles clothing make feel cute',
#  'feeling delicate wounded reason follow',
#  'guess feeling particularly hopeful honest',
#  'feel anxious worthless',
#  'stopped sit sun doze feeling cool crisp autumn quiet around',
#  'feel blessed many new faces stories surrounding',
#  'always end feeling like missed many treasures keywords',
#  'feel really important true oneself allow others sway course',
#  'feel victimized jaejoong sighed',
#  'im feeling passionate something still pray whatever connecting us',
#  'remember feeling shaken image mirror',
#  'feel bob loblaw handsome professional man im used well none things',
#  'feel pissed lack help support',
#  'many others feeling helpless world hold grieving parents hands especially mothers grandmothers nigeria desperately wait assistance girls return back home safely let laughter ring home',
#  'became official student blogger lse makes feel pretty cool actually interested href http blogs',
#  'feel like seeing series lot lately malin assured worth time',
#  'feel hopeful feel positive future',
#  'shoes feel devastated angry cancer happened',
#  'also feel vulnerable left bed virtual silence',
#  'feel little grumpy perhaps cold damp typical british weather client never home pay fee feeling anxious tax simply morning blues say joy jesus christ would well backed personal reality would',
#  'remember feeling curious mums sisters clothes third year primary school',
#  'think rooted need feel like belong know safety think dream risk fail hurt suffer succeed question',
#  'started week feeling groggy unwell picking sick note doctor climbing fresh sheets snacks bottle water hand',
#  'feel bad husband',
#  'started listening punk music liked way sounded must also credit growing middle class suburbs southern california feeling isolated bored year old would termed status quo',
#  'feel people trusting messages get cell phones via e mail',
#  'get give away day feeling amazing',
#  'know polka dot ice cream doesnt exist irl feeling would delicious',
#  'feel like something delicious used mother nightly mantra',
#  'ive feeling overly cranky tired frustrated',
#  'feeling inspired see anything anymore',
#  'feel resentful hubby doesnt notice needs done around house doesnt step help without asked',
#  'feel moving around feel contented leaving sort way',
#  'feel pathetic waking mom money vacation funds limited',
#  'feel vain cuz tell starting somewhat pay like ill lookin mirror morning flexing lady abs',
#  'stayed apartment feeling numb yet strong quiet resolve',
#  'feel foolish saying stick bad things ive confessed schedules situation feasible travel treatment right',
#  'wish better company feel really bad mothballs like',
#  'didnt feel lonely broken',
#  'panic attacks water feel stressed',
#  'feel motif elegant',
#  'feel peace complacent yet time restless misery filled',
#  'lot week finding new hospital new doctor feeling pretty drained pretty real contractions',
#  'suffering horrible cold moment lot runny nose teary eyes sore throat amp throbbing head feeling pretty rotten',
#  'taken years body built sort resistance drug take order still effects needed calm make feel happy',
#  'love go things feel like every curious question must unfolded explained',
#  'saw newspapers',
#  'tonight bed realised bad relationship friend',
#  'feel blog worthwhile blog follow educators interested learning technology used classroom',
#  'ive finished work christmas worked saturday relax feel bit festive although manager call hotel others fingers crossed dont get call worse go help someone something drastic',
#  'possible talk without feeling inhibited something',
#  'ive pretty candid people story plot least beginning suddenly change im feeling reluctant tell anyone',
#  'decided take nick date feeling little unsure group date drama previous week',
#  'love manicure monday perfect sometimes leaves feeling annoyed frustrated',
#  'recovery feeling less groggy ready beverage snack href http',
#  'feel like grouchy',
#  'raised loving home still managed grow feeling insecure',
#  'feeling lonely anxious confused',
#  'woke feeling splendid even went outside everything',
#  'im feeling kinda mellow ever since listening sacral nirvana oliver shanti hours ago',
#  'feel stubborn stupid everything could describe right',
#  'feel like could spend day every day cleaning house would still look messy',
#  'feel strongly every child needs free independent access advocate strong enough speak need',
#  'still feel cool breeze face every emotion felt every breath took',
#  'prepare kinds upcoming moments leave introverts feeling uncertain',
#  'feel like im kiss wonderfully vain swear ill melt touch ill ask saturdays saturdays saturdays tuition studying guess life like',
#  'feel little lethargic recount href http en',
#  'find feeling annoyed',
#  'feel helps viewers sympathize determined women',
#  'feel like graceful swan',
#  'feel bit uncomfortable sharing needs humbled peoples responses want help even focused much children didnt even think future',
#  'want feel peaceful money get rest life',
#  'feel rather guilty neglecting blog late',
#  'feel really lame photos assembly came wish well',
#  'feeling loved listen well',
#  'feel compassionate certain people',
#  'really dont think course great know going somewhere else probably still end going motions feeling ultimately dissatisfied unproductive disconnected others',
#  'feel victimized chevron ad amp trained ad stop visiting site',
#  'taking everything andy one knew feeling hated knowing truth',
#  'love lemon crusted flavor feeling bit naughty get pan seared lime chili tilapia',
#  'ive husband almost eight years still feels like never dull moment',
#  'getting tired feeling jaded',
#  'like feeling suspicious paranoid everyone around including cat spending way much time self loathing thoughts sinking unwarranted unnecessary depression feeling supremely guilty acting like bitch',
#  'feel vulnerable yet excited situation',
#  'im feeling angry betrayed jealous flattered excited im going say',
#  'feel special',
#  'im feeling kind scared cuz im falling love dont care cuz dont know feel dont want give heart someone new someone please stop',
#  'discovered makes feel terrific also helped lean',
#  'started sessions day day week great financially often feel beaten mentally physically end day',
#  'think folks like freud marx nietzsche first raised weve created god need feel like everything ok',
#  'almost feel emotions proud son torn whether support talk',
#  'still feel inadequate left behind times',
#  'sit crying feeling loss suffering unbearable pain know wrong made leave feel hollow gone misery taken heart since left begged stay laughed face supposed',
#  'fear suffer depression people care feel inhibited going hard times',
#  'happy report despite feeling twinge melancholy sentimentality years events life never better',
#  'feel shaky emotional thinking im sure lack sleep isnt helping',
#  'back body fact feels strange',
#  'feeling defeated respect lifestyle busy times',
#  'wrong feel unloved',
#  'feeling rich morning',
#  'im feeling curious bout content inside lol went panic saw content',
#  'feel lucky enjoyable pregnancy far',
#  'get feeling drop shipped hostile environment could easily provoked',
#  'honestly say disagree comments feelings however times would pleasant read negative rants law society general etc',
#  'want someone understand take hand make feel better',
#  'faithful feeling lump form throat speaks fearful dismiss moment wrong truthful realized leifnorthman truly apologize thousand times',
#  'listed hopelessness confusion idea god real must say reason feel thoroughly convinced days god jesus experience delusion',
#  'love running feel amazing afterwards bleeding feet',
#  'feel scared change life',
#  'feel flourish like precious flower opening coming bloom',
#  'told feel funny dont think think something',
#  'feeling super duper glam gown decided get face boot went dinner date new brighton',
#  'feel hopeless stumped still banking us reuniting getting back life',
#  'ive already invited controversy theologically let invite politically feel recipe fantastic',
#  'goal fight towards would fluctuate towards bored lazy feel im anything worthwhile',
#  'still wear wardrobe change whole feeling attire naughty man',
#  'stopped feeling bad day crazy sister actually jumped mother basement try cure ocd',
#  'feel triumphant got back running symphony x turns perfect workout music tempo triumph images frilly shirts various monuments invoke',
#  'always feel like im caught something naughty catch looking',
#  'slid wanting feel frantic heat friction bodies rubbing together ideas',
#  'definitely enjoyed every bite today already feel excited new foods going finally let eat says ok really needed',
#  'made feel vulnerable shy perhaps made think aloof made uncomfortable vicious circle pushed us apart',
#  'fear feeling like little verbally abused girl sinks mean ass sister worth gs dad silly little bro worth couple gumballs',
#  'idea item clothing could possibly fit feeling cute bill didnt fall category discovered fact crumpled heap beside underneath bed every square inch wrinkle covered impressive array animal hair',
#  'feel antsy distracted',
#  'feel mad todd isnt stronger need sometimes feels mad im hours away instead helping home',
#  'feel curious life another school would feel like',
#  'could feel watching successful business jeff created',
#  'feeling funny today',
#  'feeling little melancholy today would brother billys th birthday',
#  'lovely feeling within know sweet little wife wish knew feel towards',
#  'feel like ive neglectful friend due fact feel like hinderance stay away',
#  'feel like im frantic',
#  'lose senses feel numb consequences actions times willing stand ocean even currents wash depths safe return',
#  'cold hot feeling temperature till cant stand till makes furious sudden',
#  'alone thoughts sometimes feel little jealous imagining someone else could please',
#  'think feel angered priest moved description dream whatever going incredibly confusing way hoping looking someone agree tell justified feeling way',
#  'eat fat feel acceptable alive get rid added fat took',
#  'also glad strong enough relationship husband express im feeling mad bad sad',
#  'know na feels rejected',
#  'said feel embarrassed',
#  'feel like hes suspicious writing skills especially around subject concise sophisticated',
#  'feeling inspired wanted know like someone coming lab data fresh',
#  'feel blessed able go vote still home less half hour',
#  'believe make customers feel comfortable let setting right atmosphere',
#  'feel kinda talented',
#  'call today wasnt good day feeling soooooo dull throughout lessons',
#  'im feeling particularly impatient still happy im waiting come around',
#  'didnt dress halloween im feeling bit nostalgic',
#  'ive waited since pm line outside cold chicago get best spot photopit course three songs feel endlessly tortured looking shots cant take',
#  'really read twice feel envious ability able dream handing notice wage one get mortage im stuck job get house',
#  'feel sort ignored',
#  'kitchen bathroom gave nice additional feeling calm',
#  'feel weepy miserable tired sorts generally side good mood vs',
#  'feel obnoxious creating self portraits',
#  'also want address feel heart objection death penalty administered fact innocent people executed',
#  'feel little discipline process become habit even stubborn souls im determined find',
#  'feel like would worthwhile since im writing first exam vague idea anyone really knows',
#  'recall weigh ins previously felt though id dropped significant amount weight feel disappointed number wasnt large would liked time',
#  'assegaf rest crew feels fabulous colorful years couldnt agree',
#  'make effort simply walk slower prepare food slower focus one thing time feel calm safe body',
#  'hope least imagine someone kansas cares sincerely wants feel beloved day',
#  'speak people find feeling pretty amazed',
#  'read anne sexton makes feel morose read sylvia plaths journals made feel good happy finally enjoyed soemthing week wrote journal worth stay late tired tomorrow',
#  'thinking death',
#  'feel important people reflect back magic time',
#  'blind anyone darkest despair still feel friendly hand reaching darkness calming reassuring terrorizing',
#  'feel calmer time move hope dont repeat im pretty sure',
#  'person needed encouragement uplifting feel needy',
#  'feel like sort thing resolved moving forced entire arrangement possibly killing roommate taking room',
#  'actually feel quite sympathetic towards anna though',
#  'really miss feeling beloved especially ill tired',
#  'came meeting feeling positive letting get carried away',
#  'feel weird writing food stuff much going',
#  'think ive herd song times time ends feeling troubled name',
#  'checked writhing around agony nearing death couldnt watch made feel like heartless murderer',
#  'generally aversion shakespeare think sheer amount plays many feel sincere b seen many dishwatery community outdoor theater productions heat sounds traffic mediocre acting',
#  'woke time time change feeling strong confident today decided complete rattlesnake mater k urbana il morning',
#  'sharply inhale feeling invigorated full life',
#  'feel never chance fully heal without still responsibility caring another person daily basis',
#  'feeling someday going rich',
#  'feel horrible feeling leaving fun happy time ended',
#  'feel hesitant right time last year marked feels like day lives started get thrown chaos',
#  'im sure heard khutbah made feel awful never really saw particularly bad thing even though poor hubby hates',
#  'feel like im compassionate good listener',
#  'feel assured confident always oh god ohhh wish wait',
#  'feel hurt every time',
#  'sit corner snidely slag confront let know feel wronged',
#  'weeks post op feel absolutely amazing',
#  'ive searching book make feel content happy guidance better',
#  'cant help feeling lost little bit',
#  'feel terribly unsuccessful attempts make something life',
#  'feel need explain lest look like heartless bastards selling merch mother theresas express wishes',
#  'feel hopeless would open bible odb start searching refreshments',
#  'getting routine already feeling confident far land call home',
#  'feel like im taking roll one person really disliked one point',
#  'understand dude trying best feel accepted everyone annoyed back forth drama',
#  'feel entirely dissatisfied',
#  'wanted say something bad vibe feeling hostile didnt think good night',
#  'didnt feel stress portfolio determines accepted student teaching stressed',
#  'feel cool sheet',
#  'still unemployed feel rather listless unmotivated looking work given unsuccessful ive',
#  'thank students give mix handshakes high fives depart feeling contents stomach nicely shaken terribly stirred',
#  'think part dont bother calling docs feel rotten go ground wait til goes away',
#  'able feel divine presence observe',
#  'feel bit frightened',
#  'feeling well weekend',
#  'understand may feel rude keep destroying house face',
#  'feel irritated told line good vibes lang become ease continued smiling',
#  'remember feeling exhausted hot sore',
#  'could even feel cold breath neck whispered hertha ran fingers across side neck',
#  'feel little jealous connected feel much enjoy bodies',
#  'like feeling fearful even saying name place work',
#  'feel optimistic like good things possible',
#  'remember feeling quite shocked seen movie memories film scary flying monkeys evil witch',
#  'withdrew feet feeling strong enough sit look faint bluish purple glow resonating miniature arcs lightning bounced emin fingers surged thin uncontrollable veins across entire pool',
#  'ive feeling scared',
#  'would sleep night wake feeling drained',
#  'feel relieved someone office believes gay people rights rest us',
#  'know fairly hateful religious people use term loosely feel religion make person less hateful really wonderful ones',
#  'usually leave feeling fabulous empowered',
#  'feel convinced sun actually disappear center milky way life time opportunity meet aeronautical engineer two nights ago volunteer work alongside',
#  'ive feeling bit cranky im going complain later post',
#  'feel like know expect feel crappy makes easier',
#  'start run usually feel like running running walk taking wimpy way',
#  'often feel distressed freaked whenever child gets sick',
#  'feel fabulous hopeful round chemo work magic',
#  'feeling angry care town',
#  'wish social anxiety could funny rather laughing short breath feeling anxious',
#  'feel like wait day talk special someone promise hearing voice seeing skype enough make spontaneously combust excitement packs enough punch carry day smile across face',
#  'remember feeling energetic need coffee',
#  'much think negative thought person make someone feel slightly disheartened uncomfortable',
#  'feel sympathetic im lot lying god cant imagine much bullshitting must everyday lives',
#  'feel like im grabbing empty air',
#  'feel quite frustrated many people seem concerned least appreciate serious',
#  'feel abnormality mac eyeliner gel lovely feel abnormality mac eyeliner gel lovely href http www',
#  'guess im feeling bit abused taken granted',
#  'midst many life changes looks like going lose home rather feeling terrified trust god always provides choices maybe isnt supposed',
#  'feel nothing sincere admiration respect moderators',
#  'think anybody feel unloved unwelcome even',
#  'feel little girl surprised daily love feel continues grow',
#  'im feeling little gun shy',
#  'still feel grossed bitchy guilty angry',
#  'feel awkward',
#  'intend feel benevolent',
#  'find greetings almost exhausting america feel need try pleasant give good representation foreigners',
#  'feel though people bothered friendship busy bothered',
#  'feel distracted sex pet watching',
#  'feeling better yay prescriptions',
#  'feel completely devastated knees wind knocked shock horror scared unsure terrible events happened close',
#  'return shower shave remainder left leg feels vain insignificant',
#  'post one blog time feeling quite energetic today typing ask',
#  'see many people proudly wearing yog uniforms mrt sort make feel remorseful first ever youth olympic games even better held singapore im ashamed',
#  'feel pretty strange women expected hairless nose yet one bats eye dude hairy gorilla ass',
#  'started feel isolated many athletes getting ahead',
#  'feel like ive devoted make person feel like shes best feel like shit like ive used',
#  'feel like neighbors thinking terrible mother lets kid run wild misbehave',
#  'feel cher smart control wants young woman',
#  'always feel really stupid gets kissy parts',
#  'doubt stress grief feel resolved',
#  'feel little gloomy writing',
#  'feel superior men vidyut img src http www',
#  'knew feeling pretty keen breaking',
#  'feel need combination heat cold im looking pairs photos today',
#  'felt doubts made feel rather inadequate help elders struggling want lead anybody astray',
#  'know takes lot try start conversation painfully obvious someones trying catch eye try strike conversation starts making panic im going show im interested without hurting someones feelings rude',
#  'guess feeling bit nostalgic tonight wanted touch base mother',
#  'pictured twin set copper pipes running somewhere cool contemplated one flowed outward made feel weird think one',
#  'dont think intense feeling loss definition demands definitely things continually haunt give sense longing',
#  'fucking sad angry right feel completely shitty fucked',
#  'feel like husbands affair fault insights might help target blank class republish republish article',
#  'feeling unwelcome',
#  'feeling energetic today breathing bit tight today watched christmas movies today goodness realized sad sounds anyway',
#  'feel comes emphasis bouncy piano riffs like gavin degraw would use',
#  'feel gospel story telling us life christ indicates us divine nature humanity death christ telling us even matter separate god',
#  'guessing might feeling bit shy twitter questions',
#  'im left sulking feeling like things dont get resolved',
#  'wear comfortable smart clothes make feel terrific every single day save clothes special occasions',
#  'im happy everything awesome next thing know cant something idiotically long time period steam stupid bitch know people say time moves faster youre fun slower feeling shitty bored opposite',
#  'ive alternated feeling relieved feeling angry wanting cry desperately wanting move',
#  'feel reluctant even let family members hold longer',
#  'feel pretty amazed seem worldwide fan base',
#  'love throw anything feel fabulous feeling',
#  'really feel humiliated write',
#  'feel like struggles accepted woman attractive smart educated independent slowing becoming recognized little little less discriminated age least hope direction going towards',
#  'think good ive given much already really feel appreciative wonderful equally pleasing type giving receiving',
#  'im sure get feeling shes point anger even something darker feel part vulnerable',
#  'feel comfortable finish hope stay within group elite anglers',
#  'feel time things planet unpleasant humanity general',
#  'feeling came realization much seem using words hurt inflame accuse anger',
#  'believe tension due feeling unloved blocks us loving generously',
#  'feel carefree able let things go perhaps new leaf stephanie haha',
#  'feel strange mix pride awe holy crap time go look kids',
#  'know lot people feel dissatisfied positions life refuse accept mine thats',
#  'would feel assured tt one whn cares cares enough tt care extended family',
#  'wish could make mind awful complicated see feelings delicate things',
#  'feel guilt violent thoughts',
#  'feel kind content something really use take classroom',
#  'supposed feel insulted commonwealth games federation executives thrash india shoddy preparations games',
#  'know sure make mistakes time feel dumb next time know',
#  'feel lot wonderful things way',
#  'feel little timid training really pushed get comfort zone',
#  'profess times challenging mostly feel resigned apathy concerning misery',
#  'read stereotype young people complacent interested defending rights busy going yoga checking facebook feel devastated angry defeated',
#  'feel pretty stoked',
#  'love style free worship intensity charismatic feel songs last minutes free worship',
#  'remember ultrasound first pregnancy feeling excited see baby screen first time',
#  'im lulled fantasy walking hand hand remote location preferably beach sunset cliched know feeling love loving return',
#  'really feel like going glamorous think dark velvety roses purple callas candelabras crystals oh veil albeit fun lovely seemed place ive fallen little couture ish number much better fit',
#  'feel quite cripplingly depressed feel bad everything cant anything frozen way',
#  'feel amazing talking compassion pit',
#  'feel tortured said poddar sustained percent burns',
#  'feel like ive lost past month life',
#  'ive enjoyed writing blog chance share much feeling generous want celebrate th visit rest',
#  'starting feel little bit pressure could think sweet baby jesus anesthesiologist gets late feel baby coming may never recover',
#  'feel dazed confused weird dumb creepy',
#  'feel hurt feel good enough good',
#  'allow still loved feel beloved god feel like',
#  'feel overwhelmed burdensome weight desire relationship',
#  'believe spend lot look feel fabulous',
#  'guess supposed make us viewers care plight know public defender breed feels like betrayal imply innocent client make try harder win implies wont try hard clients',
#  'sat bad way feeling physically defeated every way current standards past nit wit absurd idea words going add amount sense moment try vent',
#  'feel sad fact ill leaving batangas na',
#  'im feeling decidedly irritated matt today',
#  'ive feeling little bit reluctant real work',
#  'feel irritable annoyed pissed deadly homicidal',
#  'tree put decorations dust hang branches frankly feel lost christmas cheer',
#  'feel dull numb time rarely feel emotions strongly yearn',
#  'im feeling really apprehensive nice know whats going time open huge worms looks like something could use surgery decide',
#  'said none deeply touched somehow didnt feel real still liked darius twig',
#  'feel regretful didnt take photo yesterday chop onions onion makes people crying also dispointed sure important',
#  'wake feeling energetic feel stronger happier inside handle stress better',
#  'bad feeling going get aggravated tomorrow',
#  'feel like pain vain struggle worth end',
#  'came low expectations vaguely bad feeling pleasantly surprised',
#  'headed course feeling relaxed strong',
#  'left feeling slightly annoyed',
#  'really feel abused man',
#  'feel heartbroken today cant give pavel wants thinks needs',
#  'focus love posts come sincere stance one believe everyday art feels happy natural',
#  'contacted long buried feelings terrified five year old boy learned console provide new sense security',
#  'feel like people judge show writing unfairly harshly show consistently funny people take granted',
#  'two weeks finish things despite busy feel content way things',
#  'feel selfish wanting energy back',
#  'hide girl dosent even myspace u read bible philippianss says everything without arguing complaining thats verse stuck live seem laid back situation feel uptight',
#  'feel walk vain',
#  'im willing stand behind anything say im ashamed human feelings make appear bitchy people',
#  'feel dunno ungrateful something lonely long wonderful boy want see less',
#  'feel lethargic time',
#  'feel like deactivate account im longer bothered',
#  'feel happy together',
#  'long every moment feel gentle touch',
#  'hate feeling pretty mutual find obnoxious thinks im bitch nothing happened nobody thinks less anybody',
#  'knew needed get dragging feet combo feeling intimidated language barrier kids nap schedules',
#  'feel joyful knowing opportunity become much closer mother sister',
#  'want stop feeling worthless',
#  'feel ok plan months november would try write story story actually still actively poking around head think ill able pick back december',
#  'also want subjects film feel respected',
#  'feel like already giving fake smile leave alone mom look',
#  'feel feel energetic',
#  'constantly feeling pulse try type somewhat humorous scene derek mark',
#  'feeling fine slightly free yay',
#  'think everyone struggles struggled wanting feel popular',
#  'still cry sometimes feel inadequate days im learning walk legs getting stronger',
#  'often feel little bit stressed havent posted blog feels little bit like rabbit hole sometimes',
#  'heaved suitcase trunk friend car received ecstatic hugs welcome parents rushed onto driveway feeling hit glanced house surprised',
#  'feeling incredibly grouchy irriated want peace quiet one coming',
#  'feel strange going homeopathic long time',
#  'feel disturbed unreasonable lie life taking towards',
#  'feel lovely sense achievement list continues grow',
#  'wasnt sad didnt feel devastated',
#  'told designer fitting im always feeling like dont belong job friends creative aspirations',
#  'think feeling pretty stressed know whatever supposed happen happen',
#  'relate sometimes feel forget people silently supporting praying',
#  'feel kind reluctant depressed told respected decision',
#  'see dorian practically filter mean things willing say argue hes feeling cranky',
#  'feel assured despite youre still',
#  'full day today really feel like productive',
#  'feel bit stressed goodness knows feels',
#  'get emails girls say scrolling photos kept feeling ugly worthless',
#  'feel like ive read outgoing notes pentagon folks notable exception bob mendes new jersey',
#  'feel little ashamed even thought body feelings',
#  'ive found successful activity im feeling little needy also gets female population interested',
#  'couldnt help feel amazed',
#  'would understood shed fussy surely feels rotten',
#  'believe lot jacobs frustrations stem feeling inadequate wanting quit',
#  'feel hopeless species',
#  'either feel submissive agree taking pain someone option presented',
#  'left conversation feeling glad opportunity discuss matters faith spirituality feeling humbled coworkers generosity toward',
#  'feel unhappy depressed different',
#  'im back feeling annoyed effort takes pick dropped fork',
#  'never really feel deprived',
#  'really feel guys supporting team relegation zone',
#  'honest feel truthful anything affects two us',
#  'feel disturbed something',
#  'feel like main character peter weirs fearless yet minus dare devil side',
#  'feel like theres nothing like smile friendly salaam alaikum everyones staring twisting mouths pity curiosity disgust avoiding eye contact looking way abruptly',
#  'simply much drawn emotions cant blend heart feelings job anywhere else life look ones company successful job hold high positions boss exactly',
#  'got huge sports bras milk drying im engorged fun super comfy pair leopard peejamma bottoms im feeling gorgeous post labor',
#  'almost feel resentful state end day would much likable seems better parties see really going',
#  'feel never find anyone else click way feel woman would actually even act like wants afraid woman ever get',
#  'take one positive side match could still win third set feeling nervous extra tired',
#  'im feeling unsure much time start doubting',
#  'feeling much better excited come back school tomorrow',
#  'made cake people made buttons feel like mutually appreciative',
#  'feel rejected former classmates feel disconnected friends either alone among understand full context lies surround us worst accepting',
#  'hope routinely hopes crushed feel stupid hope',
#  'feel like making irritated',
#  'still evolving person still going feel anger sometimes despite truthful try examine anger always able see clearly',
#  'entered temple feeling vaguely terrified',
#  'ive come contact made feel loved cared like cheerleaders corner rooting us hoping praying achieve dream someday',
#  'dont enjoy shit dont want feel heartless',
#  'drank bit actually loved merry feel fabulous morning',
#  'hate high school remembering times doesnt make feel tortured anything man piece work',
#  'fear ive lost way dont know say feel tom petty one day one night',
#  'promise id pull didnt feel well next miles',
#  'feel precious little girls arms wrapped tightly around neck',
#  'feel triumphant weirdly anxious patriots making way super bowl',
#  'im one parents feels autism devastated ruined lives',
#  'feel im watching delicate surgery loved one went gt hospital splinter battling life',
#  'feel hunger strong deep',
#  'feel insulted course',
#  'im feeling goddamn bitchy ill try keep minimum',
#  'look beady eyes think joy would receive getting raise regardless size instantly feel ungrateful',
#  'still homework fact im feeling incredibly irritable today makes panic little bit',
#  'feel sure love complete vintage winter look perfectly',
#  'feel pathetic every time walk sandra office asking leave',
#  'im close trembling feel asked attracted vicious splendor stride waitress brushing ears onto conversation',
#  'feel scared',
#  'feel self pressured expectation keep date family events order assuage guilt go',
#  'always feel intimidated attend show feeling hooking never good wish could combine colors like etc',
#  'feel like supra giving back buy supporting core sport skateboarding providing quality product kids relate',
#  'needed help way also empowering making feel confident',
#  'really love spray feels cool skin',
#  'woke feeling pretty lousy sick',
#  'feel like crappy mom id like get alexs attention mins tell think',
#  'im feeling enraged another persons actions consider thinking moments prior incident',
#  'feel disgusted like',
#  'feel like ive missed lot lately',
#  'know ill keep coming back im feeling unsure future ill probably keep telling someday could happen megan keep believing',
#  'still things worried feel quite distraught',
#  'despise ungrateful point feeling angered forgive abuse',
#  'laying bed night feeling angry',
#  'feel much loves shows safe hurt loneliness pain hands',
#  'feeling feeling pretty href http llwproductions',
#  'always find time always feel fabulous im finished',
#  'feel pity reading posts looking horrible pretend happy trying hard',
#  'im feeling little frustrated right im trying things end make feel better lack money really holding back despite fact work almost full time job love btw',
#  'feeling little disheartened country priorities',
#  'feel though patron goddess divine rage women certainly lot',
#  'ive struggled weight ages im sick feeling naff doubly determined succeed',
#  'im feeling stressed arent classes open right',
#  'feel devastated happened brand new honda civic addition first car',
#  'asked laurel snyder matthew zapruder whether feel joy tortured write poetry three sighed said tortured form torture',
#  'know waste time least makes happy rather feeling tortured',
#  'know probably feeling sorrow remorse yeah feel dad im heartless',
#  'feeling quite disheartened',
#  'feeling distraught anxious fearful depressed literally begin feel plushy bathrobe around reminds truth heart spirit',
#  'grandmother died',
#  'feel surprised la',
#  'missed friends job feeling productive',
#  'feel like ive devoted enough time read pages ive reading hour way book',
#  'sight man ran amok fighting dance',
#  'feel kinda lost',
#  'im feeling sentimental im leaving words pets mean us',
#  'extraordinarily difficult time meeting exact demands requires feel like cant possibly ever graceful poised precise sifu',
#  'feel impressed share thoughts choice election',
#  'feel fearful know something',
#  'feel heartbroken insignificant',
#  'didnt feel horny started touching like',
#  'girl smiles feel pretty much nothing dull thud maybe within reminding lost humanity',
#  'feel want hurt small heart adults always tell still things know',
#  'feel groggy disoriented awhile daughter adisyn still wakes night',
#  'guess blood lot people feel nostalgic influenced',
#  'already feeling much lousy seriously need anyone give comments',
#  'im used feel determined lately almost easy',
#  'feel numb posted href http leslielandberg',
#  'feel hot breath',
#  'feel knowledge would abused',
#  'feel dumb',
#  'cant help feeling little dismayed cast thousands affair borne game remember vividly things sense restraint',
#  'feel least glimpse believe intelligent designer god face professional lives well beliefs',
#  'suspect need blog connected feeling knitting adventurous therefor blog worthy',
#  'im already feeling stressed salvaging friendship time goes realize theres also another point isnt helping',
#  'im still trying seriously feel helpless',
#  'im feeling bit overwhelmed stuff',
#  'try best feel hopeful live faith try stick',
#  'folks use stem sentences trigger thoughts sensory poems lines like happiness feels like happiness sounds like fill blank',
#  'believe every woman feel glamorous beautiful every day',
#  'ive feeling really frightened idea adoption home study approved dossier reviewed',
#  'went opposite today even though feeling fairly crappy',
#  'cant help feel little envious',
#  'little emotional didnt know maybe cause preparing day long like first memorial hmm sure feeling anxious',
#  'arrived home hot sweaty feeling keen need chinese food put aside morning',
#  'feel gentle tugging heart step faith allow god make way even see one',
#  'feel though lovely things manifest physical way welcoming home',
#  'feel beloved bogo getting bastardized',
#  'believe youre love unless feel completely helpless feeling',
#  'feel like probably nothing paranoid',
#  'ive feeling especially crappy lately disappointing time less intense symptoms',
#  'feel terrible guilt supporting pressed charges one guys',
#  'want son feel ok way',
#  'thinking unknown',
#  'feel like loyal fan one movies easy watch feel try watch',
#  'often get strong feeling longing oddest things oddest times like leaves changing crisp feeling fall air moms chocolate chip cookies apple crisp',
#  'feeling little melancholy last weekend holidays got back home got christmas decorations put away ready move new year',
#  'feel like selfish never trait carry',
# ...
#  'tell go back last woman dated could emotionally express would never tell feeling guys would thrilled girlfriend crazy',
#  'feel honored opportunity creating children outfits royal wedding stephanie said',
#  'made one important people life feel hurt',
#  'im feeling betrayed fall board delicious looking soups floating around pinterest days',
#  'feeling account might get pretty boring yall',
#  'feel one blamed others rely',
#  'feel disgusted im curious cares lien',
#  'im feeling quietly hopeful',
#  'need hours sleep night feel energetic throughout day',
#  'im feeling nostalgic ankle boots basically governed winter wardrobe',
#  'noticed mom dad brought home good news new job didnt feel anything clearly supposed feel ecstatic',
#  'feel clever good',
#  'told friend running feel awful run pace need drop back',
#  'even explain laugh smile feel amazing',
#  'feel comments listless fatigued spacey desire portrayed really generally',
#  'id also tell hate feeling complacent',
#  'get see last remnants night time im feeling creative time get see sunrise sign made another day must prepare another battle',
#  'feel defective crippled',
#  'feel ugly still take pictures',
#  'rarely subjected hair raising taunts people particularly men weaves wigs extensions feel need address unfortunate verbal abuse many black women endure choose extend hair',
#  'feel relieved confident things moving along best possible best guys get done',
#  'feel like perhaps havent considerate recently',
#  'indecisive want lunch feeling slightly agitated constant aching ribs tiny little feet feel permanently planted able understand weeks seem go sooooo slowly',
#  'post tweet update think whether feel someone either entertained informed educated say',
#  'spent last week feeling pretty bummed',
#  'feel calm complete whole meditate',
#  'could essentially feel like getting revenge something relationships valuable',
#  'pray every woman feeling helpless',
#  'asked feeling clever',
#  'feel like mother caring child',
#  'feel somewhat crappy work',
#  'feel hugely thankful lovely day',
#  'feel life vain dont',
#  'felt amazing got back fact didnt feel mentally tortured means happily go week week though dont want start hating',
#  'thought starting livejournal might serve way get unwanted feelings way release idiotic thoughts',
#  'feel honoured privileged invited witness history making',
#  'woke feeling hopeful',
#  'would go feel troubled someone would borrow shoulder cry someone would help wipe tears need someone would depend make smile',
#  'always feel sad people say days seem',
#  'keep feeling curious live life n guys live lives',
#  'least know good ones feels amazing find guy truly complements goofiness nerdiness craziness',
#  'im day register changing shape proven somewhat exhausting ultimately know deep body changing best possible reason absolutely nothing feel embarrassed sloppy',
#  'already know one truly feel tender heart feeling right',
#  'sit write sneak glances sweet gifts coffee table feeling smug valentine day forgotten know really awkward sixteen year old self feeling chuffed',
#  'feeling grumpy yesterday morning',
#  'feel pretty mellow',
#  'completely flattered brings full circle said earlier feeling strange',
#  'feeling far away place pretty cool',
#  'feel like cupcakes might getting bit popular good still love good red velvet im complaining quite yet',
#  'know better assume drunken people tell truth feeling trying compensate lack stories last years oh ive faithful annoying jappy girlfriend last years',
#  'dont know im better anything actually think stuff feel extremely discontent',
#  'im feeling peaceful',
#  'think see shigeru sicker feel agitated forgot water bird pitiful sight pecking little bowl cage reward upon waking little sleep morning',
#  'doubt guy friends would show funeral feeling morose',
#  'think feel little overwhelmed helplessness dependance upon',
#  'feel honoured associated work',
#  'sometimes feel like kids dont understand creative explaining things apply kids right',
#  'hate feeling defeated resigned shameful',
#  'cant wait meet little guy cant help feel little nervous big day getting close',
#  'feel like depth hell feel boring',
#  'feel festive next year',
#  'feel troubled sit love feast',
#  'admiring feeling delicate masculinity ring gives intrigued fact kris kristofferson guessed shriner',
#  'feel learn conducting still continuously getting positive feedback choir',
#  'feeling somewhat resentful making list symptoms first place wondering whether keep postponing going doctor made effort nothing',
#  'hate way feel hate grumpy tired sore throat every time cough hate feel like head literally going explode spot',
#  'know simple feelings startled startled though understand words feeling words overtones green ink suddenly say',
#  'started already feeling going unpleasant taste still recovering epoxy playdough bedpan',
#  'remember time left feeling apprehensive game view still hold',
#  'feel john ortizs character represents part us practices violent behavior fucked tendency within everyone even considered normal',
#  'recall day stepped campus attend orientation day feel innocent fresh dumb rough',
#  'already begin feel suspicious put theory test',
#  'feel reading online looking cute little vintage typewriters flags skipping part makes two people unique',
#  'feel like im nearly creative clients cake toppers',
#  'understand people get bad situations end real fault kind feel im keen ones support beg fund drug habbit even better pretend theyve got nothing',
#  'im feeling really dull headed nothing tell farewell',
#  'feel hated alw want show want tomorrow',
#  'didnt feel deprived wasnt obsessing times past going well',
#  'bend feeling uncomfortable awkward',
#  'feel much ashamed much embarrassed much proud ask help',
#  'think like able find anything feel reluctant start exploring cant find easily',
#  'feel like julie roberts pretty woman wears smart shorts suit polo match',
#  'bugged persons success feeling little jealous',
#  'mental check list things past year frightened kept trapped mind feeling hopeless',
#  'im feeling pretty disheartened',
#  'feel like im caught eye storm waiting violent wall come crashing',
#  'admit sometimes struggling feeling lonely overall think natural friend filtration process adulthood brings positive process',
#  'dont read traditions love much stranger opens door dont feel offended like trying send message rest world cant open',
#  'feel direction life find passion hold passionate something really time good',
#  'im type get cynical around hallmark holiday year happen feel particularly spiteful towards',
#  'feel like bit naughty side things eating biscuits cookies chocolate',
#  'feel despairing like rather dead',
#  'feel heartbroken quarrel dont show fb normally ppl would',
#  'feeling rather bouncy',
#  'feel embarrassed sad even beyond grave seem still working release latest posthumous album',
#  'believe feeling accepted non judgemental way healing',
#  'feel honored creative couples like connects work able put trust deliver creative final product',
#  'wonder topic often talk riddles metaphors sometimes takes forever get point reading lines begin feel confused agitated annoyed dont worry youre perfectly normal',
#  'look toreador usually see toreador looking turn glare face feel contempt vile existence',
#  'mean extremely normal feel emo kinda romantic realistic heartbreaking movie',
#  'feel helpless scared things cant describe never thought control freak im recognizing feeding feelings way control something midst chaos',
#  'enjoy watching show makes feel like part glamorous group',
#  'feel graceful',
#  'feel capture beauty ugly forms concrete metal blocks flats',
#  'got home started thinking started feel homesick duplex silly',
#  'person sometimes feels jealous sometimes feels happy sometimes feels sad excited afraid angry confused',
#  'havent feeling fine work',
#  'feel like gave good fight proud performance',
#  'feel like generation men family guy suburbs midwest feel like little bit lost says heimbuch documented search midwestern hunting roots soon released book shall manly things',
#  'feel unloved unappreciated unwanted',
#  'feel incredibly impressed honoring process able honor',
#  'stand line sanctuary hear words body blood feel something worthwhile still gathering together sent',
#  'would never feel ok low point laying head toilet ring throwing wanting die',
#  'woke feeling lousy worse normal everyday lousy',
#  'feel lucky know minority',
#  'feel longing spend time silence sometimes retreat house even home',
#  'feel intimidated write acceptance speech',
#  'want talk limited time phone current arrangment feel hesitant bring',
#  'feel since much considerate loving toward',
#  'could teach trying avoid sometimes feel like art majors learn art become art teachers teach art vicious cycle people teach art people eventually teach art people',
#  'feel ppl friendly except',
#  'would wait good day id go feel ok today ill go record',
#  'feel mellow wierd inside',
#  'hurting feeling hot',
#  'feel suspicious',
#  'woke middle night feeling utterly disorientated frightened extremely upset',
#  'im feeling popular even though let go',
#  'feel like rut like worthwhile endeavor takes bit time keep thing going',
#  'im feeling generous restaurant like mandarin grill fairly stellar reputation impression may extended edible yet decorative garnishes like samphire',
#  'wish told beforehand wouldve dressed little feel somewhat place casual ita lolita skirt navy hoody xd im still glad taken',
#  'get caught world stop seeing around stop feeling gracious giving',
#  'feel pesimistic bitchy try act',
#  'im going service career much feel disillusioned still hold hope naive belief small group people ive met others different',
#  'feel extent missed point friction',
#  'couldnt help feel useless caused accident yet people clear impact left behind',
#  'didnt grab anything small could still feel tender positive movement good thing',
#  'feel life hopeful href http snowinfall',
#  'feel like youre ashamed seen public im bigger',
#  'exhausted last night feeling hot today',
#  'laid thick mattress pad king size bed start feeling little apprehensive count sheets',
#  'feel fearful realize means bit uncharted territory necessarily know outcomes consequence happen next',
#  'feel vulnerable strengthen defences',
#  'really feel like im actually hated',
#  'hate feeling unimportant feeling stupid',
#  'feeling combination rock voice kim yoon ah may sway people keen kpop',
#  'didnt mean forget even though feel remorseful everything still refuse say day go work earn money day thing true tomorrow sli oh joy',
#  'see feel contented',
#  'id plan two three activities day feel rushed',
#  'feel extremely remorseful',
#  'feel really lethargic headaches opposite constipated faint sick sometimes yesterday drinking normal amount water started getting really sharp pains stomach',
#  'enjoy feeling find become complacent emptiness',
#  'feeling excited proud even finishing started',
#  'feel like know apart supportive things like clean cook iron etc',
#  'apprehensive go still feeling quite low fighting cold top',
#  'walk pub london feel frightened',
#  'ability read eyes keeping eye contact way really getting feel whether person sincere',
#  'feel sure even though polka dotted panties black see wet becoming',
#  'look believe look good feel bad',
#  'feel almost needy kinda afraid coming strongly',
#  'ive gained lot im feeling disgusted',
#  'feel much carefree posting',
#  'feel bit ashamed human learn kind senseless cruelty wanton possibly irreversible destruction',
#  'feel bad categoria href http cursodecarretillero',
#  'feel though grasp honesty less sincere everyones words actions seem',
#  'feel horrible done',
#  'feel project successful completely encompasses personality demeanor relationship',
#  'feel awesoem bouncy energy desired',
#  'feel essay well researched great learning experience ways one',
#  'seem feel uptight isnt devestating afterall',
#  'wayne sue close friends announced guardians ther wedding',
#  'feeling told surprised everyone well considering everything body gone monday',
#  'didnt read book day long time feel peaceful href http twitter',
#  'feeling really creative use ga raspberry colored product flushed look add dabs make natural',
#  'ive feeling lately specifically since got back beloved hometown lydenburg',
#  'need start going meetings feel im alone feeling crazy right',
#  'last melbourne already feeling nostalgic looking posts wrote',
#  'think us would feel uncomfortable wars deny countries independence wherever might',
#  'feel embarrassed placing bottle cooled boiled water table',
#  'feel respected accepted despite lack knowledge everyone person',
#  'feeling dissatisfied amoun',
#  'feel less foolish putting whole self',
#  'woke feeling determined entire hour hiit without backing',
#  'feel see feeling slutty whatever cleavage showing etc',
#  'guess time start feeling festive',
#  'find feeling melancholy lately',
#  'feeling many us surprised see coming bit realism stanford part early years might useful',
#  'feel passionate women empowering lord',
#  'remember back always feel like friends afraid tell something might get angry',
#  'feel smart wearing like easily casual dressy changing shoes',
#  'feel terrible even thinking things even worse putting writing guess feelings never wrong bad actions count',
#  'im tired feeling im funny enough smart enough talented enough good enough',
#  'know im trying make someone turn new chapter feels like u supporting whatever hes',
#  'almost feel thankful year ever',
#  'feel friendly front squat lately',
#  'forgot used feel playful like little dog would jump around bed fall throw legs laugh',
#  'feel completely ignored',
#  'always idea love would feel like hypothesis met schuyler id never felt intensity relationships observations supporting null hypothesis',
#  'feel morsel pissed plunked money reckon pay per view left mad lost small empty',
#  'mentioned earlier many feel god given command teach people obey matthew believe faithful take message whole world held personally responsible eternal deaths others',
#  'guess makes feel little dangerous',
#  'always woke feeling groggy fingers ached',
#  'feel assured told islam abuse power corruption soul commitment integrity dignity human kalbu heart',
#  'feel like glamorous assistant one batons hits head',
#  'feel obscurely proud creativity glory association others find faintly depressing',
#  'feel like im defective unable perform always fighting taunts disbelief',
#  'feel horrible',
#  'feel though eusa really supporting us',
#  'feel vital impart lord bridlington miss travers fianc eacute awayed find betrothed effect reconciliation',
#  'also noticed sharing deepest fears embarrassing feelings became extremely submissive style communication',
#  'hope enjoy feel offended',
#  'feel whats going pleasant',
#  'feel like need hair dog saw headline johnny bairstow england team wasnt impressed',
#  'started dabble files havent done anything cross yet hard list anything specific ive done yet feels bit productive since like daydreaming stimulated ideas joggled memory',
#  'started symptoms interpreted diabetes least pre diabetes numbness extremities decrease mental function depression feeling lousy',
#  'feel well pain others still trying child',
#  'feeling burdened',
#  'shook hand feel impolite',
#  'feel zombie like irritable',
#  'im talking one game words friends feeling adventurous decide play searching random opponent',
#  'feel becoming enraged people office laughing like obscenely loud hyenas trying work',
#  'feel annoyed ask persons go specific information regarding lesson plan answer received entire semester late nov',
#  'made decision blog less feel like gain control feels amazing',
#  'im tired walking around bruised ego feeling humiliated im creative',
#  'feel fucked tape last year make sure get',
#  'prepare feel thankful events touch upon many different concerns poetry language issues pacific aesthetics avant garde eco poetry',
#  'feel honoured happy going way want thank players fans media',
#  'helpful feel respected felt way',
#  'feeling really whiney days ago',
#  ...]

# %%
emotions_cv = CountVectorizer(token_pattern=r'[^\s]+', max_features=7500)
emotions_X = emotions_cv.fit_transform(emotions_text).toarray()
emotions_X.shape
# Out:
# (50001, 7500)

# %%
emotions_x_train, emotions_x_test, emotions_y_train, emotions_y_test = train_test_split(emotions_X, emotions_y, test_size = 0.25)

# %%
emotions_model = MultinomialNB()
emotions_model.fit(emotions_x_train, emotions_y_train)
# Out:
# MultinomialNB()

# %%
emotions_y_pred = emotions_model.predict(emotions_x_test)
accuracy = accuracy_score(emotions_y_test, emotions_y_pred)
accuracy
# Out:
# 0.863290936725062

# %%
# Six categories: sadness (0), joy (1), love (2), anger (3), fear (4), and surprise (5).
message = "This Sucks!"
prediction(message, emotions_model, emotions_cv)
# Out:
# array([[0.43022887, 0.16808946, 0.10338223, 0.15828618, 0.1120438 ,
#         0.02796946]])

# %%
emotion_model_filename = "emotion_model.pickle"
pickle.dump(emotions_model, open(emotion_model_filename, "wb"))
emotion_cv_filename = "emotion_cv.pickle"
pickle.dump(emotions_cv, open(emotion_cv_filename, "wb"))
