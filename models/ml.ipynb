# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import random
import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zroy1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
chat_words = {
    "AFAIK": "As Far As I Know",
    "AFK": "Away From Keyboard",
    "ASAP": "As Soon As Possible",
    "ATK": "At The Keyboard",
    "ATM": "At The Moment",
    "A3": "Anytime Anywhere Anyplace",
    "BAK": "Back At Keyboard",
    "BBL": "Be Back Later",
    "BBS": "Be Back Soon",
    "BFN": "Bye For Now",
    "B4N": "Bye For Now",
    "BRB": "Be Right Back",
    "BRT": "Be Right There",
    "BTW": "By The Way",
    "B4": "Before",
    "B4N": "Bye For Now",
    "CU": "See You",
    "CUL8R": "See You Later",
    "CYA": "See You",
    "FAQ": "Frequently Asked Questions",
    "FC": "Fingers Crossed",
    "FWIW": "For What It's Worth",
    "FYI": "For Your Information",
    "GAL": "Get A Life",
    "GG": "Good Game",
    "GN": "Good Night",
    "GMTA": "Great Minds Think Alike",
    "GR8": "Great",
    "G9": "Genius",
    "IC": "I See",
    "ICQ": "I Seek you",
    "ILU": "I Love You",
    "IMHO": "In My Honest/Humble Opinion",
    "IMO": "In My Opinion",
    "IOW": "In Other Words",
    "IRL": "In Real Life",
    "LDR": "Long Distance Relationship",
    "LMAO": "Laugh My Ass Off",
    "LOL": "Laughing Out Loud",
    "LTNS": "Long Time No See",
    "L8R": "Later",
    "MTE": "My Thoughts Exactly",
    "M8": "Mate",
    "NRN": "No Reply Necessary",
    "OIC": "Oh I See",
    "PITA": "Pain In The Ass",
    "PRT": "Party",
    "PRW": "Parents Are Watching",
    "ROFL": "Rolling On The Floor Laughing",
    "ROFLOL": "Rolling On The Floor Laughing Out Loud",
    "ROTFLMAO": "Rolling On The Floor Laughing My Ass Off",
    "SK8": "Skate",
    "STATS": "Your sex and age",
    "ASL": "Age Sex Location",
    "THX": "Thank You",
    "TTYL": "Talk To You Later",
    "U": "You",
    "U2": "You Too",
    "U4E": "Yours For Ever",
    "WB": "Welcome Back",
    "WTF": "What The Fuck",
    "WTG": "Way To Go",
    "WUF": "Where Are You From",
    "W8": "Wait",
    "7K": "Sick Laugher",
    "TFW": "That feeling when",
    "MFW": "My face when",
    "MRW": "My reaction when",
    "IFYP": "I feel your pain",
    "TNTL": "Trying not to laugh",
    "JK": "Just kidding",
    "IDC": "I dont care",
    "ILY": "I love you",
    "IMU": "I miss you",
    "ADIH": "Another day in hell",
    "ZZZ": "Sleeping bored tired",
    "WYWH": "Wish you were here",
    "TIME": "Tears in my eyes",
    "BAE": "Before anyone else",
    "FIMH": "Forever in my heart",
    "BSAAW": "Big smile and a wink",
    "BWL": "Bursting with laughter",
    "BFF": "Best friends forever",
    "CSL": "Cant stop laughing"
}

# %%
def clean_text(text):
    
    text = re.sub(r"[!@#$(),\n%^*?.'\:;~`0-9]", '', str(text))
    text = text.split(" ")
    for i, word in enumerate(text):
        if word.upper() in chat_words:
            text[i] = chat_words[word.upper()]

    text = " ".join(word for word in text).lower()

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text, language='english', preserve_line=True)
    text = " ".join(word for word in word_tokens if not word.lower() in stop_words)

    
    return text

# %%
def prediction(text, model, cv):
    text = clean_text(text)
    X = cv.transform([text]).toarray()
    return model.predict_proba(X)

# %% [markdown]
# # Positivity Dataset

# %%
filename = "positivity.csv"
positivity = pd.read_csv(filename, encoding="ISO-8859-1")
positivity
# Out:
#        Unnamed: 0  sentiment          id                          date  \
# 0               0          0  1467811184  Mon Apr 06 22:19:57 PDT 2009
# 1               1          0  1467811594  Mon Apr 06 22:20:03 PDT 2009
# 2               2          0  1467812964  Mon Apr 06 22:20:22 PDT 2009
# 3               3          0  1467825863  Mon Apr 06 22:23:43 PDT 2009
# 4               4          0  1467826052  Mon Apr 06 22:23:45 PDT 2009
# ...           ...        ...         ...                           ...
# 49995       49995          1  2193552981  Tue Jun 16 08:36:49 PDT 2009
# 49996       49996          1  2193554410  Tue Jun 16 08:36:56 PDT 2009
# 49997       49997          1  2193576655  Tue Jun 16 08:38:46 PDT 2009
# 49998       49998          1  2193577315  Tue Jun 16 08:38:49 PDT 2009
# 49999       49999          1  2193577918  Tue Jun 16 08:38:53 PDT 2009
#
#            flag            user  \
# 0      NO_QUERY         ElleCTF
# 1      NO_QUERY            coZZ
# 2      NO_QUERY  lovesongwriter
# 3      NO_QUERY    BrookeAmanda
# 4      NO_QUERY     paulseverio
# ...         ...             ...
# 49995  NO_QUERY       JDenouden
# 49996  NO_QUERY      Arr0wsmith
# 49997  NO_QUERY       eratyptin
# 49998  NO_QUERY        jamie_ox
# 49999  NO_QUERY    milliontwits
#
#                                                     text
# 0        my whole body feels itchy and like its on fire
# 1      @LOLTrish hey  long time no see! Yes.. Rains a...
# 2      Hollis' death scene will hurt me severely to w...
# 3      i really hate how people diss my bands!  Trace...
# 4      Why won't you show my location?!   http://twit...
# ...                                                  ...
# 49995  @NLPride08 that's a perfectly reasonable time ...
# 49996  @Jihav actually my other PSN ID is GUNSnSPEEDO...
# 49997  @siahoney I am good thanks!    How is #Eric, I...
# 49998  doing another piece of media homework is that ...
# 49999  @stum450n Hi. Thanks for the follow. Nice webs...
#
# [50000 rows x 7 columns]

# %%
positivity_X = positivity["text"]
positivity_y = positivity["sentiment"]

# %%
positivity_texts = []
for text in positivity_X:
    positivity_texts.append(clean_text(text))
positivity_texts
# Out:
# ['whole body feels itchy like fire',
#  'loltrish hey long tears eyes see yes rains bit bit laughing loud im fine thanks hows',
#  'hollis death scene hurt severely watch film wry directors cut',
#  'really hate people diss bands trace clearly ugly',
#  'wont show location http//twitpiccom/yes',
#  'kpreyes remember bum leg strikes back tears eyes serious',
#  'ozesteph shame hear stephan',
#  'caitlinoconnor want tacos margarhitas telll gay say hello & lt',
#  'missing best friends forever watching home away reminds & lt shout courts',
#  'chriscantore congrats im totally jealous wish xm working',
#  'marge_inovera tried tweetdeck hated passion hated im sure',
#  'danadearmond',
#  'trolley packed like sardines padre game remove car good call mts',
#  'mamasvan laughing loud - nope complete camerafail',
#  'b_barnett really see coming',
#  'nicolerichie oh yes miss',
#  'eazydoesit negative lost vote confidence',
#  'sofii_noel thatã¯â¿â½s bad',
#  'crap need dresses',
#  'huuuge headache omg feel like crap',
#  'dammit need stop buying furniture',
#  'ill cant go cinema',
#  'marybethune oh everything happened today forgot going dress shopping opera tomorrow',
#  'chordsy - last find things like youre twitter',
#  'photoshop hate crash',
#  'four games fall modern warfare halo odst brutal legend bioshock need cash',
#  'miss home calving seasonsad black one died morning wish bottle calves',
#  'heidimontag wish would get tears eyes rest world unfornately cairo wait mtva play',
#  'home spring break one home tho',
#  'winggato free comp laughing loud',
#  'crying friend moving away tomorrow',
#  'good morning everybody pkoi fais pas beau bon coffee tears eyes',
#  'vernonhamilton youre stranger',
#  'smokey_robinson fell listdid offend',
#  'feeling well stupid migraine making tummy upset whole body aches shoot',
#  'dog cant move anymore praying okay',
#  'mhm good day blah blah blah',
#  'sensesdestroyer wan na go lamb god',
#  'onlysweeter dont know dance',
#  'sigh rain decide show move away invited tuesday-party start hoped',
#  'lanarisque hahahahhha hows food poisening going gone away',
#  'woke hour ago im hard tears eyes going back bed lakewood ca http//looptus/rywlhq',
#  'work w asma nawal fe obeerate alwatan tv',
#  'avisionofbeauty phone doesnt like sorry',
#  'thanks chaffie thousand apologies please fogive sinned',
#  'itschelseastaub goodnight chels sorry major layout-delay & lt',
#  'morning v groggy morning',
#  'tried fix hubbys computer didnt come disks windows key wont work might buy like afford',
#  'tired leave bed',
#  'beginning enjoy lazy town - oh dear',
#  'wyldceltic oh man sad ever',
#  'aholmes_nj able downthemall ta able delete account didnt lose photos lost almost comments',
#  'bkgirlfriday dude snowed todaycant imagine weather hawaii right',
#  'theajp glad enjoyed mate gigs lined near future none horizon mo',
#  'got denied letter bazaar bizarre sad looking forward road trip vendor',
#  'schnicklefritz omg problem lent someone never gave back',
#  'arielehenriques feel like preaching laughing loud damn im guilty',
#  'oh em gee love http//tinyurlcom/djjc want want want lusting things afford',
#  'jamzeee knowwwwww sukkkk take care gurls',
#  'iwouldificould watched tried youtube link wont work',
#  'realized im talking one',
#  'downy weather wheres summer',
#  'pose ta b goin ta az dis week hope laughing loud',
#  'tired need regular -',
#  'journalist throws shoe chidambaram http//ibnliveincom/news/journalist-throws-shoe-at-chidambaram/-html',
#  'went doctors today blood sugar level',
#  'shelikescute thats sad',
#  'sick today lot work',
#  'oh darnits mandy creed isnt jordar mikerra',
#  'common chidambaram george bush http//newsoneindiain////sikh-journalist-hurls-shoe-at-p-chidambaramhtml',
#  'still waiting missing baby boy',
#  'cant sleep im stressing jpc & lt',
#  'liking back work morning',
#  'feeling really really ill',
#  'also want easter break / pã¯â¿â½sklov',
#  'nobody likes leatherhead',
#  'beeeaaach',
#  'sucked heather sewage bath xp poor owen bear total drama island',
#  'sickness making impossible sleep hot',
#  'cant sleep wondering following keeps going guess got ta try interesting haha',
#  'kremsersenf away tubingen germs yes away friends much',
#  'awww ellie sounds sick poor thing',
#  'episode house cuddy hook apo meetings fault',
#  'wants use -directional dance pad pero di compatible sa tv yung game http//plurkcom/p/nhyu',
#  'morning im baggered gym work later',
#  'knotserious oh btwdjrocko & amp tried go cuban buffet told aboutso excitedits closed mondays sad story',
#  'bnish dan grabbed yardhouse earlier didnt pirate disappointed',
#  'robertzalme yes much theory getting much solutions coming',
#  'mean nobody goes anymore x',
#  'ugh mum wake early geesh need sleep princessnadysthere noth awww',
#  'got offer go camping fraser island weekend would jump offer without nd thought forecast rain',
#  'insomnia headache',
#  'mckayla_jb hey laughing loud way know upload picture tried never shows xo',
#  'jona_thin sorry must left corel install cd somewhere room',
#  'got amazing new pedal blew speakers',
#  'still waiting dispatch got hour ago sleeping hours guess ill go back bed',
#  'entered online poker tournement others finished th',
#  'really sleeping already cant seem get bed sun comes progress sorting life slow+hard',
#  'ryuoky sun hoping sit balcony',
#  'hrs need go quick',
#  'youve failed',
#  'get mine iã¯â¿â½m going tour copenhagen ã¯â¿â½ hmmph cant top must get thinking http//tinyurlcom/ctrgj',
#  'fragilemuse book awesome great works couldnt afford buy today tho',
#  'kev_nz laughing loud better let aboy know hes deploy bedtime hope feeling better sick sux',
#  'childrensjewell damn annoying happens isnt hope doesnt copy work',
#  'guess go bed hours havent able sleep lately stressed website done yet',
#  'pigman love cooler trenchcoat weather dnw darker evenings scary run night',
#  'hopeok soon -dies-',
#  'found nice lake-side park small beach grills oh well ill keep looking - another tears eyes',
#  'erickaaa im workkkk im freezing need mass hug call night babe xxx',
#  'delay',
#  'wet hair eyes',
#  'coffee going twitter facebook social networks seems become full tears eyes job keep',
#  'joypalmer wake think ah yes thats mice running around ceiling',
#  'moving managerial finance nicht gut',
#  'work plus im sick blah',
#  'incrediblesteve cold turkeys way know',
#  'morning gone',
#  'cant sleep frustrating',
#  'eating lunch forgot get home cooked food morning',
#  'ohdatsbeezy - dont mind behind follows',
#  'wellreadkitty oh poor thing used ot love squeezing pus vet nurse kinda gross really',
#  '& quotwho favorite vintage designer & quot lucy & quottopshop & quot miss cycle britains ntm',
#  'honey_ nasty reports flooding yet multiple reports bad hair wet pants however',
#  'mfarnsworth retired tears eyes done mate',
#  'absolutelybatty hugs back thanks hon cant believe hes gone',
#  'wish going melbourne wkend harlot house tramp',
#  'mmmm chocolate cupcake lorraine kellys fault know cakestand full cupcakes im getting hooked',
#  'whats world ppl decide shoot others watching news depressing',
#  'zeenav sims shut',
#  'nikkiwoods thinks bust day late overslept still keep entertained w/o perving laughing loud',
#  'oh gosh messy hair',
#  'think dead',
#  'seriously freaked outfuzz',
#  'kymhuynh hahaha yeah laughed way end sick',
#  'going deaf right ear many feedback squalls soundchecks earplugs',
#  'squink oh yay means ill get soon & gt_ & gt never used suffer year gets worse',
#  'cutting grass dad hayfever',
#  'xbox died stress relief depressing middle moving new apartment ugh someone cheer',
#  'arrrrrrgh havent saved file',
#  'oh babysitting love springs morning cant object',
#  's_eisbaer face',
#  'groat feels like getting sore',
#  'flat iron melted glasses',
#  'unlock espresso',
#  'yawn got getting ready school',
#  'got home school long day school today',
#  'preparing quotes day tiring job',
#  'emmabush well didnt mention stale peeps',
#  'j_e_p',
#  'im feeling ecstatic met james matthews josh wilkinson got james towel xd maan ears still ringing throat hurts',
#  'mileycyrus god blizzard',
#  'shame processing pics isnt much fun actually taking',
#  'pm asked teacher speak project said noo happy might spewed',
#  'finally back track studio lost cubase dongle miami',
#  'spring tears eyes http//twitpiccom/yagh',
#  'car sucks bad week get car taken away',
#  'binxy thanks started sniffling like crazy gym today boohoo lots vitamin c trick',
#  'sheamus chance switch bitly tiny url cant read links work bitly gets stopped malicious',
#  'amazingphoebe guess / ima still hell fucked nights regardless guess',
#  'back school papers',
#  'gahhh twitter app fails',
#  'early school ugh',
#  'know dont people put lack spelling ability looked couple posts messed word',
#  'tessaschraven sure would work fly west want though',
#  'silverwind aw sucks',
#  'trip castle turned mile round trip kids sick back car',
#  'jutecht btwloved baseball postthis definitely best tears eyes yearwas disappointed red sox opener rained',
#  'http//twitpiccom/yb - eggies sister parents im sure im gon na get back',
#  'smart start + = chipped tooth',
#  'hello tweetershavent much latelytoo busy hope well',
#  'watchin candy girlswhy cant b videosux dey mainly use american girls',
#  'procrastinator perfectionist terrible combination university',
#  'joanneskywalker really depressing teases working fine try save people created hell ahh',
#  'im wearing black socks =o haha pretty random im bored tired nigel',
#  'davtoole cant bring watch film sheffield united',
#  'sitting jury duty',
#  'im un-realisticly gutted cant go download year see papa roach',
#  'sydney rail advertising http//twitpiccom/ybkw graduate programs railways first choice alas ended fashion',
#  'blehdidnt wake tears eyes leave work early chiropractor',
#  'work late night watching game state lost',
#  'tigger lost bounce',
#  'animatic project done got positive result write page report days gon na fun',
#  'ive thinking getting blackberry iphone something sucks year contracts',
#  'waiting go dentist wondering flippin cold gon na go feel poorly',
#  'donniewahlberg word street & quotface time & quot worth individual pics rush rush rush',
#  'kdfw girl suitcase story messed cant imagine anyone something like',
#  'schedules messed gaaak many deadlines looming horizon',
#  'see snow outside im sick ohios weather years till move palm springs camissing weather',
#  'fave hairdresser still isnt back hope dont get rubbishy cut friday somanydeadends & gt_ & lt',
#  'ugh dont feel good morning hope goes away',
#  'one bunnies died today wasnt fault wasnt fault',
#  'buttload worki wish people hated cars',
#  'im miss dad',
#  'happy birthday rrdad bad also travelling today',
#  'im going lose followers one tweet laughing loud',
#  'lovely avacado bacon chicken baguette - tears eyes work',
#  'honkpeace never received dms last night twitter hacking lung something',
#  'rockinrita plans fell meet',
#  'woke upanother hour shift today started pally last nightshe kicks butt',
#  'throat killing',
#  'still center lincoln wandering aimlessly round shops wish cud think something iphone running slow',
#  'twitter wound',
#  'fever cold cough sunburn',
#  'rotting_orange im sorry job going away',
#  'ababyblueeyes yea call stress',
#  'work',
#  'tired get ready school',
#  'val dor waiting wife youngests flight leave long drive chisasibi',
#  'looks like going nice day lynchburg today bad im sitting class right',
#  'research report due five library trying get finished',
#  'hot outside ice cream tears eyes whats catch bees annoying',
#  'lauraechilds enjoying far far much',
#  'noxhanti almost quite uncanniness rampant luddism might put paid replicants theyre even built',
#  'got go sux cant text cant text am-pm ill text people later today may blogtv sure',
#  'uughhhh back work help please',
#  'rewy looking like',
#  'looking forward writing - word essay history next week stupid exam essay worth im scared',
#  'bebosore tummy',
#  'good big headache dont feel well',
#  'michellev ok hope make',
#  'feeling good morning im hungover laughing loud takes two glasses wine',
#  'babysittin stupid lil sister wen actually shud friends enjoyin weather think im jokin',
#  'english bummer',
#  'really miss & quotreal & quot college def vibe hair school',
#  'ok get serious im poking nose trying find green cant find none',
#  'missnappyboy sucks havent outside yet love cold inside outside',
#  'headache still splitting head open th day row',
#  'day two training tech doesnt even know ctrl-c hes probably lasting',
#  'charmer said aint ready yet asthma beign cautious',
#  'nohorob ack goddammit denton get good defect best alliance something',
#  'woke late today hour laughing loud school ready portfolio',
#  'kio_redsen people like work weekends though wednesdays good',
#  'started rain naw wales',
#  'sony ericsson w something seriously wrong decide want send texts tears eyes dont want',
#  'jason_nott http//twitpiccom/ybib - sorry bad weather hate hope still good tears eyes ohio',
#  'often feel like im going panic attack register classes',
#  'consumed nothing feel im everything im lost twisted paths made',
#  'think spring pink slipped',
#  'truck went shop denver leaking radiator fluid student prolly gon na stick thru likee da lifestyle',
#  'thinks going watch wall-e tonight since nothing else',
#  'jonathan_hlibka late insulted construction worker gave attitude walking wrong direction queen/yonge',
#  'guess wasnt meant happen',
#  'squarenails yep yep certainly child-friendly hk wide pavements tricky maneuvers strollers air gd',
#  'got th longest trip back train ever london tired',
#  'havent home since xmas break lm lil homesick faithhopelove',
#  'money hid golden square long gone',
#  'school need get zone game livermore today',
#  'adders -have asked bitly inaccessible im unable read articles readers tweeting',
#  'thinking hate yankees - dont im yankees fan losing orioles less',
#  'gets take math classes computer science class education class next semester',
#  'sleepy boy starts dont agree',
#  'tears eyes day got back tears eyes tired skint good news bank may watch another zombie film',
#  'royalbluestuey haha little scared public stage eh love like travel dont get chance often',
#  'mege hows beach retreat wanted go mi madre said',
#  'sparkledonkey second started posting moving subscriber section thought guys',
#  'wickedtrue boo work unrelated news get highly-paid roommate contact sent email last week response',
#  'im getting really lazy twitter updating',
#  'rock fore dough tonight & amp im missing cant wait til friday ill actually augusta ps - happy birthday eve laurob',
#  'somebody go give dad hug feel like hes grumpy days',
#  'kids still little sick im getting going light school today get lots rest',
#  'feel worn tuesday',
#  'chin-ups dont know another set',
#  'http//twitpiccom/yii - q key broke',
#  'average industry ã¯â¿â½nilla porno doesnã¯â¿â½t even start around coffee table anymoreã¯â¿â½ hell',
#  'ive bed since saturday tuesday',
#  'cigerates petrol c bollix petrol dont care cigs',
#  'getting ready work blah tuesdays suck hope ur tuesdays better',
#  'mardhiah read ohnotheydidntlivejournal sure true ill sad',
#  'hope reach home ajeesh sings super singer missed ydays episode heard sang really well',
#  'light cold hoping go away soon worried instead become heavy cold',
#  'sitting morning class crashing fast hate',
#  'looooooooooong day home chillaxin shane',
#  'slept months body always making get whyyyyyyyyy',
#  'want touch heiney',
#  'hate make joke one laughs feel funny',
#  'cant veda video today cause flipcam batteries',
#  'loooooooooong day work today home chillaxin',
#  'mã¯â¿â½nh chng mun ngh n vic chng ly / nã¯â¿â½y http//afamilychannelvnnet/tmca/phim-hay-vtv-co-dau-chay-tron',
#  'wickeddisney laughing loud loves us wonder shes going europe',
#  'soooo feeling good suckss',
#  'im lonely keep company female decatur - alabama',
#  'homework',
#  'lyokamoto hey girly left sunset wish got updates phonebut lets hangout one days',
#  'kayleighs service tomorrow ugh text morning miss bestfrannnnnnnn & lt',
#  '_kelli sure im thankful much research horizon bottom cows sunnysideraleys wholefoods cows',
#  'way airport saying bye kids soooo hard',
#  'thinking practicing posing routine worried im body oil',
#  'laugh ass dont get twitter stuff going work soon love savannah',
#  'wish could make work disappear snap fingers',
#  'eerland something air edy woke bit ago wimpering sleep go soothe quietly cried',
#  'aww one lil chicks yawned going home tomorrow',
#  'im lonely keep company female duluth - minnesota',
#  'coachdeb loving randomfacts tell us - cant dm - dms broken twitter weeks see cant send',
#  'way lakeview really sad couldnt make ifightdragons concert',
#  'iamjulito tatauc im smut know',
#  'im really mood rp everyone dies',
#  'brookandthecity cant wait miss yal soo much',
#  'woverton ive couple days hope hours',
#  'officialashleyg heath ledger rip',
#  'watching larry king live cable went booohoooo',
#  'ahhh celebrating success week found new suppliers must-have items old suppliers quit supplying',
#  'mcrmuffin thanks always need talk',
#  'woke pm philippines hot im sweating hell',
#  'wont go back kfc kfc failed ordered usual fave guy suggested & quotspecial & quot instead yum',
#  'day looking something new wear birthday next week absolutley luck',
#  'didnt well id hoped earthday footprint quiz http//earthdaynet/footprint/flashhtml - earths',
#  'edward cullen bã¯â¿â½la lugosi spinning grave',
#  'ate bean cheese dip tacos dinner sleeping next steve stinky',
#  'winkler tomo get',
#  'yankee doodle went town ridin aww miss wild n',
#  'cant keep girl im sorry',
#  'still sick feeling weak cant enjoy beautiful spring weather',
#  'boyfriend decided depress putting paradise lost',
#  'shithole awesomelife guess night crapper',
#  'mackenziefox sun doesnt wan na come today',
#  'hoping next weeks go fast left & amp already miss',
#  'sigh csk youre screwed',
#  'sometimes wonder money goes',
#  'really want go thunder today dog going crazy cant leave day long & quotm boooooored',
#  'dandy_sephy close friends family im afraid im work colleague',
#  'nawong go getting access idzrorg im dying try',
#  'bummercant get see bf sing ernie els gig guess dog pockles tonight',
#  'crapi think ive caught wifeys virus',
#  'sunny day today yay = ] still cold',
#  'expect chen super kings wud start dis season wit loss cmon ms',
#  'misscasey bummer',
#  'received least phone calls today already telemarketers',
#  'daughter isnt starting day right tried prom dress & amp doesnt fit gained little weight',
#  'custardcuppcake hand clapping usual reaction dancing',
#  'nooooo one day holiday left still much work',
#  'getting ready work next days move im missing baby much',
#  'neti pot following directions = massive sinus pain congestion yesterday drainage/bronchial cough today',
#  'ugghhwhy awake',
#  'hungover hurting real bad',
#  'gunkanator ugh horse sight well one thats mine least neighbors frown stealth riding',
#  'feel like crap',
#  'uncle grandma car crash uncle going jail dui hit run',
#  'cant sleep anymore ugh',
#  'red ant bites really smart',
#  'good game - morning - warned - mikeyy back - careful - one ppl following infected',
#  'thatã¯â¿â½s call & quotsuboptimal & quot sat night going friend study exam till fall asleep somebody please cheer',
#  'caved',
#  'djedub dats wasup bein mean talkin cares mean',
#  'scottmonty wishing official sxsemia ford car stuck crappy dodge charger rental',
#  'shit im sick',
#  'hollywills come north see us',
#  'sisky yeeee \\o/ work mins waahhhhh',
#  'today crap drawing day dont want one done day horrific gets worse every day boring',
#  'http//picim/q - sunset iphone',
#  'skimud sorry upside weather says snow day today georgetown co clear tomorrow & amp partly cloudyhave good day',
#  'markbrooke im sorry mark shoots today luck',
#  'mcunclebuck sad hope feel better',
#  'want relax',
#  'brianmckinney bunch good places mass blocks im looking im stuck lease august',
#  'reedoh laughing loud team already played lost da week x nice chill got busy day moro making da xx',
#  'best figure tweet trying upload photo',
#  'briggysmalls - wont able make got stuck running around pint ill see monday go gunners',
#  'wants go downtown take photosbut one hang',
#  'see later - tears eyes move work dont smart phone carry around send tweets run',
#  'kcinwpb depressing im ok morning',
#  'plaintruthiness first final days',
#  'coachyeomans yes',
#  'trying trim big laptop use least amount power still look ac soon',
#  'stonedsteve alas live connection moment pc got sick landline dell mini needs sorting',
#  'officialtila well sucks im near la',
#  'massive lag times wow lame',
#  'richelle feeling well staying home tend wifemissing barcamp orlando today',
#  'im missing friends & amp instead watching dora explorer - prefered mickey mouse',
#  'melaniengzuer - exactly could',
#  'petewentz guys better play tonight dont want stand rain nothing',
#  'last day freedom going back jail tomorrow hahaha aka school',
#  'first saw ingeous pouncer immediately thought demonic apprentice one made cant fit',
#  'nath_girl haha im brazil cant speak spanish sorry',
#  'soo sick revision sucks',
#  'reverendvince great show last night got late see fuckin lights bright',
#  'sherrieshepherd hi sherri love daughter diabetes shes almost love said someone needing today',
#  'tinkugallery hey amrita dont think ill get see today sigh',
#  'donniewahlberg im sick im chilling happy',
#  'laying bed ill wishing hot nurse girlfriend would come make better',
#  'justsara great daughter trying figure college go photography looking boston far away',
#  'angiekramer oh english beat really bad wanted go couldnt',
#  'ate last mini egg watched stickin around first tears eyes + years',
#  'owowow breaking boxes got hit eye rogue piece glue',
#  'hates bank able get tuesday broke effing weekend',
#  'record store day bad dying breed days miss blue dogs',
#  'anyone wan na get monday walk almost miles anyone bueller',
#  'ecu -- plex gone',
#  'yay saturday stereo died something car got ta rip dash',
#  'mussomitchel sudburys never gon na win',
#  'ugh look like mental patient grandma gon na find im play',
#  'poor roomate sick boobs leaking gross',
#  'paulacxx live fanfiction',
#  'nice weather finally blesses us dc - starts raining tomorrow',
#  'cassiefx look good scratch sniff internet',
#  'getting ready go work soon',
#  'tears eyes kingdom hearts play frm beggining roxas memory card',
#  'inmykitchen nah bro need em soon possible thothe maybach music floating sumwhere tho',
#  'sebby_peek okay goodnight love much xxxx im sorry',
#  'has_bookpushers im freaking depressed knew would happen still',
#  'ah well back grind',
#  'woke started day dropping crackberry',
#  'srptchkd hey steph texted morning said would picking around',
#  'storming dont like',
#  'tessdejong bad bday party hehe',
#  'damn man really wanted damn funnel cake',
#  'sore throat really bad head cold hench bruise blood test',
#  'feels alone friends twitter et miley cyrus doesnt answer',
#  'heebiegjbies missed bowling fam wish still',
#  'confused cs homework',
#  'sad know arsenal lost chelsea fa cup',
#  'word wise never buy porno gas-station liquor store chicks probabl covered giant moles ruins purpose',
#  'desert + running == death hmm seem forgotten little fact',
#  'stoopid-i spilt bit bleach pink top small white patch',
#  'video audio nothingggg n nooooooo asot',
#  'people forsaken seek makes sad pants',
#  'rawrbeccah come',
#  'missyuu guess \\',
#  'less week month town begins',
#  'phillprice currently got mk golf & amp love wanted mk small family got new mazda coming monday',
#  'hansonmusic wish fan event tulsa college graduation miss guys',
#  'leannenufc oh still quite early mebbies things flow better later laughing loud worry moment xd',
#  'early',
#  'theres fox garden hide',
#  'booshface laughing loud cooper cooped ] hate things though call jenny long legs xd idea',
#  'bdiflip yep doesnt',
#  'im always hanging boysand feeling left',
#  'thinks shes done something isnt quite sure oh need',
#  'think milk bad',
#  'terrible daughter',
#  'work',
#  'craving pinkberry right cant get fix',
#  'nathanfillion & amp morena orlando panel - pm one upping con prank war plan late',
#  'feel sick stomach ick',
#  'hawaii & amp woke love saturdayseven though work hours least get monday',
#  'exam done hopefully passed maybe marks curved stressful lame',
#  'saw old house first tears eyes long tears eyes beautiful theyve done ton miss',
#  'exam tears eyes',
#  'ok seems working - comp one midlife crises seems everytime quiz',
#  'campus pc lab dont photoshop',
#  'bed got ta early work night night sexuals laughing loud xx',
#  'home alone lonely',
#  'leapylees oh ill check tescos theyre much closer scotmid yummy treats make us gain weight',
#  'im lonely keep company female cincinnati - ohio',
#  'hope show doesnt move fridays tho whats gon na telly saturdays',
#  'watching brothers game losing',
#  'someone got disqualified sending multiple entries',
#  'whered mr pepper dude go via zenjar',
#  'way back conference - amazing sorry everyone couldnt come',
#  'work',
#  'lonemat yes months ago',
#  'pm think im going bed got work tomorrow',
#  'princessq confiscated bottle',
#  'hurt crap finger playing football boys soo swollen hurts',
#  'watching film visitor feeling depressed',
#  'actually hot outside http//mylocme/op',
#  'suppose go camping weekend bad weather changed plans',
#  'need homework school starts monday oh well still need iwill godly day sunday church',
#  'emilysmoomoo shame schofe didnt say hi side studio shall go visit soon',
#  'bientã¯â¿â½t dã¯â¿â½collage vacances bye bye twitterã¯â¿â½',
#  'lectrickrainbow ended babysit',
#  'finally heading party emergency vehicles arrived kroger took stretcher',
#  'oceanuptwitt would enter cant',
#  'call grandparents tears eyes',
#  'raining toois raining everywhereim sorry kids houston really sucks',
#  'elevenution yeah supposed clean room never',
#  'swear didnt matter id move today fed might cable and/or food til get jobreal talk',
#  'watching breakfast club missing/thinking katie & lt xoxo',
#  'stupid caffine headache hate addiction grrrr',
#  'lose followers tears eyes haha',
#  'mii mni huge headache',
#  'laying bed watching favorite showwhose wedding anyway guess good gon na get',
#  'asked abercrombie model',
#  'charley_farley im kind love hathaway mum understand want see hope make',
#  'yer hgistory presetnation',
#  'exhausted long day babysitting',
#  'think like trim virl shorter http//trim/jiq',
#  'wants access virus ti theyre like grand',
#  'argh geek makes cry inside - uncle runs windows whenever camera card full buys another',
#  'im lonely keep company female cincinnati - ohio',
#  'andy roddick got married',
#  'damn celtics chokin bulls keep playing like cavs title lose',
#  'ive many probs w/ twitter app week finally seems back normal well see',
#  'tried setting twitter phone failed',
#  'mulatta emotional reaction severus looked conflicted omg couldnt hold',
#  'elderly im terrified becoming dont mind healthy young elderly people absolute fear & amp cant quit',
#  'men freakin suckkkkkkkk',
#  'heh im glad mood went shit need cassandra',
#  'xtashax miss woo woo',
#  'unpacking really sucksand homework already',
#  'back killing',
#  'csantopietro medical student weekends study',
#  'nathanfillion bad im canada dont hbave b+ns',
#  'bonnie oh havent able read yet lotsa email dms today kinda shocked opened bo',
#  'dont know lay night go fun really need stay detox god sounds boring',
#  'hurts poor thumb',
#  'skdickey im bummed cant ride bike new wheels show tuesday',
#  'marcushazzard ugh homework ive got money wish could go dancing tonight',
#  'jmk brandon doesnt want toooooo',
#  'tears eyes make ends meet somebody move ends',
#  'depressing empty tic tax box',
#  'leaving beach got nice pictures sadly wasnt inspired enough draw anything',
#  'really needs sort insomnia crap still wide awake',
#  'beat two year olds tomorrow denver wont kick ass even harder beers backyard option',
#  'lukeaddis wow filled whole page aplusk twitter king im go searching tweets',
#  'much pain back fucked dont know happen feels like something place lower back',
#  'greenmonsterpoo little bee miss youuu',
#  'crash shut sh go back way via mangawhai',
#  'bechyy miss online weird seeing online hehehe',
#  'rch_l laughing loud pitty points ftw dont always help though',
#  'want macbook taking suggestions name',
#  'well good night followers wish',
#  'teearnstack conshence think wouldnt know either xd goes dictionary conscience aw dont want die',
#  'fuck birthday',
#  'maryalmighty',
#  'thinking great day cleveland sports precious browns left sad fb',
#  'mariajessica ahhh jess still revisions thesis bound till tuesday cant lazy',
#  'missing baby girl',
#  'bit tongue',
#  'kataylor wish could go going cruise hope fun enough',
#  'wish friends twitter',
#  'tears eyes go fold laundry mentioned much hate laundry well anyone got laundry fairy spare',
#  'paurubio ruins others tweet',
#  'ripped new tank trying take tag offawesome goodnight',
#  'samatic ha ha damn fun without',
#  'tonylui oh sorry late response got hit car',
#  'anyelday ooops bug fixed try tiny url',
#  'thinking drive nashville',
#  'really crusty feet ah awoken yet loud drunks even summer love shore',
#  'bdhorse im nawt stopped sitting like minutes ago',
#  'shinydirt dude bf went said hot got dirty confused look disappointing laughing loud ff still rocked',
#  'needs twitter tutorial',
#  'im sooooooo sad watching week b lasts american chopper like jr think sr serious fucking issues',
#  'wax - epilate ive waxing lower legs diy recently -scrutinise- see ingrowns',
#  'trying write song freakin insanely hard',
#  'bananawong hobing ah joeys cat lost two beloved cats less year',
#  'ecosaveology sorry missed today let know and/or ed come oklahoma texas ed amazing',
#  'trying figure heck going dont understand site wont let upload picture',
#  'msprettynsweet messin essay papers huh laughing loud good luck didnt hang laughing loud',
#  'cmellmer long twitter',
#  '_angeliina ouch glad ya didnt =d otherwise poor kevy would awful lonely laughing loud',
#  'mslujan fair w/e night',
#  'sad broke nail bowling',
#  'bout go bed without baebe good tears eyes tonight',
#  'frankie nonnas really want',
#  'going books getting ready school tomoz',
#  'sarahdope need dibs',
#  'liz_perez sad first ever playoff experience straight whoopin',
#  'one worst moods ever',
#  'srslylily cold',
#  'pana send message wont read anyway',
#  'got done watching saddest movie - boy striped pajamas',
#  'disappointing game rose garden tonight blazers',
#  'headache',
#  'pinkberry sara wallowing self pitty',
#  'saw marley sad cried',
#  'bored',
#  'hate laptop hours go email slow hardlly ever turn tweetdeck itunes visit blogs anymore b/c',
#  'rode much today got blisters palms need better gloves',
#  'listening saturate tears miss dad',
#  'omg feel like jerk great guy think craigby',
#  'wants find good guy',
#  'elikapeka sad car accident careful',
#  'damn thumb throbbing forgot give perscription pain meds counter stuff dont cut',
#  'moriahsallis dont want move come see',
#  'sfltv yeah screen over-nighted itll monday sunday delivery ticket replacement phone new monit',
#  'didnt get much sleep last ngiht fire trucks',
#  'playing guitar hero ps im noob',
#  'cant sleep david isnt raining thundering',
#  'going sleep b/c feels really sick',
#  'disappointed sound quality educamp - especially recordings',
#  'brian_g think could wait urgent care want save dollars doesnt sound fun hang er',
#  'callin niteboring & lt -- -- lol sometimes thats got kids',
#  'shrek well option thtjust tht st cell n gift bro boot plus tht damn thing cost k back',
#  'im lonely',
#  'ever thought laying bed would darn boring want go somewhere',
#  'oh noes found cons skate shoes hard find financial issues bought nike',
#  'sivereaf man fixing good sorry hear wife',
#  'something road killed truck almost florida http//twitpiccom/ljr',
#  'worst headache lying bed day lazy',
#  'worst headache ever',
#  'ok tears eyes head home sad leave dancing knee really hurts sleeping tomorrow',
#  'says kinda miss long hair http//plurkcom/p/oxx',
#  'boring game fun',
#  'silly govt grant havent paid yet',
#  'back huuuurts happy never move xx',
#  'lose followers less hours im back single digits kinda bums',
#  'go job',
#  'wan na go home',
#  'short hairi hate',
#  'krystleperez tried test wpm wouldnt let without installing application',
#  'oregonjen whole post con blues things really sucks others say gets worse go',
#  'kimkardashian looks like hurts ive never sunburn =x armenians shouldnt burn laughing loud',
#  'lost money tonight support local bartender',
#  'nicolerichie funnybut theres happy ending',
#  'adthrelfall fork redmine sa plugins word warning cant raise authors accept pull requests',
#  'empressericka oh well tried',
#  'dennis im sorry human bad game bad really bad familiar games right',
#  'ashlynicole happens phone got cut ya',
#  'sch start tmr',
#  'tomm_j haha video soo sick want',
#  'guess get get wake early tomorrow yardwork yay',
#  'leaving trollstigen heading towards bjorli super-dissapointed trollstigen spectacular http//twitpiccom/ldv',
#  'got home already want go back & lt off-roading',
#  'madeline_cole sorry bout hun',
#  'majornelson wow good deal xbox bad stock',
#  'kings men rule \\/ pray pray',
#  'twimailer twitter says twimailer email isnt working anymore cant see easy way fix ur site',
#  'maharishi_velle bcus kid bedbugson couch & amp say im itchy & amp rush get home & amp take freakin shower',
#  'still alone',
#  'way dont live country suburbia hell theres sense community',
#  'beethousand call got dropped',
#  'swedishjoe would love traveling throughout may',
#  'want listen point',
#  'roombreathe eitherand doesnt last long kinda sucks weather nice',
#  'brawl let guys ahaha go adam hunter',
#  'sushirockstar blogtv sucking computer boo',
#  'cant believe almost tears eyes brother move chile',
#  'legonz guy snuck didnt get invite hope freegin great tears eyes',
#  'pinkberrygirl nothing really / hour shift work today boo iam dead zone ill tweetless',
#  'davedays actually rained day today live kinda suckedlol',
#  'xxmarypoppinsxx well yeah',
#  'jonathanrknight hope feeling better jon looking forward going cruise soooo wish going xx',
#  'cant sleep stupid bus',
#  'really easy park stuck hopelessly one lane pile hasnt shown signs movement minutes',
#  'jonathanrknight would uk need full service give us shout til morninxx',
#  'cant find sister twitter makes harder stalk',
#  'want talk love night looks like im going get',
#  'didnt go coachella live middle nowhere fml',
#  'twitter temporarily disable editing whos tweets go mobile currently neither turn specific ppl',
#  'im going cry',
#  'oh well back work tomorrow',
#  'fiancees mother taken ill heading upto birmingham see family least fri',
#  'mariahcarey ouch sore tooth fun',
#  'iamdiddy got home trying im locked',
#  'cookiemonster thankfully todaybut work tomorrow hoping rain dead wipers/',
#  'arifgan arifgan except last part',
#  'jessicastrust problemo might wan na tell pembrokedave said im nice hes horrid & amp dean_cummings im always nice',
#  'trying avoid getting delay evil blood tests today dont want go either',
#  'remainamystery hope gets fixed soon',
#  'face numb laughing loud pittsburg ca http//looptus/myqkat',
#  'rain today first cricket game season',
#  'joelmadden soo wanted see movie love jennifer aniston refuse watch know dies',
#  'viva_la_sue_sue hurt right',
#  'want third day weekend',
#  'homework',
#  'im back guys laying hotel soooooo excited many things havent heard sweetface -',
#  'local oxfam trendy window display shocker cyberman helmet paired manequin wearing dress sign doctor though',
#  'ood + snapper tarakihi kingfish porae marlin',
#  'robertbrook youre getting abit today im going take river wander - dreaded gym',
#  'talieshablackie nup',
#  'ddlovato germany toobaumholder never seen celebrity concert cept lil jon',
#  'restless sunday night',
#  'morning people last day holiday today back work tmrw hr shift',
#  'really enjoyed last night truely sorry giving mel cold',
#  'bradiewebbstack aww poor bradie walk',
#  'damn thought successfully ousted cat came home',
#  'beer pizza krispy kremes anna pretty fun way end melbourne sad go home',
#  'biological clocks messed still cant sleep',
#  'im awake going get ready back school monday',
#  'rossbreadmore sounds like fun sunshine following ali_bubblegate ali_mosaic',
#  'waahh im home & amp im sick',
#  'skinhead & lt many small place nearlly jizzed missin cheffy though',
#  'jonnypaula oh dear youve started auto-facebook-updating-via-twitter already',
#  'oh ffs get rid desktop tool dock vista good please anyone know hate',
#  'yes governor corzine',
#  'drugs arent bad miss well anyways talkin bout icebreaker xbox live need new mic nd quick',
#  'bw know right ever since released ive wanting perform end jeesh',
#  'sunny day back work tomorrow',
#  'scott_amh yes says wp database doesnt exist',
#  'eating final easter egg & lt/ business nall great stuff',
#  'grrr cant center div safari reason using width em margin auto works fine ff aligns left safari',
#  'courty yer know woke like noo dream wasnt real',
#  'dollyparton whataburger well eni claudia night ima think idea',
#  'im shattered sister kept couldnt sleep hours',
#  'contemplating',
#  'far gutted / wardrobe next bedside table bed argh old desk',
#  'ive updated couple wordpress sites bummer see need build k theme scratch damn',
#  'theellenshow ellen watched show ages agree views gay rights tonight proof bad',
#  'cant sleep stomach hurts',
#  'got home church tomorrow would last day easter break',
#  'today sorta bummy club didnt work king taco bomb im back home ready sleeeeeep',
#  'im going start playing wow',
#  'hmm thought daddy giving milk think im seeing double get rid hickups http//twitpiccom/lpb',
#  'lovelies sorry absence woke flu-ey symptons still got im bit subdued still smiling -',
#  'raining grrrr ipl',
#  'xxhale ahaa get family mehmets family maybe going florida miami want go la & lt',
#  'omygosh end holidays maths exam tomorrow / billion othes week- okay six stilll ahh',
#  'chaitee new business idea spandex fatties many business ideas',
#  'miss best friends forever mandy way nyc',
#  'start term',
#  'shift b two hourscant wait go home & amp spend tears eyes w/ guysb turn around & amp b right back',
#  'ssedro submerged let dry like week might suggest hairdryer waters hd buh bye',
#  'bruno ohhh much ohh feel terrible',
#  'doin graphics work aaaaaaaaaaaages x',
#  'moved couch cause boo said snoring',
#  'back work feel ill',
#  'mattk_au wow nice effort im stuck wastelands -k need find avatar rental somewhere',
#  'erlang recommendations engine making good use cores damn disk cant keep need ram damn',
#  'filipinowise see quite busy work top caught bad ass cold week studio yet',
#  'sweltering im irritated friends cancelling last minute biometric passport tmr wooo',
#  'ahj speculation press today chris considering leaving hes dumped',
#  'hilariouscow yeah got hands documentation pretty interesting boring want radians back',
#  'says nakakapanlumoshouldve printed chance http//plurkcom/p/ozg',
#  'shotdown would even care updates never',
#  'back school tomorrow',
#  'fair_awesome dont though',
#  'samantharonson thank sam went checked sad',
#  'early sunday morning twins still sick fever days criminal looks like ear infections',
#  'eileenmarshall need friend ill vilnius thank kobe im getting moscow soon',
#  'amazingphoebe thats want believe guest',
#  'amazingphoebe youre right doesnt matter',
#  'report media regulators bffc done next asa pcc dreaded ofcom theplus side im listening fatboy slim',
#  'famouslyalone wish jen coming',
#  'bored silly think hav cold - bored sillyand think hav cold',
#  'miss cosplay sooo much',
#  'maryjanesuckaz really',
#  'disappointed damn getting hopes',
#  'pseudrandom sweeping garden = sweeping garden sadly [ didnt know meant something else ] hehe',
#  'painfully dull experience nearly new pc n running probsitunes bad times speedy fecker quiet good times',
#  'birthday cake gone good good',
#  'great weekend birthday went bang laughing loud back college mro',
#  'raining paradise',
#  'nose done really hurting ouch',
#  'looks like wet ride home - day',
#  'vicodin_martini jealous get watch tv',
#  'babybeech oh trying comment report status ages ago haha also tempted sun xxx',
#  'therescue want go manchester uk cant go leeds',
#  'djknucklehead',
#  'hunnybunnyxjs youre either',
#  'lenedgerly hub says buying one xmas tried audible books fell asleep airplanes lost place',
#  'bringing baby drs today -yuck- poor little dude im hoping allergies beginnings something serious',
#  'allenhortaleza food tech today',
#  'sconefiend missin alla yall go bed & quotbrunch & quot later',
#  'sweet_candii smashed pancakes',
#  'booooo cant see photos reason glad hear nagas good tears eyes miss',
#  'back school tomorrow',
#  'miss erica way used hang sad realizations come night',
#  'happy - drinking pint tea cos dont coffee left',
#  'tomorrow back school',
#  'ohmydaysitshayz ahahha maths test tomorrow swimming',
#  'franky_fingers home b next one though promise hope cleaned seat put ur feet one inch x',
#  'honeybeemine missed sytycd dance event afternoon evening',
#  'cat looking bereft take away food getting teeth checked tomorrow morning anesthetic sad kitty',
#  'sebby_peek understand',
#  'im still & amp sleep',
#  '_brian_johnson & quoteveryone become great & quot one still isnt working rest work fine',
#  'bombtwinz carpenters making repairs couldnt leave alone',
#  'suffering gastric acid since saturday morninghuhuhu help',
#  'wishing could go see tai today',
#  'feel like lost best friend',
#  'back school tomorrow got lot homework',
#  'wish houston houston_dynamo game instead work',
#  'sorting high schools yo nerve wracking stuff dont want get wrong',
#  'wan na watching milan v torino tv occupied others',
#  'fsuamanda kind syrup folgers morning sun mine',
#  'good couldnt help check result sharks v crusaders game',
#  'doorsdownrock thanks guys - sorry miss show mohegan',
#  'work crazy busy today rns patients pts r conrol & amp someone pass away god bless',
#  'miserableatleast tempwent much enjoying weekend',
#  'brookeelyse officially finished life meaning anymore one single thing look forward',
#  'awake project really vivid dream thought real',
#  'belladonna youre im patio theres music & ltgrin & gt got ta yardwork soon',
#  'last day',
#  'andrea home bored got college tommorow bad times bad times',
#  'paper please write yoself best intentions starting somehow devolve simply getting',
#  'dont want wake',
#  'bored waiting pee wee pictures san antonio posted',
#  'drinking coffee perfect tears eyes',
#  'ew karen dillards',
#  'studying chemistry got pg three days including chapters reading material workbook',
#  'maybe cutting ties best thingso sad tho miss',
#  'wallace_reid mine gone text-only completely unusable im go ffox',
#  'nikkibenz still waiting hope got',
#  'meshmeshere thank hope get tears eyes',
#  'jradc day hell work ended badly started whole hours went',
#  'back skaterhockey crazy old bears _chiefs reloaded goals us last mins',
#  'licensed drive',
#  'sun burnt & amp hurts helping kayla party thing',
#  'drpants going lots sad people today',
#  'sniffly nose',
#  'cleaning battery acid holga',
#  'sireuan',
#  'realized left wallet llano',
#  'back uni tomorrow cbaaaa',
#  'want go resevoir',
#  'dylanjobe starhawk please',
#  'christamacphee sick lot',
#  'im listening fuck first tears eyes agessssss - sarahwhere r sing along',
#  'enjoy night crammingã¯â¿â½',
#  'wow chaneles nephew passed away yesterday part drive got shot times reason still came work',
#  'sigh stitching yet bad day',
#  'neck herts',
#  'tottenham - newcastle ouch newcastle looking good drop',
#  'im trying figure twitter thing works',
#  'want write history paper',
#  'merrrrgi got nothing',
#  'kwill cant write jfs wall fb wan na know name girl michael kluthe salon know',
#  'wan na go home',
#  'going bridal shower today looks like going rain',
#  'morningglory cant say didnt try',
#  'oh almost monday',
#  'homework',
#  'sad leave dayton',
#  'last day going back work',
#  'patientzeroband thanx im bad day today',
#  'work -',
#  'getting packedoff texas week bad work',
#  'alwaysmommy im jealous raining gloomy stay indoors',
#  'klutz like themwhich means gon na much new moon',
#  'aanaravs cool wish netflix',
#  'hollymcombs hi ths really holly great actress miss charmed please write back xxx',
#  'mannnn dad wants cut grass darn laughing loud',
#  'warmth sun returned transplanting strawberries today may story show lost daphne winter',
#  'upset cant find pair sexy cut-out sandal boots anywhere',
#  'college visit',
#  'vanillurve dun miss us',
#  'jamiev way cant go holiday',
#  'raining',
#  'joannadelilah need lose lot started gaining went back birth control yrs ago',
#  'woa listend jennette mccurdy sing acoustic guitar wow shes amazing jezz wish could sing',
#  'awww last day spring break',
#  'confusing game chatter twitter',
#  'lyndseylouwho wish known sooner could come honey',
#  'hannahmtew',
#  'cba school morra',
#  'johncow yeah hate things sorry get auto-dm cant hit un-follow button fast enough',
#  'got exam timetable exams day',
#  'nathanreid ya sucks stress gf turn stress relationship',
#  'feel like death warmed pretty sure im getting bed today',
#  'ugh work http//twitpiccom/llt',
#  'jasmineoh lucky ive studying like hours',
#  'stupid allergies headaches',
#  'livejournal seems cant distracted editing essay back mm',
#  'crappy dayrain much homework constantly let people',
#  'bjstone im going see againlol im going girls floor last tears eyes something group',
#  'oh good mom back bed hour minutes tears welling eyes',
#  'last day experiments cinemahow sad',
#  'still waiting goal man',
#  'boknowsshoes guess ill make laughing loud',
#  'waiting get told clean & ampwatching american idol thing gabbis sleeping',
#  'miss home church tho infinity ny church bronx also bronx community baptist church bronx ill back soon',
#  'ben_hall sorry meant ex gf better keep secret',
#  'rockbigdave charge mine practically daily',
#  'im missing bananas myy pancakes still gon hit spot regardless im trippin ] holla',
#  'omghe killed cries sooo latewith house episodes',
#  'doesnt want go bac toronto today',
#  'tanto stockholm friends today great tears eyes im extremely tired easter breaks tomorrow',
#  'gud mornin gotz stomach acherz',
#  'jeremya bummerthats worst way whole life',
#  'orange county sad going back bay area work tomorow love dinsey oc',
#  'day grand internet outage',
#  'wish followers',
#  '[ -o ] sitting atlanta airport waiting flight orlando-wish going disneyworld http//tinyurlcom/dyanlp',
#  'wants see maddie',
#  'dreary outside',
#  'goodbye disneyland going melrose',
#  'bad hair day',
#  'rainy day',
#  'misses rob something cronic left two mins ago',
#  'violently throwing kinda freaked since didnt even go last night one sip alcohol',
#  'solangeknowles wish could wont chicago tonight',
#  'librarybad times',
#  'way home swans another sad goodbye get home family spring break',
#  'soooooo grouchy tonight wearing ring ither',
#  'hoping mini golf tonight please dont rain',
#  'audubon center sanctuarywalkin trails feel better ashton kutcher',
#  'im hungry dont know eat',
#  'new amp shows cancelled wait use',
#  'amaditalks thought really healthy didnt know vegan knew martha apprentice didnt watch',
#  'got made redundant today oh shame',
#  'paulaabdul hmmmm rain toledo',
#  'cant find cue cards',
#  'cant seem anything right today maybe take nap',
#  'tons homework',
#  'fatally_yours dont trader joes fl actually poor healthfood store selection need move laughing loud',
#  'coffee bee sunday tradition last one semester',
#  'cherrybumbum lose video camera poor thing',
#  'bowl pho good',
#  'feeling great anymore hahaha sure drink lil year cool',
#  'pavithri sniff thanks sniff',
#  'binko picture laughing loud excited video oh well hhahha',
#  'leavethistown miss muffin',
#  'mileycyrus dont leave us haha im part fan family okay good look hm premiere germany god bless luv ya guurl',
#  'last day spring break heading venice beach around though fun',
#  'fell last night fav jeans dead beasides im wounded',
#  'seriously much going watching katie leah play lotr one online going feel ignored',
#  'lovely outside one share lovelyness',
#  'sundays always depressing worry mondays following day',
#  'petewentz piecsesthe stupid little fish im bad monthso make get better sucked bad',
#  'cant find ipod tore living room apart never found',
#  'alynn dont want know answer want money back',
#  'angelicmischief nothing stood pomptly hit floor threw',
#  'sad someone left today cant wait summer',
#  'breaks later tweethearts',
#  'bergenlarsen actress played oracle replaced inferior crap coverup bonded wanted cookies',
#  'got home fashion show rehersal listening depressing music aid depression',
#  'stuppppppid papers day long even thought going',
#  'fair ride tilt-o-whirl bad santana doesnt play anymore',
#  'cat usual lies beside right im get go somewhere else poor thing',
#  'called day -',
#  'hollywills wished cud signin',
#  'elshertz yess say need fornarina jeans',
#  'dannywood danny enjoy well-deserved break miss boys already though going nkotb withdrawal',
#  'weather messed sunday',
#  'bbc toy americans showing wonderful full episodes topgear available watch us',
#  'marianne cold',
#  'woburn days days til graduation',
#  'rockpapershot oh man jealous doesnt unlock tuesday',
#  'tears eyes bath yoghurt bubbles goodnight fav twittertown sweet dreamss',
#  'havent gotten started prepping essays massive exam next saturday exams one must get ass gear',
#  'woot work sunday ohh wait thats exciting',
#  'lazone http//bitly/anqju ace prize winning fan made vid best single released please keep retweeting',
#  'want wendys',
#  'walmart sunday always barely got alive',
#  'hate saying goodbye ugggggh',
#  'christymychem yeah know hey email',
#  'back church memorize creed gon na killl wan na shopping tay momma',
#  'stefsull usually gets wonky actually headed genius bar aft macbook refused restart last forced reboot',
#  'calanan youre pretty damn cool although miss brunch today thanks hosting last night super fun',
#  'bripoe aw man wan na see terracotta army',
#  'still lil bit hungover awesome bachelorette party though',
#  'marybologna keep updated im working',
#  'really going watch brothers sisters breaking bad damn roomies',
#  'ah alicia making watch saw im scared',
#  'bedback work tomorrow',
#  'rosewowie im similiar boat one tears eyes zone behind',
#  'going back school',
#  'degrees thats like summers day ul know coldwinter getting close',
#  'still work',
#  'nayedene workin old phantom opera z moment great astaire-depeche mode vid got removed utube',
#  'left queesy feeling much frusteration anger team',
#  'noisy street-lit outside keep window open else ill die',
#  'lost usb',
#  'back work wish still holiday',
#  'happy going bed',
#  'trying get train london present ceo none parking machines accepting cards must monday',
#  'ready another work week',
#  'shenaniganjenn plz dont die totally need may th would miss & amp dead would suck',
#  'aubreyoday abouthumm danielle laughing loud yay',
#  'danwarp argh icarlycom keeps forwarding icarlycomau',
#  'bad bad person',
#  'lilyroseallen giving free tickets county durham area fair x',
#  'follow guys im new',
#  'johnathan havent mate',
#  'like nokia messaging app support nokia slow',
#  'nooo school mins altough im still bed',
#  'queenbmakeup havent found face cleanser/exfoliator ive liked since real oily skin idk look',
#  'wish doug',
#  'im cold',
#  'iced hazelnut coffee mcds sounds great right bad ive given caffeinei guess ill stick ice water',
#  'lindza broke nose holy crap hope okay',
#  'creating twitter account',
#  'took bubs hospital first big bump bump frightened witless shes ok tho wait day laughing loud',
#  'bike ride really hard yesterday paintball least good fun',
#  'drinkyd know im like damn ima never meet cockblocking security guards',
#  'search friend countrywithout email address',
#  'maester sad true society says life already',
#  'anybody remember & quotwe want cup & quot song z canucks wish knew tape',
#  'school hair seems mind morning hugs jane xx',
#  'ddlovato great day demi school haha x',
#  'shame beejive supported anymore open sourced',
#  'project references xcode killing poorly documented buggy something get',
#  'soy_ale dood month selling',
#  'mrskutcher sad story rubina everyone elseslumdog millionaire stars family trying sell herhttp//bitly/muu',
#  'oh man im going miss back-to-school gossip',
#  'bsy today lot work',
#  'school tears eyes see guys later',
#  'simon_barton oh god hope im young spawn',
#  'sleeping poor start week',
#  'thinkin bout mess kids r gon na make eatin tacos dinner',
#  'vaempyr sent friday',
#  'ow heard jamesmeese got pwned face yesterday playing syn futsal team unisexicorns poor james',
#  'nut_cookie hope ugh im pissed user posts lot pictures kinda nsfw & amp mama kang-mom',
#  'msphotogenic loved mine moved seattle hi miss',
#  'vinny_vegas yeah something nice eight letter word distance gah',
#  'two deaths one day fuck',
#  'exactly one year ago drunk baked cocaine mom calling asking',
#  'woke apparent readon realizedim fn sick dammit nooooot sexy clenex please',
#  'cant tweet something awwwww',
#  'work',
#  'loves sunshine wishes christopher didnt work pm tonight',
#  'want cold snow cold hot chocolate _____ brazil hot -',
#  'shamalac sad inevitable - noticed lot trees uprooted either side agara junction flyover',
#  'beejensen awi actually text-ed one wanted',
#  'imariaprime everyone left jewb talking knuckle herpes star wars',
#  'cant monday already',
#  'first message cant think anything quirky interesting write',
#  'imjulio gon na hang ableton sesh aint got oc live buddies',
#  'antmats cant believe im back ny yuck wish fsa school actually wish went northeastern',
#  'go rs revision session school today grim cant believe havt go school holidays',
#  'official printers hate going sulk make cup tea',
#  'comes something notice wifes shoes twitter notice feet ooops',
#  'ready work ohcorrections fridays work',
#  'im sadi met guy dreamsin dreams didnt even get name number ahh swt dreams tonight please',
#  'snoozed far many times stressed getting everything ready hour',
#  'baby girl immunisations today shes happy',
#  'oooooo ok cuz wonderin hell ur eat supper like cuz thaugh america srry',
#  'really hoping get job getting worried',
#  'nails book complete series called life ice-cream salvage day call monday',
#  ...]

# %%
# vectorize
positivity_cv = CountVectorizer(token_pattern=r'[^\s]+', max_features=7500)
positivity_X = positivity_cv.fit_transform(positivity_texts).toarray()
positivity_X.shape
# Out:
# (50000, 7500)

# %%
positivity_x_train, positivity_x_test, positivity_y_train, positivity_y_test = train_test_split(positivity_X, positivity_y, test_size = 0.25)

# %%
positivity_model = MultinomialNB()
positivity_model.fit(positivity_x_train, positivity_y_train)
# Out:
# MultinomialNB()

# %%
positivity_y_pred = positivity_model.predict(positivity_x_test)
accuracy = accuracy_score(positivity_y_test, positivity_y_pred)
accuracy
# Out:
# 0.75368

# %%
message = "This sucks"
prediction(message, positivity_model, positivity_cv)
# Out:
# array([[0.90922377, 0.09077623]])

# %%
positivity_model_filename = "positivity_model.pickle"
pickle.dump(positivity_model, open(positivity_model_filename, "wb"))
positivity_cv_filename = "positivity_cv.pickle"
pickle.dump(positivity_cv, open(positivity_cv_filename, "wb"))

# %% [markdown]
# # Emotions dataset

# %%
n = 416809 #number of records in file
s = 50000 #desired sample size
filename = "emotions.csv"
skip = sorted(random.sample(range(n),n-s))
labels = ["index", "text", "label"]
emotions = pd.read_csv(filename, skiprows=skip, encoding="ISO-8859-1", names=labels).drop(columns="index")
emotions
# Out:
#                                                     text  label
# 0                             i dont know i feel so lost      0
# 1      i take a shower i feel wonderful energetic and...      1
# 2      i feel assured that i m doing so much right an...      1
# 3      i havent done my eye make up i hate anyone see...      0
# 4      i have wished her the best and i truly feel as...      1
# ...                                                  ...    ...
# 49996  i choose to voice my feelings people are offen...      3
# 49997  im used to feeling isolated and a million mile...      0
# 49998           im feeling inspired by their drama today      1
# 49999  i feel like telling these horny devils to find...      2
# 50000  i think that after i had spent some time inves...      5
#
# [50001 rows x 2 columns]

# %%
emotions_X = emotions["text"]
emotions_y = emotions["label"]

# %%
emotions["label"].value_counts()
# Out:
# 1    16997
# 0    14554
# 3     6844
# 4     5687
# 2     4074
# 5     1845
# Name: label, dtype: int64

# %%
emotions_text = []
for text in emotions_X:
    emotions_text.append(clean_text(text))
emotions_text
# Out:
# ['dont know feel lost',
#  'take shower feel wonderful energetic previous feelings life turn awesome feeling creating life like happiest life world',
#  'feel assured much right alone',
#  'havent done eye make hate anyone seeing feel nekkid sounds really vain think look horrendous without',
#  'wished best truly feel though sincere',
#  'feeling lousy wondering able keep vlcd part hcg cycle',
#  'feel lot less hostile',
#  'miss feeling special girl hed take date',
#  'know im going disappoint ive decided volunteer year fear ill end feeling resentful',
#  'feel lauterbach victimized',
#  'put mask come work suppress emptiness feel inside pain loneliness bitter jaded woman really',
#  'able lose three kilo feeling energetic even month old things seem track',
#  'feel free express without inhibition',
#  'realizing school soon',
#  'feel stupid felt way feel even stupider even word',
#  'feel better worse',
#  'feel like ive pressured tell',
#  'feel many artistic motivations hard keep',
#  'took mg thinking took already mg messed little since trying stay mg less feeling really relaxed long day',
#  'try return feel like broke boyfriend know get relationship back track',
#  'feel worthless sometime like im good enough anyone friends sometimes even family',
#  'im feeling bit amazed grateful landed amid congregation',
#  'feel like mention another sweet family us',
#  'feel abused',
#  'credit feel agitated stuff face hair good two hours later longer supposed keep anyway think',
#  'feel generous follow mostly endure like person willing wait reach somewhat artificial goal',
#  'knew feelings core thankfully daughter came fine',
#  'feeling happy positive bowel hand become grumbling mess back hip pain slowly creeping back life',
#  'also noticed actually feel trusting believe spirit feels way trust better trust',
#  'feel like eager get undergrad finished last three years',
#  'feel like maybe branch fond warm colors like reds oranges limits things bit',
#  'im feeling whiney cant seem get things year many people',
#  'know whether pre race apprehension feeling bit jaded busy season really struggled summon enthusiasm race',
#  'see bracken feeling miserable definitely miserable hes ever really grateful hasnt sick often',
#  'feel like much resolved little disappointed',
#  'feel important part grieving healing process',
#  'force hand find resolution cant help feel would vain bc coming everyone busy little thing',
#  'panicked peony told go get doc looked knew feeling completely useless',
#  'know still feel surprised thinking could done deserve',
#  'feel mostly pathetic right',
#  'feel like got enough confidently say ones liked comparison others',
#  'feel shocked realize whatever talking seeing understanding way',
#  'remembered years ago wondering would feel revival broke rochester span style background yellow font size',
#  'im feeling like next couple days going entirely devoted scarlett since didnt get spend much tears eyes weekend',
#  'found satisfaction contentment chasing feeling happy',
#  'feel lost stressed little wil',
#  'must say feel little jaded organisation heart foundation cancer choice spent quite significant amount tears eyes quite reasonable amount money come point think entirely inappropriate action food grocery council said',
#  'excited came perfect tears eyes feeling little homesick',
#  'almost see dark eyes judas iscariot averted savior feel searing sorrowful scorn must accompanied gaze continued charade asking',
#  'feel weepy',
#  'think probably good somebody might feel disempowered realize things life dont feel victimized',
#  'sometimes feel troubled',
#  'going write one trait feel separates merely talented athlete great ones consistency',
#  'belonged difference feeling like youre accepted belong feeling like youre others people',
#  'im still feeling little annoyed',
#  'hear friends going ons drama lives feel little petty',
#  'saw could told everything like everything clicked suddenly saw really feelings id repressed came surface realized love',
#  'love reading books best educate kids part care strongly issue part like feel inadequate',
#  'sort like feeling satisfied efforts put results much better ive expected',
#  'feeling blessed thanksgiving break opportunities catch friends family',
#  'started feeling numb relief',
#  'feeling triumphant give god glory',
#  'think feel guilty profession remains blind',
#  'ended getting lovely knit thought would great autumn winter feels lovely drapes beautifully',
#  'havent gotten yet still resent paying dollars procedure wasnt fully successful since wore glasses years feel ive tortured enough',
#  'come feel acceptable beautiful first tears eyes life',
#  'feel like live without gps also thankful driving common items learn drive maps road signs google directions mapquest almost got us shot times atlanta kidding',
#  'feel like lame email im tears eyes',
#  'admit feeling bothered',
#  'actually post stupid whining blog post ill feel publicly humiliated ridiculous',
#  'feel though valuable input benefit congregation whole',
#  'feel apprehensive biking rain hot weather',
#  'cant feel sympathetic humans get killed yoma merely part nature',
#  'still feel passionate cause',
#  'could feel summer losing battle fact admired last breath',
#  'longer feel another one times im convinced something reality impale',
#  'look back seemingly endless hours played therapist daily years phone feel like missed lot',
#  'afford forgive emotionally charged feel wronged',
#  'working hard practice gratitude especially moments feel overwhelmed',
#  'know people feel creative longhand mind works',
#  'want feel unimportant unloved nuisance',
#  'hope otherwise im going feeling little foolish',
#  'recognised reasons going made feel agitated personal reasons felt needed get child school',
#  'feel bit gun shy failure given failed life business first tears eyes starting seven years ago',
#  'im trying understanding feel though shes given much tears eyes transition im left anger rebellious urge push heart good',
#  'said hard feelings wasnt heartbroken anything',
#  'feel even pressured',
#  'basically chopped machete could leave feeling rejected leave opposite want',
#  'feel worthless pathetic tears eyes shouldnt hgave feel way cant spak ill get yelled blamed like oh ylur fault oh bring',
#  'also tried think ways achieve feeling elegant',
#  'still feeling contractions terrified',
#  'ask may read blog facebook problem feel want delete apprehensive whatever go ahead',
#  'feeling absolutely enraged right bathroom incident happened morning happened six years ago',
#  'feel honored artworks part salon maastricht',
#  'feel cool moist wind smell damp earth hear raindrops falling',
#  'always feel invigorated refreshed good session trail',
#  'guess good feel smart often feel dumb though',
#  'longer feel urge prove strong',
#  'feel gods presence gentle bending trees wind blows',
#  'im feeling lucky living see ocean quite regularly',
#  'im feeling stress sucks pretty truth im feeling stress sucksseptember th',
#  'remember feeling impatient endless convoluted fairy tale told throughout book',
#  'feel anxiety forgetting vital things like breast milk home getting drs note signed',
#  'feel intimidated developing brains bodies',
#  'wish president hardly know people got feeling hated quiet smiling',
#  'feel bad accepting',
#  'overwhelming feeling wanting live glad left feeling confident decision move',
#  'feel people look think im strange',
#  'feel privileged met',
#  'without giving second thought taped sat write feel little emotional',
#  'feel shy high school freshman',
#  'feel could optimistic times project honestly put alot work believe work ethic strong perhaps instead trying everything delegating work',
#  'feel dangerous situation putting many souls risk',
#  'im feeling far cute right',
#  'feel longing express',
#  'feel bad neck',
#  'strangely drawn feel love heartless bastard',
#  'went bed feeling totally drained silent tears falling face',
#  'feel snobbish saying',
#  'feel john gribbin much clearer expanation brain greene fabric cosmos elegant universe chooses carefully scope depth content',
#  'feel thrilled part great team fabulous challenge',
#  'feel strangely distressed lack attendance',
#  'feel energetic full life excitement',
#  'feel devastated sad disappointed angry bitter relieved content working happy',
#  'feel like pain hurt terrible things life died tears eyes free',
#  'found bond growing feelings romantic',
#  'im feeling kinda sorta romantic wishful lately',
#  'put lot miles shoes starting feel knee hurt ran',
#  'feel like ive missed like im getting three quarters day',
#  'finally told geeky best friend feelings hes supporting support girl likes',
#  'think part feel jaded',
#  'feel impatient anxious go right path',
#  'merging discussed feeling helpless god omnipotent dedicating completely feel safe',
#  'dread checking emails make feel shitty',
#  'feel fucked rolls around treated considerably better production values give swinelord murky high octane sludge much needed layer clarity allows appreciate musicianship display',
#  'soon see feel lively ready take world',
#  'feel inhibited quoting',
#  'feel honored love sketches',
#  'think gets round issue man wooing fair lady sin seems feel makes somehow submissive power',
#  'never know could end next right feel pleasant warmth comes hitting sweet spot life',
#  'feeling stubborn friend said come wanted hug said well come halfway walked shes leaving today',
#  'dont feel ashamed timid embarassed anything else along lines im around know still love end day',
#  'thought would possibly panic suddenly feel hopeless depressed happening',
#  'suddenly feeling reluctant whole thing',
#  'feel like blogging say feel like writing something dumb',
#  'dreamt shots tequila morning im feeling groggy',
#  'feel really special',
#  'leash exasperated cry little feeling beaten game',
#  'havent externalize yet didnt tell restaurant didnt want eat know real middle eastern food taste like im feeling irritable',
#  'might feel resentful sometimes think part process living world good know could',
#  'feel thrilled life',
#  'feel ridiculously amused',
#  'feel doomed beginning terms relationship mother',
#  'feel depressed',
#  'started feeling funny whole week end week work like',
#  'feel valued like im contributing life greater good globally',
#  'feel pained upset scared court believed theory heywood poisoned cyanide',
#  'feel totes weird',
#  'feel absolutely honoured selected part historic event',
#  'feel beloved',
#  'completely sympathize wish feel stability scared change see definitely stability',
#  'realize someones feeling like pissed pretty harsh hang way ah man hate phone calls',
#  'feel envious everyone take weird sort jealous less fortunate',
#  'feel like blank face smile often',
#  'reached stage finally feel ive accepted ms part',
#  'spent little tears eyes perusing offerings even though im feeling little broke new books one website hawking due search criteria',
#  'got nyko perfect shot surrendered really feel intelligent companion shooting href http www',
#  'still feelings broke',
#  'feel loving arms around us',
#  'feel sentimental knowing blip family timeline',
#  'sure feel tears eyes slightly annoyed slightly grateful guess',
#  'recently talking friend feel reluctant press point feel like someone pushing boundaries even end feeling uncomfortable unhappy',
#  'ive feeling doomed gift really',
#  'feel bad feel sick missing training',
#  'saw marks spencer knew good miss pleased dh feeling generous yet treated',
#  'know good feels kick ass week determined',
#  'feel effect backfires changes distracting solondz talented enough gain sympathy sans gimmicks',
#  'im gentler calmer angie even im feeling gentle calm',
#  'leaned close enough feel hot breath cheek',
#  'feel selfish even thinking',
#  'im poor jobless without income technically homeless stuck situation makes feel unhappy financial situation ever worsens',
#  'feel really weird posing photos doesnt feel unnatural',
#  'never feels insincere little nosy get hint something might wrong want jump get details',
#  'feel like selfish one saying ok enough enough want think change always worry problems',
#  'confidently began feel gorgeous feelings everything changed gorgeous didnt even consider friend',
#  'feel tortured comes quilting part decisions know',
#  'feel today accepted promotion work',
#  'hate feeling cause shitty say lease',
#  'feeling rejected manifestation knew deserved came life',
#  'sat shared little walked door feels terrified',
#  'feel feel drained feel talking others finish strength',
#  'ive drunk lot wine im feeling fine got race cat bed',
#  'im feeling hateful right',
#  'know supposed go nurses feel like terrified going nurses station',
#  'decided feeling tearfully regretful probably rather good mental state occasion nodded bring us together',
#  'remember feeling nervous listening girls stories experiences confident id done much',
#  'still feeling really good thankful sickness behind',
#  'still care see anything regards sex makes feel violent inside start crying',
#  'feel anxious overwhelmed gods word says cast anxieties cares',
#  'actually first woke feeling pretty rotten morning head stuff',
#  'laugh feel im least talented person',
#  'im big believer need feel part something feel valued worthwhile',
#  'used people disappoint feeling heartbroken things changing',
#  'stewing brewing little post conscious parenting im feeling little jaded whole term',
#  'feel hesitant write post feel reading recent entry blogger really look',
#  'feel relaxed realize way blogging outlet',
#  'love feeling reassured',
#  'ive felt thing rollos wife feeling day im glad thank god',
#  'feel pathetic defeated',
#  'actually went lot fun weekend made feel invigorated today helped crank ton pages novel editing',
#  'rarely feel bothered walking around',
#  'feeling joyful reach chest treasures bible take memories make joyful day',
#  'feel happy changmin',
#  'feeling little apprehensive sad leaving bella four nights',
#  'feel exactly supposed exactly want amazed blessings opportunities presented get',
#  'feel uncertain amount tears eyes noah gone',
#  'ill say film didnt feel like anything special',
#  'feel achieved flow looking also broke boxy look',
#  'interviewed journalist herald earlier week festival feel really pleased team achieved year festival',
#  'ive voiced concerns past us dropping old im feeling slightly reassured preparations new campaign',
#  'im coincidentally feeling weight thanksgiving upon making bad choices weekend',
#  'entire day didnt sell single policy feel pretty satisfied tears eyes know takes good sales get paycheck week',
#  'articles clothing make feel cute',
#  'part youth group started going certain things made feel unwelcome nowhere else turn',
#  'feel messy sometimeswhy cheat necessary love',
#  'feel beaten feel like sword put fire afterwards becomes sharp fl gone horrors imagine grew without without love',
#  'knew taking liked way made feel troubled conscience trouble enough keep going old addictive road',
#  'know feels read someone suffering pain mentally',
#  'feel reassured cycling descending bad',
#  'feel really unimportant friends lives',
#  'standing feeling uptight white like lame',
#  'know women circumstances outside control choice work outside home away children feel thankful us willing sacrifice weve able make choice possible',
#  'love feeling humiliated wedding situation',
#  'didnt buy didnt buy announce closing marked everything week left marked everything else table sat forlornly corner surely feeling unloved',
#  'feel vital gain customers',
#  'feel impatient always body pace since always behind mind mind rushes ahead things want climb wants higher level body keep',
#  'receiving many positive reviews feedback music feel respected well talent something',
#  'seem work nerve tell people feel wronged',
#  'feel need ask range questions lilia oh beloved physics teacher',
#  'feel bob loblaw handsome professional man im used well none things',
#  'realised making could added bananas feeling would delicious',
#  'awful feeling doomed',
#  'feel awful',
#  'feeling rather discouraged remembered',
#  'im still feeling weepy stressed overwhelmed im getting handle',
#  'feel tortured right',
#  'remember feeling curious mums sisters clothes third year primary school',
#  'much work feel little sorry feeling lonely',
#  'feel bad husband',
#  'must say im totally feeling look reason im loving swag',
#  'always feel like somebody watching popular topics href http www',
#  'im going stuck new jersey forever feel alot less doomed think way',
#  'try connect three four times response tend feel valued channel energies elsewhere',
#  'help feel annoyed curly nothing eat poop yet continued caring day day',
#  'express feelings matter unpleasant may hear say',
#  'pleased feel hopeful help aaron pleased help feels support others experience understandings gained previous life healing studies done inner levels',
#  'feel like got pissed actually learning something wouldnt stop saying end',
#  'im feeling beaten weary battle want give',
#  'didnt want feel resentful hang nates ability work head member',
#  'im feeling restless shit damn',
#  'stayed apartment feeling numb yet strong quiet resolve',
#  'think worth remembering even though read books blogs feel friendly toward us end things stranger even interacted blog comments e mail whatever',
#  'dunno feeling jolly festive year',
#  'feel ridiculously obnoxious',
#  'right thoughts head feel like reluctant blogger type world read',
#  'feel happy hide feelings miss thing used',
#  'leave still feel respected think',
#  'feel think trusting friends feels good',
#  'kind get feel casual nfl fans people follow football closely view nfl draft',
#  'panic attacks water feel stressed',
#  'ive kind gone back old ways always feeling like im unwelcome',
#  'lot week finding new hospital new doctor feeling pretty drained pretty real contractions',
#  'feel overwhelmed excited future',
#  'often felt like youth group activities controlling chaos instead helping kids feel loved know jesus',
#  'must admit feeling bit apprehensive whole situation',
#  'love go things feel like every curious question must unfolded explained',
#  'feel irritated hear name disgusted feeling youre around presence brought annoyance like calamity disrupt peace mine deemed person hated lifetime',
#  'feel like punished know lie',
#  'feel like talented anything enough dream goals',
#  'try hate anyone anything cant help feel like hate sons dad jaded women hatred hatred derived sons pain',
#  'feel like tears eyes incredibly productive',
#  'know stephh someone isnt immediate area hold bawl eyes sob feel chest aching walks right rubs',
#  'dont know malaysians feeling frightened',
#  'small child least remember walking around old neighborhood feeling desperately unhappy nothing particular',
#  'dont know end year stress sleeping home work colleagues banded together irk feeling unfriendly foul mouthed last week',
#  'break feel devastated puts dating altogether',
#  'justify killing people feel sorry likes killed',
#  'feel end surprised uncover way useful also pleasurable really whole family',
#  'feel really honoured given opportunity',
#  'left office feeling hopeful call never came',
#  'decided take nick date feeling little unsure group date drama previous week',
#  'feel divine',
#  'wonder though many us non passionate people felt fine told feel passionate jobs',
#  'recall feeling beaten',
#  'feel like grouchy',
#  'feel really inspired plant trees',
#  'feel stubborn stupid everything could describe right',
#  'would feel aching pain',
#  'feel devastated hear',
#  'imagine feel love thing day going well',
#  'feel reluctant anything know sticking working like trojan shows strength character blah getting',
#  'want sleep well feel energetic',
#  'feel like im kiss wonderfully vain swear ill melt touch ill ask saturdays saturdays saturdays tuition studying guess life like',
#  'feel less frightened',
#  'feel little lethargic recount href http en',
#  'im feeling really successful',
#  'feel abused friends meant harm',
#  'im feeling pretty strong mostly energetic thanks regular exercise loads sleep',
#  'woke felt sad quickly replaced feeling reassured things work tears eyes',
#  'accustomed feel garment actually pleasant reminded body proper posture gave chest lift',
#  'feel lethargic n feel low n n energy n th usually goes hand n hand w th layer',
#  'get sometimes feeling sometimes get frightened like get frightened',
#  'taking control feeling morose teary eyed',
#  'using day treat intended think one application group would still feel lovely especially live grimy city like',
#  'feel scared feel daunted feel unsure face dream accomplishing also feel first tears eyes long tears eyes strength comes way deep inside',
#  'feeling dangerous wimbledon height src http www',
#  'feel rather foolish afraid invest especially bought attractive valuations',
#  'feeling loved listen well',
#  'may feel compassionate',
#  'im still feeling little tender really hot really cold foods',
#  'dont think like anyore want like feel neccesary loyal owe continue showing much meant still',
#  'got early enough set transition area warm feel rushed',
#  'im looking good feeling good crappy cold im dealing',
#  'want learn game well enough play without feeling intimidated',
#  'feel hesitant buy another belly dancing dvd workout',
#  'im right part function irritate lt know dont think mind much knows hes asking feels bit playful smirks taking bait indeed know twist circuits',
#  'love wife often involves feelings however meeting expectations quite frankly makes mad know still love actions beginning complete forgiveness',
#  'id rather hope feel indecisive',
#  'feel dangerous children undergo dinosaur alligator section past yrs keep mind alligators crocodiles fact told reality dinosaurs may simply little overlap',
#  'want feel ehol popular podcast feeling feelings want feel ehol archives href http thepopularpodcast',
#  'feel reluctant post response facebook blog',
#  'get little tired remaking certain things one feel thrilled continue making',
#  'longer feel frightened timid',
#  'feeling disgusted sex marriage',
#  'feel damn romantic thing watch',
#  'must inform kind player please feel offended',
#  'feel tongue lapping sweet nectar already spilling',
#  'care lot reason never apparent said feel totally inhibited say anything fear stop caring say something wrong',
#  'feel like suffering today',
#  'sit crying feeling loss suffering unbearable pain know wrong made leave feel hollow gone misery taken heart since left begged stay laughed face supposed',
#  'feel lyrics tekst pjesme lyrics free download mp link rel stylesheet href http tekstovilyrics',
#  'comes many catches glad dublin feeling wifi generous',
#  'found definitions difference submit surrender feel submissive submits slave tends submit surrender',
#  'im feeling depressed',
#  'bought one skein months ago looked cool really yarn hold start feel agitated',
#  'wanted feel gorgeous breasts way could get shirt',
#  'eager try feel super special',
#  'feel lucky enjoyable pregnancy far',
#  'busy new job amp didnt feel like much say post let alone much tears eyes like used',
#  'felt amazing slept well night feeling strong bunch feelings',
#  'wish numerous enjoyable feelings comparably many unhappy encounters james blunt waffle house stereo system coming days',
#  'want think things ponder annoying parts everything depressing feeling accompanies every accomplishment havent gotten every opportunity missed',
#  'know question thinking feeling thing feel sure',
#  'know thats everybody feels hes supportive',
#  'feel like pretty productive week please continue pray aspect',
#  'feel deserve cases whiney attention seeking bitch though',
#  'used feel tears eyes ok',
#  'need take bath work feel vile',
#  'im bartender feel little bit offended read bar reviews someone complains',
#  'combed couple days feeling little insecure whether looks good',
#  'feeling regretful know standard amp done best put efforts',
#  'feel satisfied well recognized',
#  'im feeling bit apprehensive trip',
#  'thick could feel optimistic self wanting clamp problem take beach walk itll make happy said',
#  'really try feel bitter world home birth rise hard',
#  'feel better days like grip',
#  'love running cold cooler temperatures heat generated running balances cold make feel perfectly content',
#  'feel triumphant really change condition life',
#  'feel mad todd isnt stronger need sometimes feels mad im hours away instead helping home',
#  'get excited see outfit think might actually able recreate cheaply feel comfortable wearing',
#  'also feeling appreciative husband bought new shirt new belt',
#  'went back old patterns expecting feel disappointed sad',
#  'feeling rather apprehensive traveling never flown alone worried ability keep track important documents well various travel arrangements',
#  'feel really tortured',
#  'took final walkthrough could almost feel house aching change',
#  'look back another year feel contempt discontent',
#  'find feeling overwhelmed cares world',
#  'im feeling low put favorite high heels stand little taller',
#  'tired wearing shirts derics less feeling cute',
#  'feel bit invigorated',
#  'feel dirty somehow wash evil',
#  'feel blessed able go vote still home less half hour',
#  'feel disappointed meal',
#  'guess similar viewpoint might feel smug better someone else',
#  'call today wasnt good day feeling soooooo dull throughout lessons',
#  'im feelin hot touch say miss wan na say miss much something keeps really quiet im alive im lush love love love',
#  'ever talked afterwards feel really dumb regret saying anything',
#  'im pleased report feel like im seeing ton supportive publications encouraging us realize real try supermom superdad tears eyes',
#  'feel terrible beat child get tooth hoping tooth fairy win round wont find cps waiting doorstep return home virginia',
#  'feeling discomfort strong focus work',
#  'feel supportive sexy comfortable',
#  'love nothingness feeling running feel little weird',
#  'feel fearful starting first draft',
#  'feel resentful',
#  'feeling overwhelmed options could see like red cropped sweater best friends sweater bird frog toys future babies people keep snood',
#  'believe feel invigorated better able cope world matter get paid day job',
#  'love men much especially men life watch make stupid mistakes order avoid fears feelings loving honest relationships slip right fingers',
#  'realize hearts deceitful holy spirits conviction god uses feelings discomfort drive us away dangerous things',
#  'promise cry feel heartbroken every stab comes way promise make hard',
#  'end needing weekend recover weekend lazy feel completely useless bit guilt ridden',
#  'feel pleasant',
#  'im already feeling firmer stronger confident month pfpdx week challenge',
#  'really want near touch pissed feeling rejected suck right thing',
#  'feeling jolly enjoying beautiful october lots blah blahs',
#  'really start packing feeling slightly dazed passing days',
#  'im black henley shirt black sweat pants dont elastic bottom straight cut ones dont feel bit embarrassed',
#  'wear super fierce mask im people know bubbly mask people really closed colorful mask im feeling friendly towards somebody whoooole bunch masks depending situation hand',
#  'feel cute today',
#  'feel dumb someone say something takes seconds register saying',
#  'feel preference privilege tragic dramatic kind sin',
#  'feel super proud part powerful group people',
#  'found feeling pleasant anticipation',
#  'cant feel sincere heart',
#  'feel never chance fully heal without still responsibility caring another person daily basis',
#  'finally realising close finishing tears eyes uni least living egham virginia water get little emotional yesterday realise point may feel little listless',
#  'ive using people motivators right feel determined',
#  'feel know fond continues things sweet kind things friendship keep us daily lives',
#  'firmly believe shouldnt spend lot look feel fantastic love mixing style steals higher end items',
#  'feel blessed roof head food fridge amp cozy warm bed sleep',
#  'feel much intensely dizziness mind though still pleasant',
#  'im feeling unwelcome sometimes',
#  'get bus pass im feeling generous',
#  'feel naughty href photos n sizes id photo gne button zoom class photo gne button sprite zoom grey onclick',
#  'feel terribly unsuccessful attempts make something life',
#  'feel hopeless would open bible odb start searching refreshments',
#  'feeling pretty crappy past days really many outfits show',
#  'currently think hope next tears eyes look back post feel regretful',
#  'feel gun dangerous police baton baton would ha',
#  'feeling positive everything',
#  'understand dude trying best feel accepted everyone annoyed back forth drama',
#  'feel much messy etc',
#  'received book put starting feeling little intimidated afraid might boring difficult',
#  'feel completely heartbroken lost empty',
#  'feel ive given chance way look hell im talented',
#  'know female orgasm feels like things go mind precious moment',
#  'feel entirely dissatisfied',
#  'feel lot confident talking writers writing ever front classroom',
#  'cant help feel anxious',
#  'target feeling pathetic buying clairol nice n easy cover rapidly increasing gray hair big yankees cell phone rang',
#  'wanted say something bad vibe feeling hostile didnt think good night',
#  'im feeling damn sarcastic damn feel like lashing nobody particular',
#  'love rotations amazing feeling give people need help feel loved',
#  'began feel anxious',
#  'didnt feel stress portfolio determines accepted student teaching stressed',
#  'feel mad mother tells hit red zone use breathing stay calm',
#  'understand parents feel things infer dangerous us',
#  'feel bit cranky poetry actually',
#  'feel dismayed many people get stuck salvation mentality',
#  'enjoy maintaining website opportunity change feel inspired',
#  'arrived talking feel discouraged',
#  'start feeling stressed',
#  'feeling much better quite drained bit headache glad home',
#  'im really feeling drained',
#  'im going slide saccharine cutesy wootsy love fest amazes watch young human feel become compassionate',
#  'im feeling exceptionally brave day tell husband need buy like nothing else',
#  'guess ate point drank water point worked point feel like tortured week',
#  'feel like comes faith sometimes need become lost either within outside many different experiences life within',
#  'feel bit clever',
#  'wonder feels dirty started deceptively',
#  'cant wait one appreciate comes along feelings wont vain',
#  'still feel im still rather doubtful abt life ntu think',
#  'withdrew feet feeling strong enough sit look faint bluish purple glow resonating miniature arcs lightning bounced emin fingers surged thin uncontrollable veins across entire pool',
#  'feel relieved someone office believes gay people rights rest us',
#  'usually leave feeling fabulous empowered',
#  'im feeling little snarky grouchy today ill work hard bite tongue',
#  'baffled hurt feel assaulted unsafe',
#  'im feeling really mellow right probably almost whole family away youth rally moment',
#  'feeling like im really caffeine tears eyes dont want get complacent',
#  'feel like know expect feel crappy makes easier',
#  'im feeling really overwhelmed honestly',
#  'want feel lousy christmas mikey stirred crib',
#  'didnt love probably see say pretty engrossing maybe feel dumb twists turns erotic thriller took kept guessing ending end',
#  'feel privileged watch clients fade away size grow happiness eyes',
#  'dunno change plans id dunno feel really really terrible',
#  'still feel timid approaching new person personal level petrified little girl anymore',
#  'feel though men tend violent especially towards women',
#  'feel like wait day talk special someone promise hearing voice seeing skype enough make spontaneously combust excitement packs enough punch carry day smile across face',
#  'feel scared call',
#  'remember feeling energetic need coffee',
#  'dont know keep feeling caring',
#  'feeling numb legs gradually arms laid looking ceiling balling eyes',
#  'tend feel fact wonder might like simply drop concepts judgements hitherto accepted writ simply moment alive',
#  'feel bit nervous anxious know describe actually',
#  'get feel listless crammed information ive opportunity reflect guilty tears eyes ive wasted sluggish spent much tears eyes butt',
#  'feel really honoured invited',
#  'feel proud american cue patriotic theme music',
#  'feel tortured feeling miserable alone',
#  'im back charlotte im fully feeling aftereffects smart decisions last night',
#  'remember many nights would cry feel love hated confidence happiness',
#  'still feel ugly although better',
#  'spent rest day exploring book shelves reading books human rights burma know good use tears eyes help feeling like anything useful could possibly help',
#  'feel awkward',
#  'always came back day beach feeling exhausted sun refreshed calm',
#  'feel respected trusted give know im good kisser nijifagilie',
#  'feel like ages really since ive tpt packet share im glad one',
#  'help feel proud padres fan tears eyes',
#  'feel vital setting thematic mechanical beats get player involved invested',
#  'clue reply feel pounding bars til free',
#  'feel like fake much explain',
#  'feel important tears eyes year important training year',
#  'feel pretty lousy starting wonder thyroid working properly since runs family thyroid issues',
#  'im feeling oddly appreciative life right',
#  'feel distracted sex pet watching',
#  'feel customer service workforce superior',
#  'feel monsters us know fanatics matter hateful amp murderous make army',
#  'forget long ago age feeling carefree',
#  'post one blog tears eyes feeling quite energetic today typing ask',
#  'feel lot guilt making others unhappy',
#  'feel pretty strange women expected hairless nose yet one bats eye dude hairy gorilla ass',
#  'feel like crap everyone else fab tears eyes willl fuck',
#  'feel charming',
#  'feel safe since knows foibles peccadilloes funny side ill safe',
#  'manage avoid one year hosting party little people instead invited adult friends come dinner would least feel festive',
#  'feel alone really',
#  'fucking sad angry right feel completely shitty fucked',
#  'took photo room felt peaceful made feel hopeful',
#  'bring tell feel might rude acting even discourteous',
#  'feel important handwriting scrapbook layouts',
#  'feel caught strange dreamy haze',
#  'feeling pretty bed',
#  'slightly feel shaken think whether mockery would shatter motivation given help fight cancer',
#  'wholeheartedly feel validity vulnerable cyclist road get beyond feeling fear get home safely bicycles',
#  'know feel extremely paranoid lately',
#  'know ive called neville know realist know everyone get along people feel way feel always truthful everyone deal',
#  'say ive feeling little jaded lately weekend amongst plants nature lifted spirits',
#  'feel passionate music like way used',
#  'wear comfortable smart clothes make feel terrific every single day save clothes special occasions',
#  'feel moving towards casual gamer',
#  'stretch feel fabulous',
#  'always feel pressure strong independent icon womanhood without making look whole life revolving around guy',
#  'feel slightly devastated',
#  'adhere friendship stay intact yet couldnt held responsible one thing asked make stop feeling terrible tears eyes',
#  'remember running boston starting feel need get distracted feeling wondered talking would help sarah',
#  'feel vulnerable little anxious sometimes scared push feelings supposed strong bold',
#  'know lot people feel dissatisfied positions life refuse accept mine thats',
#  'really feel hopeless caring environment',
#  'shot makes sense feeling victimized',
#  'abrasive towards people like brock lawly numerous nameless fundies start feeling lame',
#  'hurt much causing feel sacrifice tender care',
#  'got home great night feeling cold trouble falling asleep',
#  'im hoping partners even dont agree interpretation sensitive thoughtful behavior made women feel perhaps reconsider whether guy talk appears benign receiving end',
#  'cant deny feeling restless',
#  'need feel jealous everyone else pregnant feel grateful many options front',
#  'im feeling kinda useless im active anymore',
#  'ended getting nice deals everything bought patient diddled around wares neither made feel uncomfortable taking offers',
#  'feel pretty oh pretty june href http dresswithpurpose',
#  'love style free worship intensity charismatic feel songs last minutes free worship',
#  'sitting home licking wounds day day feeling melancholy baby',
#  'feel quite cripplingly depressed feel bad everything cant anything frozen way',
#  'im feeling happy returned second ncte wish friends would splurge bit feel energy connections create within profession',
#  'either feel uptight alert dazed completely emotionless',
#  'grew trying fight insecurities tried happy look cheerful much possible point life feel pretty quite smart',
#  'feel like im damaged way preventing able relate certain people ways would like',
#  'feel nagged stop caring',
#  'days feel ok today',
#  'feel might believe demands emotional physical connection non negotiable',
#  'feeling insecure grip powerful hormones wondering life going turn',
#  'wonder hot chicks viewed suspicion cops anyone strip searched cop feels suspicious something',
#  'personal issues events occurred left feeling totally pissed fed angry world',
#  'came away feeling certainly tragic life short shelby good life',
#  'believe spend lot look feel fabulous',
#  'feel assured actual baby tummy hehe sounds silly preggo always wonder even baby alive etc',
#  'taciturn feelings timid speak',
#  'feel free get rid feel excess',
#  'im happy energy amp motivation even put make mornings really boosts confidence amp make feel pretty',
#  'feel irritable annoyed pissed deadly homicidal',
#  'knew wanted blog today feel slightly productive writers block left office took walk',
#  'said none deeply touched somehow didnt feel real still liked darius twig',
#  'feel romantic today reasons',
#  'wake feeling energetic feel stronger happier inside handle stress better',
#  'bad feeling going get aggravated tomorrow',
#  'feel heartless right',
#  'feel like mad woman',
#  'im exhausted mildly drunk accumulation beer samples feel satisfied efforts put',
#  'think better first photo though xd look retarded feel quite artistic',
#  'im feeling bit stressed',
#  'went perfect day feeling ok thought within hour full lead feeling like absolute crap',
#  'feel like im punished co workers getting married taking much tears eyes',
#  'feel supportive us know want children fair tell also function insensitive friends reschedule holiday due ivf starting',
#  'must qualify statement somewhat feel perpetrators violent deaths rather feel innocent victims',
#  'feel hesitant try new ones',
#  'feel dunno ungrateful something lonely long wonderful boy want see less',
#  'love get comments feel free ask questions share thoughts',
#  'felt angry pair trousers stolen could able find thief anyone knew story',
#  'dunno whether forgotten yw decided go try dun wan na feel regretful',
#  'im feeling needy messed anymore',
#  'guarantee saw jerks public would feel afraid',
#  'often feel little envious talk people like larry missionaries',
#  'knew needed get dragging feet combo feeling intimidated language barrier kids nap schedules',
#  'feeling groggy',
#  'feel agitated light outside early evening leaves feeling like tears eyes yet keep working dark relax concentrate tears eyes stuff',
#  'guess feel better least',
#  'certainly get concept valuing enough also recognise lot times valued others highly allowed people treat ways feel undervalued accepted treatment simply lot life',
#  'think drinking im feeling festive im feeling',
#  'feel ok plan months november would try write story story actually still actively poking around head think ill able pick back december',
#  'feeling confident going last weeks class',
#  'typing heart trying get lighten realise feel shaky like little tiny people little tiny boat great big ocean sound familiar',
#  'feel like im back uni bit mad',
#  'nervous would feel pain felt delicious smarting tingling heat growing soreness',
#  'feel stressed giving essence tears eyes feel stressed right back away feed without feeling threatened vampiric partner',
#  'really feel like got fucked sexually emotionally abandoned heartbroken spasms pain regressing past abuse even care',
#  'know solved anything sure would momentarily made feel less agitated sure',
#  'really feel super sucky thinking pathetic life',
#  'feel landscape portraits truthful meaningful allow people create feelings portrait based feel see certain plant',
#  'im working still feeling broke',
#  'almost feel ashamed whenever come across year old reading piece classical literature philosophy us gotten point reading considered niche hobby hipsters',
#  'mula pamilya magkakaroon ka ng trust security di ito nafi feel ng bata na abused maria luz estudillo said',
#  'say might subjective please feel insulted points view differ',
#  'think everyone struggles struggled wanting feel popular',
#  'feel valuable book christians googler culture want understand especially gutenbergers lives',
#  'always loved sharing things feel passionate',
#  'already loved sweet woman love even feel like ward super true yall',
#  'im feeling almost spiteful',
#  'hate gays feel heterosexuality makes much acceptable thus god make image',
#  'feel stupid think could actually serious',
#  'feel desire learn explore truth say spirituality leads useful sources',
#  'relate sometimes feel forget people silently supporting praying',
#  'may answer question staroba roles know feeling disillusioned',
#  'like listen without feeling rushed although generally prefer nonfiction audio decided give try',
#  'refuse stay place moments feeling exhausted hard work needing validation return',
#  'wish could back nearest tree something feel offended receiving prickly offering',
#  'aspire much feel im constantly running somewhere impatient restless',
#  'know feels like abused',
#  'glimpsed boredom loss impetus arise feeling uncertain goals',
#  'laugh feeling amused wonder sometimes weird social anxiety aware',
#  'feel drained emotionally spiritually',
#  'feel enormously privileged going parallel maturing process tears eyes speed pop music',
#  'far finished things definitely feel carefree biggies done',
#  'popenguine everyone great makes feel truly welcomed',
#  'feel like object humiliated used',
#  'arrived entertain enthusiasts feel entertained',
#  'engaged flurry wedding planning know like feel need lose weight holiday special event think year get ultimate body',
#  'think feel sad leave',
#  'envy confidence help feeling resentful effortlessly balances cultural deference self affirmation',
#  'feel like theres nothing like smile friendly salaam alaikum everyones staring twisting mouths pity curiosity disgust avoiding eye contact looking way abruptly',
#  'feel vile feel like dumpster human negativity causes insides collapse outsides break scab frizz dry',
#  'im sure makes sense anyone else always feel like im weird one literally feels life quickly passing',
#  'feel blogger shouldnt afraid blog topics issues may potentially offensive others importantant highly opinionated',
#  'im feeling unsure much tears eyes start doubting',
#  'end state financially feeling useless low self esteem confident picking new job even old job open grab',
#  'feel little like maybe missed something',
#  'hope routinely hopes crushed feel stupid hope',
#  'get lonely get inspired draw use feelings push artistic ability',
#  'mention feel lousy',
#  'use relax sometimes feeling little stressed',
#  'starting feeling like project make recipe something creative order post',
#  'deterred outside take children made feel crappy dont like stay home',
#  'feel super duper tired',
#  'feeling positive ready attack week',
#  'made feel totally unwelcome managers work gone one trained team human least',
#  'feel almost angry bored frustrated useless',
#  'im writing feel tad bit reluctant say goodbye year',
#  'pagetitle geeths dawath almond burfi metadescription days back feeling restless two failures almond burfi tried two different sources',
#  'get tired easily weaker feel lousy etc',
#  'feel triumphant weirdly anxious patriots making way super bowl',
#  'informed feeling blank nonchalant wont like see',
#  'feel anything trusting anyone esle mater',
#  'always wake great mood feel relaxed',
#  'miss able lounge couch day watch football eat good food feel distracted countless projects floating around mind',
#  'feel innocent smile mine others lifeline words want convey way',
#  'grew wanting much like everyone family never settled one unique musical niche feel smug mocking others dare like pop song indie folk techno show tunes even ska',
#  'feel bitter towards friend feel bad tears eyes become reserved around want',
#  'ive feeling little blank could think nothing write might interesting explore mind captivated',
#  'idea store feeling anxious',
#  'still feel tortured knowing wake everyday alive somewhere world someone dying',
#  'managed keep hold remainder classes barely feeling stressed got home took klonopin',
#  'feel helpless rid',
#  'still feel relief still feel satisfied want crave options seem promising worth shot',
#  'feel like ive missed lot lately',
#  'feel like really cool close friend',
#  'still feel though something sweet wonderful ending',
#  'still feel complacent unfinished projects',
#  'also think wouldnt hurt let feel admired',
#  'know said man lately ladies know feel gentlemen effort put communication emotions work together build strong unit moves forward together',
#  'consume keeps feeling like terrible terrible human',
#  'feeling wouldnt pleased dad',
#  'im sure feel song since kind really obnoxious whatever fun',
#  'ive always cant seem focus school anymore im sick feeling dazed',
#  'ive struggled weight ages im sick feeling naff doubly determined succeed',
#  'im feeling quite lethargic feel like sitting lounge watching tv like',
#  'hold pretty heavy grudges feel someone wronged',
#  'feel direction life find passion hold passionate something really tears eyes good',
#  'feeling totally heartbroken reason',
#  'feeling like goal little lame comparison',
#  'rise know feelings lie wont beaten lie',
#  'frightened weight continuing go whilst stand feeling helpless scoffing course',
#  'im fatigued feeling sentimental',
#  'feel honored high level discourse blog extraordinary people reading writing',
#  'grew feeling shamed judged lot learn family friends society school work media',
#  'click instantly feel horrible',
#  'need work tomorrow feeling burdened tedium mundane world wishing something someone appear conversation magick tarot wands spells meditation etc',
#  'feel like dangerous menacing criminals',
#  'feel terrible neglected scrubs long summer',
#  'feel timid face world anymore',
#  'ive always hidden think feel act feel accepted family friends society',
#  'feel makes little oasis hawaii special',
#  'feel determined keep daily deficit whilst honest tracking happen tears eyes',
#  'like eat im homesick feeling nostalgic',
#  'hope youre enjoyable pvp experience well see progresses decide try different spec feel useful',
#  'want protect feeling unloved like',
#  'im friends id rather expound make feel absolutely horrible',
#  'issue forgiving never feel offended',
#  'havent feeling long tears eyes reciprocation proud friend made big change today would never seen wearing weird furry boots look like animal hooves rubber soles',
#  'im feeling sad today confidant ive done right thing',
#  'feel uncertain lot things',
#  'feel stressed would understatement',
#  'never imagined dad could wonderful fulfilling never understood like love woman especially one actually loves respects well new feeling one im quite fond',
#  'also hoping feel well enough us make julian tears eyes weekend',
#  'suppose boring appointment good thing help feeling disappointed something interesting write blog',
#  'want make friends family feel welcomed greeted invited special even open front door',
#  'feeling little shaken center searching peace beauty like highlight fabulous',
#  'feel numb posted href http leslielandberg',
#  'feel precious thing people always late grates thing',
#  'feel dumb',
#  'feel lucky love job',
#  'feel like alone wanted whatever seems like wrong thing',
#  'feel gloomy everyday',
#  'always feel disturbed get crap mind writing somewhere else',
#  'feel regretful disgusted self',
#  'believe every woman feel glamorous beautiful every day',
# ...
#  'confess like others feeling sort stupidly sentimental moment possessed precious little met christopher hitchens anecdote rest assured shall restrain',
#  'feel angry brazilian players',
#  'try taking deep breaths feel overwhelmed',
#  'woke feeling homesick missing much despite wonderful bkk past da',
#  'feel like theres empty piece still found going back living understanding roots',
#  'confirmed place back may june quite remember tears eyes still feeling pretty uncertain feeling huge amount pressure commit numerous people asking',
#  'said personal opinion please ignore anything might feel offended pictures href http toymakerinc',
#  'care think im bein douche care think ive helped caring care feel bad care think something anything',
#  'realised even know refugee families living suburb let alone whether feel welcomed whether need help',
#  'feel amply welcomed kingdom insofar experience earth jesus father',
#  'see making beautiful artistic home earthen materials feeling excited inspired happy joyful working creatively people',
#  'job needed missed go away things missed person feels amazing',
#  'feel kinds special even wont match',
#  'feel like artists love ones find truly talented seem unique style recognize mile away',
#  'bet counting midnight celebrate new year go home go bed without feeling completely lame',
#  'feeling hell pretty pleased',
#  'realise im clearly feeling hostile bracing overwhelming sadness come',
#  'ive feeling bit nostalgic young adult novels actual young adulthood',
#  'still feeling impatient go back home',
#  'feeling bit isolated perhaps entirely sure least three months still go travelling lark really cup tea',
#  'im feeling mistake people actually suffering mistake',
#  'like outsourcing picky sod usually end feeling dissatisfied work others force outsource need realize everything',
#  'feel like rut aching change',
#  'im sorry whole anniversary milestone feeling romantic',
#  'feeling relaxed healthy ready bed',
#  'feeling discouraged broken broken many times',
#  'didnt feel enough strong smart funny female main characters fiction since thats imagine started writing',
#  'feel like isnt happy one',
#  'slept morning away setting clock purchased first day barcelona forward one hour sitting poke hand window feel gentle rain curling drowsing',
#  'need little sugar bowl need little hot dog roll stand bit loving oh bad feel funny feel sad',
#  'feel pretty awful tired started show yet yes gender boy',
#  'feel overly intelligent talking length past simply population always issue mmorpgs',
#  'feel pity think people believe jesus faith live perfect lives free sin pain',
#  'regret crackers wondering much feeling lousy due eating wheat gluten higher carb much due actual illness',
#  'feel pathetic useless today',
#  'share im feeling thankful w amp christian friends around',
#  'play feel special big',
#  'honestly feel surprised though suppose',
#  'feel low right',
#  'feel shaken unsettled need shake things makes sense',
#  'always think things thankful everyday basis feel overwhelming blessed',
#  'feel relaxed energetic',
#  'feel greedy tell god given much handle good tears eyes cause god sees necessity give ability handle bless',
#  'find feel embarrassed speaking portuguese people know stakes higher',
#  'stepped house makes feel depressed',
#  'tell go back last woman dated could emotionally express would never tell feeling guys would thrilled girlfriend crazy',
#  'feel like people constantly curious much weigh look like wear',
#  'feel heartbroken soul nblogging',
#  'accepted student',
#  'already place feeling unloved taken advantage rejected hit nerve',
#  'le gayi im feeling generous today',
#  'feel respected trusted valued even',
#  'feeling listless depressed',
#  'guess surprised feeling homesick soon',
#  'feel everyone loves gossip make mistake trusting one person every best friend another best friend one ever keeps things',
#  'like feeling needy',
#  'noticed mom dad brought home good news new job didnt feel anything clearly supposed feel ecstatic',
#  'im feeling pretty miserable',
#  'sitting class feeling really dumb idea professor talking',
#  'even explain laugh smile feel amazing',
#  'ive told feel defective goods',
#  'know heart hearts rejoice things still feel selfish heavy',
#  'feel like nobody getting hurt result something like made harm foul',
#  'feeling bit unsure',
#  'doubt theres greater reluctance federal authorities employ tear gas plain force feel threatened',
#  'im wearing lots makeup feeling discontent insecure',
#  'feel even determined sort though going slow progress keep getting distracted fabric forgotten remembering bought projects yet sewn',
#  'feel violent today',
#  'feel pleasant anticipation knowledge likely surrounded novelty beauty thailand rest sea soon',
#  'feel ugly stupid alone',
#  'shared feel god faithful',
#  'could almost feel shocked gazes band mates fact would surely notice one especially could imagine reaction would get',
#  'finally able put name writhing burning pain feeling stomach throat esophagitis dull aches back muscles shortness breath heart palpitations well mad stress didnt realize',
#  'feel little brave venture comfort zone kitchen',
#  'suppose could walked table effectively butting line rude instead watched people books signed left feeling satisfied experience',
#  'know going feel shitty wednesday',
#  'feel alone emptiness could filled',
#  'feel like learn ec get popular tears eyes goes want regret putting tears eyes learn',
#  'feel like strong person',
#  'painting go two planned feel reluctant throw moment knowing world turned upside tiniest demanding beings least little',
#  'feel convinced language loses capability tell stories eloquently continuously beauty lost soul',
#  'mean care much family going things becoming something making feel almost morose',
#  'came morning tea chia ready start something feeling productive routine',
#  'feel smart impressive',
#  'feel uncertain every decision make',
#  'look richmond lived last ten years tried get attention paid ideas feel disheartened',
#  'never fail feel sense joyful elation chosen instrument amazing healing system',
#  'longer feel guilty',
#  'feel many people deemed intelligent arent really intelligent youd think theyre hardworking',
#  'bed feeling foolish emotional',
#  'im currently luckily remember feeling miserable first came school',
#  'feel reluctant week dont want stop',
#  'least know good ones feels amazing find guy truly complements goofiness nerdiness craziness',
#  'completely flattered brings full circle said earlier feeling strange',
#  'im feeling really really grumpy',
#  'ive done best week take care aside sneezing feeling little lethargic like ive got crap lungs im feeling better taking daily theraflu liquid medicine swear along drinking plenty fluids juices',
#  'cant remember words clumsy mouth feels funny jerky cant spell',
#  'ive feeling bit disillusioned since seeing viddy katy perry recently meeting karl lagerfeld dinner paris fashion week',
#  'feel sorrow beloved miss',
#  'still feel need safe place vent write get stuff chest without feeling judged like put false pretenses',
#  'im starting feel like useless old man',
#  'think ex made feel unimportant thought important suspect behaviour came across like important partly know deal want deal',
#  'hear kids mums nannies around dads course used dad sea mums nannies even feel weird',
#  'feel romantic tonight',
#  'feel need delicate discuss mildly autistic issues using soap anyway',
#  'wrong standards religion talk god feel pretty peaceful pretty simple',
#  'feel rotten',
#  'giggle feel joyful',
#  'feel lame run minute miles despite goal',
#  'feel learn conducting still continuously getting positive feedback choir',
#  'realized reason feel thrilled town get sleep without waking middle night hes finally home work',
#  'didnt know awesome could feel spouse team turns successful',
#  'hate way feel hate grumpy tired sore throat every tears eyes cough hate feel like head literally going explode spot',
#  'want team members feel valued appreciated',
#  'ill let people know im feeling really annoyed day cause hate people guessing lying around hiding truths',
#  'feel like tragic fucking strong word',
#  'started feeling pathetic tragic sorry',
#  'feel lucky grateful handling treatment way',
#  'happy anc feeling might training next transfer hopefully sweet sister hedelius manti ut',
#  'im frustrated feel fucked something feels',
#  'feel sympathetic',
#  'feeling awfully romantic dudes',
#  'arriving new zealand teenager first overseas trip something exhilarating change scenery etc',
#  'used ambitious believe doubt feel drained lack self belief',
#  'know feel feel confused overwhelmed unable pull ground even though know going okay',
#  'feel like julie roberts pretty woman wears smart shorts suit polo match',
#  'normal day didnt feel well completely normal day take mtx',
#  'watching china winning asian olympic games',
#  'writer tonight feeling bit heartbroken',
#  'strongly believe get victimized somebody gaze really want feel victimized',
#  'feel particularly intelligent visual memory good study habits knack test taking',
#  'sit year later feel even hesitant',
#  'admit sometimes struggling feeling lonely overall think natural friend filtration process adulthood brings positive process',
#  'found leaving meeting feeling restless usual',
#  'feel like fault talking innocent enough think actually wanted conversation sex',
#  'received call tuition agency guy told wife used teach primary school recollections feeling extremely ungrateful',
#  'feel really bitter',
#  'get ready bed evening feeling really really discouraged vow nothing work cv next day leave silly writing behind buckle find real work',
#  'really proud sticking non smoking feeling bit frustrated ashamed lack progress health goals',
#  'feel like mention dad obnoxious tourists',
#  'feel always far bolder stephies lovely gentle way painting',
#  'feel student killed innocent victims shouldnt get media attention w videos amp pics',
#  'wasnt cant anything feel helpless theres much pain involved want curl die',
#  'see dearest standing ready catch fall feel nothing distraught',
#  'im anxious term done feeling little stressed homework',
#  'bit childrens head way flippin bible study feel like crappy mom dont want get mornings sometimes',
#  'feel funny sometimes especially think like tug snap twang tight string pull push away today tomorrow',
#  'end feeling messy unpolished day',
#  'feel depressed voting knowing voted created problem dont another choice',
#  'im feeling needy',
#  'im feeling kinda horny booked flight burbank',
#  'im trying find balance allowing ey european specialties cant eat home stuffing face feeling crappy',
#  'get slightly queasy feeling reading romantic plot even im fully enjoying',
#  'feel nostalgic friends counting increments much fraction doctor point',
#  'feel unloved unappreciated unwanted',
#  'feel impatient tears eyes running',
#  'feel ignored unseen',
#  'also feel feelings intensely im afraid talk share',
#  'feel accepted others',
#  'suppose feel nothings resolved know soccer playing wont go away',
#  'im pretty sure feeling mutual sweet pair',
#  'suddenly started feeling less stressed sleeping better feeling healthier realized recent health problems actually resulted working toxic environments',
#  'feel im alone dreams accompanied someone definately invited',
#  'im feeling little less trusting everyday shopping day',
#  'walk around dressed plainly im talking usual printed tee jeans shorts skirt combo feel dull well',
#  'taken piriton makes sleepy seems much effect allergies night alongside co codamol forgotten makes feel rotten breathless tired doesnt seem help pain',
#  'feeling overwhelmed depressed lilli needs go back read wrote lilli eighth birthday remind born purpose created way reason',
#  'feeling probably arent impressed either',
#  'pleasantly surprised feeling pretty smug chosen wild card weather good trails fun food great stayed really beautiful place',
#  'im really feeling mood write anything worthwhile ill end wittering absolute crap depending perspective one need read',
#  'still reading learning much connection pets truly formulating opinions interact culture first question would would people feel socially acceptable treat children people like animals',
#  'tended try pleasing others things afraid might feel rejected',
#  'really angry since feel really sincere towards qiuyue wanted together',
#  'really feeling eager put noose around neck second get work every day',
#  'feel way im proud tattos',
#  'im sure personal thing movie accompanied song feel sorrowful right',
#  'feeling troubled',
#  'im lucky last hour usually like ten minutes feeling pathetic',
#  'im reveling start shiny new year makes feel totally loving hopeful',
#  'still awe much love child full makes life feel also thrilled much brothers sister love',
#  'hadnt thought feel dumb really inconvenient talk listen',
#  'feel incredibly devastated',
#  'feel uncomfortable day',
#  'feel pesimistic bitchy try act',
#  'feel almost embarrassed contribution ridiculously unsophisticated pretty much immune alteration things happening',
#  'dont know could fill heart feel sweet girls',
#  'feel stunned vision sea pilgrims',
#  'expected feel terrified endangered',
#  'feel like treading dangerous ground reveal much',
#  'im feeling really productive wear something simple presentable like basic shirt jeans',
#  'feeling rich yup know blessed',
#  'couldnt feel god still little faithful desperation kept wanting jesus although felt weak times like couldnt get hold never stopped hoping would',
#  'remember saying feel weird woke seat pass',
#  'feeling thankful blessed',
#  'finally able feel comfortable bathing suit rowdy bunch drunken indian college boys rolled boat shore',
#  'feel bit depressed studying days',
#  'feel bad break rules india elders scold',
#  'feel fearful anticipation new experience remind sometimes repeatedly',
#  'feel like lot people dont really sing popular music said upbeat reflective rae recent interview',
#  'understand saying feel like think sincere way',
#  'feel quite sure ill able forgive completely lose lbs',
#  'one go crazy christmas thanksgiving desire year avoid crazed state mind us feel even determined stay sane',
#  'weeks days today feeling fantastic',
#  'im feeling homesick yet im feeling alright',
#  'ive done good amount audience research seoul feel like would useful opportunity',
#  'feel connection joanne im glad know im one turns cooking therapy',
#  'san francisco fifth said feeling bit numb',
#  'read dave pelzer book read thought ooh thats grim didnt feel need go read tales kids abused',
#  'feel like heartless bitch dragging th graders stage seemed like contrived obvious finish show could gone',
#  'enjoy feeling find become complacent emptiness',
#  'didnt human feeling love beloved',
#  'im feeling stupid keep loving someone doesnt even cares feelings',
#  'feeling excited proud even finishing started',
#  'feel slighted determined impose left good terms right tears eyes',
#  'feel jealous way feel books target blank img src http img',
#  'crawled back bed feeling relieved didnt check immediately breaking cold sweat whenever tried feet',
#  'began cry describe feeling feel useless empty',
#  'told staff said know feel invigorated stuff',
#  'walk pub london feel frightened',
#  'said sorry feel talking something would ever show asked see lovely falsetto chorus let see way someone else eyes',
#  'feel quite privileged good line',
#  'im back track sure feeling really love longing someone since ive seem misconception',
#  'feel devastated occured good cause hopefully dogs run around acting like dont get shot',
#  'wish everyone feeling happy today families friends',
#  'feeling indecisive since favorite option',
#  'im feeling low creativity ill troll drafts',
#  'cried lot night going sleep feeling nervous scared sad amazing adventure nothing real world awaited us got back',
#  'wayne sue close friends announced guardians ther wedding',
#  'feeling optimistic good core te shoulder burden wr',
#  'feel like neglectful dolly mommy',
#  'want feel resentful guys want chip help',
#  'feel regretful mom grandma keep reminding',
#  ...]

# %%
emotions_cv = CountVectorizer(token_pattern=r'[^\s]+', max_features=7500)
emotions_X = emotions_cv.fit_transform(emotions_text).toarray()
emotions_X.shape
# Out:
# (50001, 7500)

# %%
emotions_x_train, emotions_x_test, emotions_y_train, emotions_y_test = train_test_split(emotions_X, emotions_y, test_size = 0.25)

# %%
emotions_model = MultinomialNB()
emotions_model.fit(emotions_x_train, emotions_y_train)
# Out:
# MultinomialNB()

# %%
emotions_y_pred = emotions_model.predict(emotions_x_test)
accuracy = accuracy_score(emotions_y_test, emotions_y_pred)
accuracy
# Out:
# 0.8618510519158468

# %%
# Six categories: sadness (0), joy (1), love (2), anger (3), fear (4), and surprise (5).
message = "This Sucks!"
prediction(message, emotions_model, emotions_cv)
# Out:
# array([[0.24956348, 0.22524736, 0.09779449, 0.26053409, 0.1554596 ,
#         0.01140098]])

# %%
emotion_model_filename = "emotion_model.pickle"
pickle.dump(emotions_model, open(emotion_model_filename, "wb"))
emotion_cv_filename = "emotion_cv.pickle"
pickle.dump(emotions_cv, open(emotion_cv_filename, "wb"))
